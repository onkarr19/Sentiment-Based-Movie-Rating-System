# %%
import nltk                                # Python library for NLP
from nltk.corpus import twitter_samples    # sample Twitter dataset from NLTK

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\onkar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\twitter_samples.zip.
# True

# %%
#  import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\onkar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
print('Number of positive tweets:', len(all_positive_tweets))
print('Number of negative tweets:', len(all_negative_tweets))

print('\nThe type of all_positive_tweets is:', type(all_positive_tweets))
print('The type of a tweet entry is:', type(all_negative_tweets[0]))
# Out:
# Number of positive tweets: 5000
# Number of negative tweets: 5000
#
# The type of all_positive_tweets is: <class 'list'>
# The type of a tweet entry is: <class 'str'>

# %% [markdown]
# # Splitting Data
# #### Train : Test :: 80 : 20

# %%
n = int(len(all_positive_tweets)*0.8)
test_pos = all_positive_tweets[n:]
train_pos = all_positive_tweets[:n]
test_neg = all_negative_tweets[n:]
train_neg = all_negative_tweets[:n]

# %%
train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %%
import re
import string
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer


def process_statements(statement):
    """Process statement function.
    Input:
        statement: a string containing a statement
    Output:
        statements_clean: a list of words containing the processed statement

    """
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    
    # remove stock market tickers like $GE
    statement = re.sub(r'\$\w*', '', statement)
    
    # remove old style retweet text "RT"
    statement = re.sub(r'^RT[\s]+', '', statement)
    
    # remove hyperlinks
    statement = re.sub(r'https?:\/\/.*[\r\n]*', '', statement)
    
    # remove hashtags
    # only removing the hash # sign from the word
    statement = re.sub(r'#', '', statement)
    
    # tokenize statements
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    statement_tokens = tokenizer.tokenize(statement)

    statements_clean = []
    for word in statement_tokens:
        if (word not in stopwords_english and  # remove stopwords
                word not in string.punctuation):  # remove punctuation
            # statements_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            statements_clean.append(stem_word)

    return statements_clean

# %%
def get_freqs(data):
    """Process statement function.
    Input:
        data: an array of strings containing a statement
    Output:
        freq_dict: a dictionary of words representing their frequencies

    """
    freq_dict = {}
    for i in data:
        for word in process_statements(i):
            if word in freq_dict:
                freq_dict[word]+=1
            else:
                freq_dict[word]=1
    return freq_dict

# %%
dict_of_positives = get_freqs(train_pos)
dict_of_negatives = get_freqs(train_neg)

# %%
pos = dict_of_positives.keys()
neg = dict_of_negatives.keys()

res = pos | neg
len(res)
# Out:
# 9085

# %%
resultant_dict = {}
for i in res:
    pos_value = dict_of_positives.get(i,0)
    neg_value = dict_of_negatives.get(i,0)
    x = pos_value / (pos_value+neg_value)
    
    resultant_dict[i] = x

# %%
def check(s):
    cleaned = process_statements(s)
    
    arr = []
    for i in cleaned:
        x = resultant_dict.get(i, 0.5)
        arr.append(x)
        
    print(cleaned)
    print(np.mean(arr))
    
    return np.mean(arr)

# %%
s = 'Wonderful, loved it! :)'
check(s)
# Out:
# ['wonder', 'love', ':)']
# 0.8220976910632083
# 0.8220976910632083

# %%
import pickle

# %%
def save_data(file, data):
    with open(file, 'wb') as f:
        pickle.dump(data, f)

# %%
def load_data(file):
    with open(file, 'rb') as f:
        return pickle.load(f)

# %%
file = 'model_1.pkl'
# save_data(file, resultant_dict)

# %%
# x = load_data(file)

# %%
# x
# Out:
# {'surrey': 1.0,
#  'barefoot': 0.0,
#  'adio': 0.0,
#  'orphan': 0.0,
#  'shaaa': 0.0,
#  'tommorow': 1.0,
#  'caro': 1.0,
#  'monkey': 0.0,
#  'gent': 1.0,
#  'pausetim': 1.0,
#  'outi': 1.0,
#  'img': 1.0,
#  'jenna': 1.0,
#  'retard': 1.0,
#  'fresherstofin': 0.0,
#  'shek': 0.0,
#  'strang': 1.0,
#  'kingdom': 0.5,
#  'peek': 1.0,
#  'katamari': 1.0,
#  'coconut': 1.0,
#  'ohgod': 0.0,
#  'ffvi': 0.0,
#  '5pm': 1.0,
#  'cyber': 0.5,
#  'thanq': 1.0,
#  'birthdaymonth': 1.0,
#  '☆': 1.0,
#  'meant': 0.3333333333333333,
#  'kayla': 0.0,
#  'an': 0.3333333333333333,
#  'lrka': 0.0,
#  'controversi': 0.0,
#  'away': 0.3333333333333333,
#  'najam': 1.0,
#  'conflict': 1.0,
#  'everyth': 0.4166666666666667,
#  'x11': 1.0,
#  'straight': 0.0,
#  'aaahh': 0.0,
#  'rememb': 0.45,
#  'usernam': 1.0,
#  'smoak': 1.0,
#  'book': 0.4666666666666667,
#  'skrillah': 0.0,
#  'brambhatt': 1.0,
#  'mental': 0.2,
#  'angel': 0.6666666666666666,
#  'ion': 0.0,
#  '😬': 0.0,
#  'cass': 1.0,
#  'freez': 0.0,
#  '):': 0.5,
#  'lowest': 0.0,
#  'caribbean': 0.0,
#  'unam': 1.0,
#  '__': 0.3333333333333333,
#  'l': 0.5,
#  '6gb': 0.0,
#  'inapropri': 0.0,
#  'surviv': 0.4,
#  'bbi': 0.3333333333333333,
#  'stock': 0.6,
#  'abit': 1.0,
#  'intro': 1.0,
#  'sg1': 1.0,
#  'cafe': 0.0,
#  'consider': 1.0,
#  'ram': 1.0,
#  'cop': 0.5,
#  "we'v": 0.6666666666666666,
#  'fiesta': 1.0,
#  'viewer': 0.0,
#  'bachpan': 0.0,
#  'niamh': 0.5,
#  'login': 0.0,
#  'tabl': 0.0,
#  'program': 1.0,
#  'seeker': 0.0,
#  'closer-chas': 1.0,
#  'rel': 0.0,
#  'lmfaooo': 0.0,
#  'creat': 0.75,
#  'etc': 0.6666666666666666,
#  'bna': 0.0,
#  'veget': 0.0,
#  'niwll': 0.0,
#  'johnforceo': 1.0,
#  'tulan': 1.0,
#  'cleans': 1.0,
#  '2ne1': 1.0,
#  'motiv': 0.0,
#  'ada': 1.0,
#  'fl': 1.0,
#  'nailedit': 1.0,
#  'ifimeetanalien': 1.0,
#  'tombow': 1.0,
#  'cutest': 0.3333333333333333,
#  'bought': 0.25,
#  'bajrangibhaijaanhighestweek': 1.0,
#  'din': 0.5,
#  'humid': 1.0,
#  'reqd': 1.0,
#  'cabl': 0.0,
#  'bigbang': 0.0,
#  'se': 0.6666666666666666,
#  'ninh': 1.0,
#  'jacki': 1.0,
#  'jason': 1.0,
#  'brolli': 0.0,
#  'afang': 1.0,
#  'error': 0.0,
#  'assassin': 0.0,
#  '👌': 0.5,
#  'vampir': 1.0,
#  'ohhh': 0.6,
#  'kale': 1.0,
#  'djstruthmat': 1.0,
#  'gossip': 1.0,
#  'dipoppo': 0.0,
#  'updat': 0.5454545454545454,
#  'waa': 0.0,
#  'nyc': 1.0,
#  'darn': 0.0,
#  ':-)': 1.0,
#  '😜': 1.0,
#  '>:d': 1.0,
#  'justget': 0.0,
#  'heyi': 0.0,
#  'pigeon': 0.0,
#  'march': 0.5,
#  'hatessuc': 1.0,
#  'landscap': 1.0,
#  'kathryn': 1.0,
#  'dream': 0.5,
#  'oh': 0.36065573770491804,
#  'hk': 0.5,
#  'elect': 0.3333333333333333,
#  'agre': 0.7647058823529411,
#  'estat': 0.0,
#  'entrepreneurship': 1.0,
#  'topnewfollow': 1.0,
#  'ou': 1.0,
#  'crystal': 1.0,
#  'cushion': 1.0,
#  'excus': 0.5,
#  'biom': 0.0,
#  'inaccur': 0.0,
#  'welder': 0.0,
#  'excit': 0.875,
#  'ladyposs': 1.0,
#  'mixtur': 0.0,
#  'sorri': 0.1,
#  'hih': 1.0,
#  'worri': 0.7727272727272727,
#  'happybirthday': 1.0,
#  'knew': 0.5833333333333334,
#  'otp': 0.25,
#  'mka': 1.0,
#  '61': 0.0,
#  'build': 0.8,
#  'kart': 1.0,
#  '30': 0.6,
#  'appear': 0.6,
#  'lolz': 1.0,
#  'crack': 0.3333333333333333,
#  '. . .': 0.5,
#  'mood': 0.75,
#  '01482': 1.0,
#  'nk': 0.0,
#  '90210': 1.0,
#  'noesss': 0.0,
#  'palac': 1.0,
#  '️2': 0.0,
#  "why'd": 1.0,
#  'fun': 0.6923076923076923,
#  'hai': 0.4666666666666667,
#  'a6': 1.0,
#  'misspelt': 0.0,
#  'sunday': 0.46153846153846156,
#  'linda': 0.0,
#  'moar': 1.0,
#  '12.00': 0.0,
#  'rescu': 1.0,
#  'x29': 1.0,
#  'homosexu': 1.0,
#  'hobbi': 1.0,
#  'hand': 0.26666666666666666,
#  'alvadhaau': 0.0,
#  'mubank': 0.5,
#  'dozen': 0.0,
#  'indian': 0.3333333333333333,
#  'car': 0.3125,
#  '∠': 0.0,
#  'p': 0.5,
#  'idiot': 1.0,
#  're-watch': 1.0,
#  'imysm': 0.0,
#  'pc': 0.75,
#  'jarraaa': 1.0,
#  'basil': 0.5,
#  'influenti': 0.0,
#  'ooz': 1.0,
#  'crikey': 0.0,
#  'tykkäsin': 1.0,
#  'mcdo': 1.0,
#  'victoria': 0.0,
#  'overcast': 0.0,
#  "q'don": 0.0,
#  'java': 1.0,
#  'yosh': 1.0,
#  'rqst': 1.0,
#  "kinara'": 0.0,
#  'theo': 0.0,
#  'tasteless': 0.0,
#  'runescap': 1.0,
#  'sooo': 0.3333333333333333,
#  '20min': 0.0,
#  '350': 0.0,
#  'heat': 0.5,
#  'km': 0.3333333333333333,
#  'sialan': 0.0,
#  'ideal': 1.0,
#  'notic': 0.3333333333333333,
#  'hero': 1.0,
#  '⭐': 1.0,
#  'vsco': 1.0,
#  'crimin': 0.0,
#  'redhead': 1.0,
#  'interact': 0.3333333333333333,
#  "mine'": 0.0,
#  'hanabutl': 1.0,
#  'approv': 1.0,
#  'lansi': 0.0,
#  'nation': 0.6,
#  'conven': 0.0,
#  'sticker': 1.0,
#  'mein': 0.5,
#  'muaahhh': 1.0,
#  'tour': 0.36363636363636365,
#  'co-work': 0.0,
#  'logo': 1.0,
#  'basenam': 0.0,
#  'bnf': 1.0,
#  'amyjackson': 1.0,
#  'oi': 0.0,
#  'judi': 1.0,
#  '341': 0.0,
#  'prime': 1.0,
#  'b2aa': 0.0,
#  'tam': 0.0,
#  'cilic': 1.0,
#  'thank': 0.842809364548495,
#  'prepar': 0.3333333333333333,
#  'star': 0.7272727272727273,
#  '10:17': 1.0,
#  'retali': 1.0,
#  '2015': 0.5416666666666666,
#  'ndee': 1.0,
#  'debacl': 1.0,
#  'mamayang': 1.0,
#  'zumba': 0.0,
#  'wgm': 1.0,
#  'csrrace': 1.0,
#  'truli': 0.0,
#  'ran': 0.25,
#  'nigg': 1.0,
#  'hubba': 0.0,
#  '인피니트': 0.0,
#  'bi0': 1.0,
#  '😟': 0.0,
#  '07:02': 0.0,
#  'rubber': 1.0,
#  'ad': 0.9090909090909091,
#  'pleasant': 1.0,
#  'ole': 0.0,
#  'toptravelcentar': 1.0,
#  'thnkyouuu': 0.0,
#  'pud': 1.0,
#  'flavour': 0.0,
#  'friooo': 0.0,
#  'hahay': 0.0,
#  'stumbl': 1.0,
#  'wip': 1.0,
#  'yer': 1.0,
#  'fifth': 0.5,
#  'jeep': 1.0,
#  'worthwhil': 1.0,
#  '→': 1.0,
#  'includ': 0.75,
#  'cute': 0.3620689655172414,
#  'meri': 1.0,
#  'mom': 0.4117647058823529,
#  "second'": 1.0,
#  'tl': 0.125,
#  'tweak': 0.5,
#  'muertosatfring': 1.0,
#  'godbless': 1.0,
#  'unsettl': 0.0,
#  '2k15': 1.0,
#  'femin': 1.0,
#  'ji': 1.0,
#  'resort': 1.0,
#  'ed': 0.0,
#  'chap': 0.0,
#  'jotzh': 1.0,
#  'basi': 1.0,
#  'fowl': 1.0,
#  'wheelchair': 0.0,
#  'kb': 0.5,
#  'partner': 0.0,
#  'brb': 0.5,
#  'minju': 1.0,
#  'mr2': 1.0,
#  'ge': 1.0,
#  'ug': 0.0,
#  'mileag': 1.0,
#  'carli': 1.0,
#  'gomez': 1.0,
#  'unfav': 0.0,
#  'disney': 0.5,
#  'loos': 0.6666666666666666,
#  "php'": 1.0,
#  'gestur': 1.0,
#  'pakistani': 1.0,
#  'nez': 1.0,
#  'kiksext': 0.5,
#  'legit': 0.5,
#  'ack': 1.0,
#  'hickey': 1.0,
#  'cue': 1.0,
#  'goictiv': 1.0,
#  'groan': 0.0,
#  'cactu': 0.0,
#  'extraordinari': 1.0,
#  'vega': 0.6,
#  'scream': 0.6666666666666666,
#  'confid': 0.0,
#  'postpon': 0.0,
#  'heheheh': 1.0,
#  'fern': 0.0,
#  'appli': 0.8333333333333334,
#  'adf': 1.0,
#  'perspect': 0.0,
#  'other': 0.5714285714285714,
#  'hi': 0.8461538461538461,
#  'engross': 1.0,
#  'mesh': 0.0,
#  'stori': 0.47619047619047616,
#  'wailay': 0.0,
#  'heiya': 1.0,
#  'chase': 1.0,
#  'sunni': 0.8333333333333334,
#  'xi': 0.0,
#  "what'": 0.5185185185185185,
#  'data': 0.16666666666666666,
#  'tweepsmatchout': 0.0,
#  'jannatul': 0.0,
#  'silverston': 1.0,
#  'spade': 0.0,
#  '..': 0.5291005291005291,
#  'etdi': 1.0,
#  'pitbul': 1.0,
#  'base': 0.6666666666666666,
#  'hundr': 0.0,
#  'josh': 0.5,
#  'buri': 0.0,
#  'paw': 0.0,
#  'hunt': 1.0,
#  'earth': 1.0,
#  'felt': 0.42857142857142855,
#  'manga': 0.0,
#  '7elw': 0.0,
#  'incred': 1.0,
#  'grasp': 0.0,
#  'facebook': 0.5,
#  'coco': 1.0,
#  'afterschool': 0.0,
#  '4:20': 0.0,
#  'merced': 1.0,
#  'harap': 0.0,
#  'where.do.i.start': 1.0,
#  'touch': 0.5833333333333334,
#  'summon': 1.0,
#  'moos': 1.0,
#  'maldiv': 0.0,
#  'logic': 1.0,
#  'yellow': 1.0,
#  'ihop': 0.0,
#  'cali': 0.0,
#  'denmark': 0.5,
#  '344': 0.0,
#  '┓': 1.0,
#  'billion': 0.5,
#  'reabsorbt': 0.0,
#  'pre-season': 0.0,
#  'prey': 0.0,
#  'kiss': 0.42857142857142855,
#  'mel': 0.0,
#  'reassur': 1.0,
#  'turn': 0.5,
#  'ferdou': 0.0,
#  'dayofarch': 1.0,
#  'ciao': 0.0,
#  'girlfriend': 0.6,
#  'lead': 0.5,
#  'bohat': 0.0,
#  'smh': 0.3333333333333333,
#  'explan': 1.0,
#  'ganteng': 0.5,
#  'newwin': 0.0,
#  'housemus': 1.0,
#  'andr': 1.0,
#  'rude': 0.2727272727272727,
#  'shorter': 0.5,
#  '💔': 0.0,
#  'boii': 1.0,
#  'llaollao': 0.0,
#  'boner': 0.0,
#  'jess': 0.5,
#  'burek': 1.0,
#  'overwhelmingli': 1.0,
#  'rape': 1.0,
#  'disvirgin': 0.0,
#  'sjw': 1.0,
#  'eatmeat': 1.0,
#  'bollywood': 0.5,
#  'upset': 0.09090909090909091,
#  'goddamn': 0.0,
#  ';-)': 1.0,
#  'theyr': 0.0,
#  'nightmar': 0.0,
#  'secondari': 0.0,
#  'junior': 1.0,
#  "when'": 0.0,
#  'issu': 0.4666666666666667,
#  'prinsesa': 1.0,
#  'fcking': 0.0,
#  'exit': 0.0,
#  "sculptor'": 1.0,
#  'looov': 1.0,
#  'replenish': 1.0,
#  'messi': 0.0,
#  'elhaida': 0.0,
#  'numbero': 1.0,
#  'powi': 1.0,
#  'gfriend': 0.0,
#  'chuckl': 1.0,
#  '100': 0.5,
#  'netherland': 0.0,
#  'corey': 0.0,
#  'acheb': 1.0,
#  'promot': 0.5,
#  'discuss': 0.6666666666666666,
#  'imsorri': 0.0,
#  'rodder': 1.0,
#  'trespass': 0.0,
#  'saran': 1.0,
#  'goodi': 0.0,
#  'jokid': 0.0,
#  'swore': 1.0,
#  'he': 0.3333333333333333,
#  'pinkeu': 1.0,
#  'papertown': 0.0,
#  '°': 1.0,
#  'bahari': 1.0,
#  'south': 1.0,
#  '🎵': 1.0,
#  'foundat': 0.0,
#  'fish': 0.6,
#  '26th': 0.0,
#  'non-trial': 0.0,
#  'ep': 0.5,
#  'save': 0.5833333333333334,
#  "urie'": 0.0,
#  'cornish': 1.0,
#  '221b': 0.0,
#  'leia': 1.0,
#  'noe': 1.0,
#  'theoper': 1.0,
#  'teacher': 0.3333333333333333,
#  'grill': 1.0,
#  'eye': 0.5217391304347826,
#  'stackar': 0.0,
#  'combat': 0.0,
#  'krystoria': 0.0,
#  'pakistan': 0.5,
#  'ovh': 1.0,
#  'mouth': 0.16666666666666666,
#  'vomit': 0.0,
#  'assia': 1.0,
#  'anniversari': 0.75,
#  'lotsa': 1.0,
#  'iirc': 1.0,
#  'narrow': 1.0,
#  'heyyy': 0.0,
#  'startupph': 1.0,
#  'gondooo': 1.0,
#  'entertain': 0.0,
#  'pic': 0.6,
#  'tio': 1.0,
#  'hhahahahaha': 1.0,
#  'resto': 1.0,
#  'complaint': 0.0,
#  'bhook': 0.0,
#  'instamood': 1.0,
#  'chan': 1.0,
#  'pll': 0.0,
#  'rotat': 1.0,
#  'taught': 1.0,
#  'ko': 0.2727272727272727,
#  'hash': 1.0,
#  'pier': 0.0,
#  'educ': 0.3333333333333333,
#  'himseek': 0.0,
#  'matthew': 0.5,
#  'slow': 0.2,
#  'sinc': 0.25,
#  'ventur': 1.0,
#  'movnat': 0.0,
#  '3:03': 0.0,
#  'brad': 0.0,
#  'phrase': 0.0,
#  'cinepambata': 1.0,
#  'ireland': 0.5,
#  'uk': 0.4,
#  'viciou': 0.0,
#  'ripsandrabland': 0.0,
#  'hawako': 0.0,
#  'hse': 0.0,
#  'zaz': 0.0,
#  'reynold': 0.0,
#  'puddl': 0.0,
#  'gandhi': 1.0,
#  'nicki': 0.0,
#  'respons': 0.75,
#  'meydan': 0.0,
#  'méxico': 0.5,
#  'narco': 0.0,
#  'nae': 0.0,
#  'enix': 1.0,
#  'wayanad': 1.0,
#  'airport': 0.2222222222222222,
#  'chswiyfxcskcalum': 0.0,
#  '10/10': 1.0,
#  'sept': 0.5,
#  's2': 0.0,
#  'jonginuh': 1.0,
#  'comput': 0.4444444444444444,
#  'soamaz': 1.0,
#  'stadium': 0.0,
#  'vincent': 1.0,
#  "kyungsoo'": 1.0,
#  'xma': 1.0,
#  'sobrang': 0.0,
#  'bdayt': 1.0,
#  'ang': 0.2857142857142857,
#  '5so': 0.4166666666666667,
#  'poldi': 1.0,
#  '4:13': 1.0,
#  'skill': 1.0,
#  'dealsuthaonotebachao': 1.0,
#  'mart': 0.0,
#  'budg': 0.0,
#  'reaalli': 0.0,
#  'pricelessantiqu': 1.0,
#  'sugarrush': 1.0,
#  'joselito': 1.0,
#  'everyday': 0.16666666666666666,
#  'womad': 0.5,
#  'crumbl': 0.0,
#  'chickmt': 0.0,
#  'ctto': 0.0,
#  'competit': 0.5,
#  'disc': 0.5,
#  'specially-mark': 1.0,
#  'manzano': 0.0,
#  'tommi': 0.0,
#  'text': 0.48,
#  'expect': 0.42857142857142855,
#  'cinema': 0.0,
#  'undercoverboss': 0.0,
#  'woman': 0.42857142857142855,
#  "shamuon'": 0.0,
#  'campu': 1.0,
#  'haizzz': 0.0,
#  'boreddd': 0.0,
#  'daze': 0.0,
#  'creas': 0.0,
#  'clonmel': 1.0,
#  'rob': 0.5,
#  'wing': 0.25,
#  'x15': 0.027777777777777776,
#  'alma': 1.0,
#  '💛': 0.0,
#  'emyu': 0.0,
#  'edwin': 1.0,
#  'confetti': 0.0,
#  '😕': 0.0,
#  'comfort': 0.5,
#  'walkersmithway': 1.0,
#  'tama': 0.0,
#  'long': 0.45,
#  'imposs': 0.0,
#  'digit': 0.0,
#  'taknottem': 0.0,
#  'accid': 0.0,
#  'engin': 1.0,
#  '339': 0.0,
#  'obv': 1.0,
#  'lafayett': 0.0,
#  'bailey': 1.0,
#  'nicest': 0.0,
#  'sighsss': 0.0,
#  'liter': 0.2777777777777778,
#  'mubarik': 1.0,
#  'nearest': 0.5,
#  'wrocilam': 0.0,
#  'yaya': 1.0,
#  'pet': 0.5,
#  'midnight': 0.5,
#  'workshop': 0.6666666666666666,
#  'camara': 0.0,
#  'forehead': 0.0,
#  'familiar': 0.6666666666666666,
#  'vicki': 0.0,
#  'pech': 1.0,
#  'etienn': 0.0,
#  'charg': 0.4,
#  'surreal': 1.0,
#  'jim': 0.5,
#  'satyajit': 1.0,
#  'pubcast': 1.0,
#  'bottl': 0.5,
#  'capee': 0.0,
#  'pta': 1.0,
#  'briefli': 0.0,
#  '•': 1.0,
#  'dey': 0.0,
#  'decemb': 0.5,
#  '24': 0.25,
#  'zareen': 1.0,
#  'lush': 0.0,
#  'fall': 0.2777777777777778,
#  '2015kenya': 1.0,
#  "mom'": 0.0,
#  'hain': 0.5,
#  'youll': 1.0,
#  'naa': 0.0,
#  'untruth': 0.0,
#  'muahhh': 1.0,
#  'fuckin': 0.0,
#  'liceooo': 0.0,
#  'wkwkw': 0.0,
#  'mumma': 0.0,
#  '😢': 0.0,
#  'nagsend': 1.0,
#  'mych': 0.0,
#  'ooop': 0.0,
#  '9:25': 1.0,
#  '190cr': 1.0,
#  'addm': 1.0,
#  'boob': 0.3333333333333333,
#  'pic.twitter.com/jxz2lbv6o': 1.0,
#  'divinediscont': 1.0,
#  'jet': 0.0,
#  'buckl': 0.0,
#  'stomachach': 0.0,
#  'breakfast': 0.5,
#  'swell': 0.0,
#  'georg': 0.0,
#  'som': 0.5,
#  'achiev': 0.6666666666666666,
#  'rap': 0.0,
#  'gud': 1.0,
#  'ebook': 0.0,
#  'grepe': 0.0,
#  'eyelid': 0.0,
#  'hong': 0.5,
#  'galat': 0.0,
#  'wrack': 0.0,
#  'feminist': 1.0,
#  'tkt': 1.0,
#  'cherish': 1.0,
#  'lega': 1.0,
#  'taft': 1.0,
#  'utd': 0.0,
#  'suriya': 0.0,
#  'peter': 0.5,
#  'number': 0.6875,
#  'x7': 1.0,
#  'cyclerevolut': 0.0,
#  'pero': 0.0,
#  'a9': 0.0,
#  'monthli': 0.5,
#  'batalladelosgallo': 0.0,
#  'sleep': 0.330188679245283,
#  'ka': 0.5,
#  'button': 1.0,
#  'socialmedia@dpdgroup.co.uk': 1.0,
#  'abligaverin': 0.0,
#  'thek': 1.0,
#  'natur': 1.0,
#  'describ': 0.0,
#  'paint': 0.5714285714285714,
#  '64': 1.0,
#  'finnigan': 1.0,
#  'juli': 0.4782608695652174,
#  'rita': 1.0,
#  'sarajevo': 0.0,
#  'multiraci': 1.0,
#  'selamat': 1.0,
#  'roux': 1.0,
#  'umaga': 1.0,
#  'came': 0.30434782608695654,
#  'arnd': 1.0,
#  'wider': 0.0,
#  'ht': 1.0,
#  'saddest': 0.0,
#  'junjou': 0.0,
#  'pledg': 0.0,
#  'macci': 0.0,
#  'warn': 0.0,
#  'yaa': 1.0,
#  'uuu': 0.5,
#  'ykr': 1.0,
#  'houston': 1.0,
#  'photoshooot': 0.0,
#  'atchya': 1.0,
#  'despit': 0.5,
#  'whattsap': 0.0,
#  'max': 0.3333333333333333,
#  '1900': 0.0,
#  'everybodi': 0.2,
#  'ghantay': 0.0,
#  '626-430-8715': 0.0,
#  'pl': 0.2,
#  'sarah': 1.0,
#  'enrol': 0.0,
#  'cjradacomateada': 1.0,
#  'iger': 1.0,
#  'bulli': 0.0,
#  'rettweet': 1.0,
#  'yeahh': 0.5,
#  'criticis': 1.0,
#  'real': 0.5142857142857142,
#  'dev': 0.0,
#  'carmel': 1.0,
#  'els': 0.6666666666666666,
#  'lunch': 0.2727272727272727,
#  'ging': 0.0,
#  'garden': 0.7142857142857143,
#  'cod': 0.0,
#  'nth': 0.5,
#  'collin': 0.0,
#  'niend': 0.0,
#  '9dg': 1.0,
#  'noon': 0.0,
#  'ehdar': 0.0,
#  'riski': 0.0,
#  'gorgeou': 0.9,
#  't-shirt': 1.0,
#  'opt': 0.0,
#  'wentz': 0.0,
#  'dang': 0.3333333333333333,
#  'trendi': 1.0,
#  'pixel': 0.0,
#  'pack': 0.5384615384615384,
#  'gorefiend': 1.0,
#  'offroad': 0.0,
#  'ledger': 0.0,
#  'mustread': 1.0,
#  'halfway': 1.0,
#  'x16': 1.0,
#  'fyi': 0.0,
#  'iyalaya': 0.0,
#  'finddjderek': 0.0,
#  'yael': 1.0,
#  'jungl': 1.0,
#  '89.9': 1.0,
#  'boy': 0.5652173913043478,
#  'shane': 0.0,
#  'hbd': 0.5,
#  'singl': 0.6666666666666666,
#  'goalscor': 0.0,
#  'boi': 1.0,
#  ':-(': 0.0,
#  'gh': 0.0,
#  'river': 1.0,
#  'ensur': 1.0,
#  'feetblog': 1.0,
#  'jillcruz': 0.0,
#  'sadli': 0.09090909090909091,
#  'four': 0.625,
#  'khani': 0.0,
#  'amiibo': 0.0,
#  'exec': 1.0,
#  'wat': 0.25,
#  'thatscold': 0.0,
#  'reader': 1.0,
#  'pip': 0.0,
#  'lowbat': 0.0,
#  'tomcat': 0.0,
#  'loveyaaah': 1.0,
#  'financi': 0.0,
#  '02079': 1.0,
#  'tgk': 0.0,
#  'gain': 1.0,
#  'environ': 1.0,
#  'prettiest': 1.0,
#  'woza': 0.0,
#  'kansai': 1.0,
#  'lusi': 0.0,
#  'via': 0.9836065573770492,
#  'noodl': 0.0,
#  'joke': 0.25,
#  'homebound': 1.0,
#  'comic': 0.25,
#  'lmao': 0.16666666666666666,
#  'backkk': 0.0,
#  'hall': 0.5,
#  'subj': 0.0,
#  'version': 0.6666666666666666,
#  'trop': 0.0,
#  'timw': 0.0,
#  'ngeze': 0.0,
#  'males': 1.0,
#  '07:24': 0.0,
#  'nyquil': 0.0,
#  'threaten': 0.3333333333333333,
#  '💃': 0.75,
#  'fruiti': 1.0,
#  'minc': 0.0,
#  'halla': 1.0,
#  'msc': 0.0,
#  '6g': 0.0,
#  '13': 0.7142857142857143,
#  '200': 1.0,
#  "i'm": 0.3448275862068966,
#  'bang': 0.0,
#  'kink': 0.0,
#  'belat': 0.75,
#  'zayniscomingback': 0.0,
#  'dine': 1.0,
#  'munchkin': 0.5,
#  "michael'": 0.0,
#  '💞': 0.3333333333333333,
#  'rofl': 1.0,
#  'aragalang': 0.0,
#  '💓': 1.0,
#  'subdivis': 0.0,
#  'marshmallow': 0.0,
#  'seen': 0.2857142857142857,
#  'boss': 0.0,
#  'dandia': 0.0,
#  'prexi': 0.0,
#  'groupi': 1.0,
#  'ingat': 1.0,
#  'dosent': 0.0,
#  'mysumm': 1.0,
#  'wordoftheweek': 1.0,
#  'hopeless': 0.0,
#  'done': 0.6896551724137931,
#  'arummzz': 1.0,
#  'x34': 1.0,
#  'chain': 0.5,
#  'televot': 0.0,
#  '¦': 1.0,
#  '2017': 0.5,
#  'affect': 0.6666666666666666,
#  'baek': 0.0,
#  'philea': 1.0,
#  'v.ball': 1.0,
#  'hardcor': 1.0,
#  'imagin': 0.8333333333333334,
#  'lession': 1.0,
#  'super-blend': 1.0,
#  'war': 0.0,
#  'sholong': 0.0,
#  'heathrow': 0.0,
#  'pant': 0.3333333333333333,
#  'renew': 1.0,
#  'gobigorgohom': 1.0,
#  'nag.greet': 1.0,
#  'yeeeah': 1.0,
#  'exploit': 1.0,
#  '30th': 0.5,
#  'confisc': 0.0,
#  'shoeshi': 1.0,
#  'himmat': 1.0,
#  'funni': 0.7894736842105263,
#  'unmarri': 0.5,
#  'gi-guilti': 0.0,
#  'improv': 1.0,
#  'ivan': 0.0,
#  'might': 0.6774193548387096,
#  'bout': 0.5,
#  'longest': 0.0,
#  'similar': 0.0,
#  '27juli': 1.0,
#  'rosh': 1.0,
#  'onkey': 1.0,
#  'slowli': 0.0,
#  'audit': 0.0,
#  'hauc': 1.0,
#  'prada': 0.0,
#  'spot': 0.4,
#  'ramzan': 0.0,
#  'trish': 1.0,
#  'optimis': 0.0,
#  'screenshot': 0.3333333333333333,
#  'foof': 0.0,
#  'dit': 0.0,
#  'diz': 0.0,
#  'harmo': 1.0,
#  'axio': 1.0,
#  '319': 0.0,
#  'eyyah': 0.0,
#  'diarrhea': 1.0,
#  'journal': 1.0,
#  'daft': 0.5,
#  'poc': 0.0,
#  'tagsforlikesapp': 1.0,
#  'slipper': 0.0,
#  'raiz': 0.0,
#  'tire': 0.11904761904761904,
#  'delv': 1.0,
#  'arr': 1.0,
#  'fade': 1.0,
#  '510': 0.0,
#  'bv': 0.0,
#  'erica': 0.0,
#  'sharethelov': 1.0,
#  'gee': 0.0,
#  'nonexist': 0.0,
#  'yeaaah': 1.0,
#  'worldwid': 1.0,
#  'cheung': 1.0,
#  'somewher': 0.5,
#  'nw': 0.0,
#  '0.001': 0.0,
#  'tame': 1.0,
#  'subject': 1.0,
#  'explain': 1.0,
#  'solo': 0.4,
#  'shinsengumi': 0.0,
#  'indo': 1.0,
#  'section': 0.6666666666666666,
#  'press': 1.0,
#  'ee': 0.0,
#  'fron': 1.0,
#  'gishwh': 0.0,
#  '1/5': 0.5,
#  'pusher': 1.0,
#  'um': 1.0,
#  'rewatch': 0.0,
#  'uca': 0.0,
#  'way': 0.5230769230769231,
#  'haw': 1.0,
#  'grotti': 0.0,
#  'gift': 0.4375,
#  'mia': 0.5,
#  'helen': 1.0,
#  '…': 0.6888888888888889,
#  'prami': 0.0,
#  'fugli': 0.0,
#  'arini': 0.0,
#  'sweetest': 0.5,
#  'chronic': 1.0,
#  'carriageway': 0.0,
#  'charad': 0.0,
#  'toll': 0.0,
#  'assum': 0.0,
#  'quad': 1.0,
#  'could': 0.32894736842105265,
#  'dia': 0.3333333333333333,
#  'blackberri': 0.0,
#  'frequent': 0.0,
#  'newest': 1.0,
#  'power': 0.5454545454545454,
#  'z': 0.0,
#  'dd': 0.5,
#  '10:59': 0.0,
#  'olymp': 0.0,
#  'instal': 0.5,
#  'dew': 1.0,
#  ';}': 1.0,
#  'cuddl': 0.14285714285714285,
#  'stroke': 1.0,
#  'loud': 0.0,
#  'pfb': 0.5,
#  'wolv': 1.0,
#  "yesterday'": 0.5,
#  'sunggyu': 0.0,
#  'netfilx': 1.0,
#  'scam': 1.0,
#  'xfile': 1.0,
#  'distanc': 0.5,
#  '346': 0.0,
#  'rizal': 0.0,
#  ...}

# %%
pos_values = []
for i in test_pos:
    val = check(i)
    pos_values.append(val)
# Out:
# ['bro', 'u', 'wan', 'cut', 'hair', 'anot', 'ur', 'hair', 'long', 'liao', 'bo', 'sinc', 'ord', 'liao', 'take', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', ':)', 'bro', 'lol', 'sibei', 'xialan']
# 0.491346383781463
# ['back', 'thnx', 'god', "i'm", 'happi', ':)']
# 0.6153863338241786
# ['thought', 'ear', 'malfunct', 'thank', 'good', 'clear', 'one', 'apolog', ':-)']
# 0.6680242280845263
# ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', '...', ':)']
# 0.42509515743363446
# ['happi', 'friday', ':-)']
# 0.9364804469273743
# ['follow', ':)', 'x']
# 0.717712043431693
# ['teenchoic', 'choiceinternationalartist', 'superjunior', 'fight', 'oppa', ':D']
# 0.673611111111111
# ['birthday', 'today', 'birthday', 'wish', 'hope', "there'", 'good', 'news', 'ben', 'soon', ':-)']
# 0.5791146550619642
# ['good', 'morn', ':-)', 'friday', '\U000fec00', 'plan', 'day', 'current', 'play', 'shop', '...']
# 0.6519556093022684
# ['happi', 'friday', ':)']
# 0.9362464466933741
# ['3', 'good', 'nigth', ':)', 'estoy', 'escuchando', 'enemi', 'god']
# 0.6463796450830642
# ['actual', 'bye', 'bye', 'inde', 'go', 'take', 'drama', 'elsewher', ':)']
# 0.5720845103004075
# ['ff', 'readi', 'weekend', ':)', 'smile']
# 0.8402508962107703
# ['work', ':)']
# 0.7312279470174208
# [':)', 'mood', 'bipolar']
# 0.7497659997659998
# ['thank', ':)']
# 0.9210536819232471
# ['hahahahahahahahahahahahahaha', 'die', ':)', 'liter', 'front', 'like']
# 0.49416837751938497
# ['yoohoo', 'shatter', 'record', 'bajrangibhaijaanstorm', 'superhappi', ':D']
# 0.6785714285714285
# ["who'", 'awak', ':-)']
# 0.6794871794871794
# ['happi', 'friday', ':-)']
# 0.9364804469273743
# ['pleasur', 'doll', 'thank', 'wonder', 'energi', 'class', ':)']
# 0.5994393739735354
# ['f', ':)']
# 0.49964899964899967
# ['delight', "m'dear", ':)']
# 0.7664326664326664
# ['hi', 'emma', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# 0.7696886446886447
# ['followback', 'beauti', 'girl', 'today', ':)']
# 0.6623465382086072
# ['lyka', 'followback', ':)']
# 0.7775437775437775
# ['alrd', 'joy', ':)']
# 0.6997659997659998
# ['ourdaughtersourprid', 'dhan', 'dhan', 'satguru', 'tera', 'hi', 'aasra', '...', 'mani', 'congratul', 'pita', 'g', '...', 'keep', 'bless', 'alway', ':-)']
# 0.6248921156225787
# ['thank', 'ye', "let'", 'hope', 'work', 'miss', ':-)']
# 0.6331936691390564
# ['keeo', 'guess', 'what', 'behind', 'white', 'cover', ':)', 'special', '..', 'happi', 'bday', 'darl', '…']
# 0.5937998700568533
# ['happi', 'friday', 'everyon', ':)', 'big', 'followfriday']
# 0.8561102363337
# ['awkward', 'moment', 'name', 'akarshan', 'end', 'stay', 'singl', ':D', 'foreveralon']
# 0.6482844750955643
# ['know', ':)', 'hot', 'alway']
# 0.6776730755366438
# ['worri', ':)', 'know', 'much', 'stress', 'problem', 'site', "can't", 'wait', 'till', 'event']
# 0.6099509998333059
# ['say', 'sweetpea', 'start', 'hold', 'regular', 'gluten', 'free', 'cake', 'pastri', 'workshop', ':)']
# 0.5695531727789793
# ['highfiv', 'probabl', 'ahead', 'sinc', 'less', 'artsi', 'verbal', ':D']
# 0.5256410256410255
# ['bae', ':)', '<3']
# 0.7414160771825006
# ['kid', 'kaaa', ':p']
# 0.6494252873563219
# ['love', 'chat', 'cycl', 'oxford', 'campaign', 'way', 'home', 'yesterday', 'cycl', 'rout', 'pleas', ':)', 'cycl', 'oxford']
# 0.5730370071651775
# ['wahoo', 'team', ':-)', 'masaantoday']
# 0.7871621621621622
# ['anchor', 'sea', '..', ':)']
# 0.6320996320996322
# ['dat', 'rp', 'tho', 'thank', 'much', 'guy', 'celebr', 'one', 'month', 'partnership', 'ty', 'raid', ':D']
# 0.5535576558837808
# ['visit', 'robbenisland', 'cultur', 'experi', 'tri', 'whale', 'watch', 'aquat', 'safari', 'either', 'great', ':)']
# 0.6306849023353042
# ['least', 'friday', ':D']
# 0.8095061728395061
# ['mayb', 'garru', 'liara', 'rest', 'crew', ':D']
# 0.6363960113960114
# ['thank', 'follow', 'great', 'day', ':)']
# 0.785660303651618
# ['massag', 'appoint', 'avail', 'tomorrow', 'morn', 'burnley', 'give', 'us', 'call', 'book', ':)', '01282', '453', '110']
# 0.5504442604267779
# ['great', 'hear', 'nice', 'day', 'thank', 'visit', ':)']
# 0.7659402995448282
# ['bore', 'everyth', ':D']
# 0.5674603174603174
# ['drama', 'korea', '49', 'day', ':)']
# 0.7574454248872853
# ['btw', 'anyon', 'repres', 'footbal', 'manag', 'commun', 'youtub', ':)', 'fm15', 'fmfamili', 'vidcon', '2015']
# 0.5346695578313225
# ['mean', 'aamir', 'khan', 'one', ':)']
# 0.6123333629780408
# ['happi', 'friday', ':)']
# 0.9362464466933741
# ['right', 'back', 'excel', 'job', 'difficult', 'medium', ':)']
# 0.6028667178841702
# [':)', 'want', 'ff']
# 0.7266808172319984
# ['tweet', ':p']
# 0.8133333333333334
# []
# nan
# ['pleas', 'follow', 'liam', ':)']
# 0.6614780470216541
# ['love', 'write', ':)', 'absolut', 'ador', 'nva', 'lucki', 'enough', 'live', '5', 'minuet', 'away', 'roll', 'gamec']
# 0.555276515654133
# ['ff', 'thank', 'brian', ':)']
# 0.9377995682343508
# ['headrest', 'loos', "that'", 'reason', 'pit', ':-)']
# 0.575281151596941
# ['hi', "i'v", 'spoken', 'store', 'advis', 'paypoint', 'card', 'top', ':)', 'thank', 'beth']
# 0.6326942069891841
# ['thank', 'help', ':-)']
# 0.7665331626684283
# ['deepthroat', 'good', 'movi', ':)']
# 0.6740945728172005
# ['hallo', 'twitter', ':D']
# 0.8518518518518517
# ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# 0.40691281343455254
# ['thank', 'wish', ':)']
# 0.7191082517169475
# ['aitor', 'sn', 'would', 'mind', 'check', 'bio', 'particip', 'ps4', 'giveaway', 'could', 'winner', ':)']
# 0.6253356854720914
# ['hi', 'jawad', 'today', 'thank', 'follow', 'retweet', 'much', 'appreci', ':)']
# 0.7112252192614493
# ['thank', ':)']
# 0.9210536819232471
# ['actual', 'need', 'stop', 'tweet', 'drive', ':-)']
# 0.5223883623883624
# ['kind', 'feedback', 'truli', 'made', 'day', 'perfect', 'way', 'end', 'work', 'week', ':)']
# 0.5854464715632012
# ['well', "that'", 'presal', 'ticket', 'bought', 'thank', 'wonder', 'take', 'book', '...', 'thing', 'parent', ':)']
# 0.5540378507872007
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# 0.8076972188276119
# ['hope', 'goe', 'well', ':-)']
# 0.656958653026428
# ['betcha', ':)', 'dumb', 'butt', ':)']
# 0.6997191997191997
# ['kik', 'qualki', '808', 'kik', 'kikmenow', 'milf', 'like', '4like', 'bore', 'summer', 'sexysaturday', ':)']
# 0.37568382198578004
# ['follow', ':-)']
# 0.7828014184397163
# ['thank', ':)']
# 0.9210536819232471
# ['ye', 'hun', "i'm", 'good', ':)']
# 0.609453296707261
# ['enjoy', ':)']
# 0.9449614996489997
# ['wow', 'vw', 'bu', 'lot', 'umpfff', 'love', ':)']
# 0.6739343198175006
# ['ca', 'retweet', 'domg', 'nanti', 'difollow', ':D']
# 0.638888888888889
# ['wish', ':D', ':D', ':D', ':D', ':D', ':D', ':D', 'kid']
# 0.8626103614859236
# ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 0.534260455593569
# ['ye', 'car', ':)']
# 0.6392862017862018
# ['like', 'especi', 'klee', 'one', ':-)']
# 0.608311535289266
# ['look', 'amaz', 'april', 'love', 'glass', ':D']
# 0.6962516784562357
# ['know', ':)']
# 0.760518564866391
# ['build', 'hous', ':)']
# 0.6978052154522744
# ['yeah', 'kinda', 'feel', 'like', 'warm', 'butter', ':D']
# 0.5446271691916291
# ['realli', 'week', 'big', 'decis', 'feel', 'rather', 'badass', ':)']
# 0.6512160545393633
# ["i'm", 'go', 'sleep', 'hope', 'wake', 'follow', 'luke', 'hem', 'someday', ':)', 'goodnight', 'fam', 'ili', '5so', 'lot', '💟']
# 0.6213203345742555
# ['congrad', 'better', 'updat', 'page', 'accomplish', ':-)', 'keep', '...']
# 0.6135784900299674
# ['film', 'day', 'invit', 'reason', 'lol', ':)']
# 0.789147693951565
# [':)']
# 0.9992979992979993
# ['whenev', 'sister', 'see', 'cri', 'text', 'ask', 'im', 'okay', 'aw', 'someon', 'care', ':-)']
# 0.4578801684296245
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# 0.7540555134569965
# ['t-shirt', ':D', 'awesom']
# 0.9583333333333334
# ['belat', '..', 'thank', 'thank', ':D']
# 0.7929438516395038
# ["can't", 'wait', 'see', ':-)']
# 0.5943949904843759
# ['happi', 'happi', 'birthday', 'happi', 'happi', 'birthday', ':)']
# 0.8761850352120659
# ['take', 'care', ':)']
# 0.6423530644426166
# ['road', 'trip', 'tregaron', 'view', 'potenti', 'new', 'boar', 'finger', 'cross', 'bring', 'boy', 'home', ':)']
# 0.6040273368648654
# [':)', 'good', 'know', ':)']
# 0.804353855250396
# ['told', 'im', 'gorgeou', 'extrem', 'sweati', 'walk', 'work', 'made', 'day', ':)']
# 0.5820752429411818
# ['morn', 'em', ':)']
# 0.8044058044058043
# ['glyon', ':D']
# 0.75
# ['💓', '🚮', '👯', 'definit', 'perfect', 'would', 'pictur', 'next', ':)']
# 0.7494547622131763
# ['initi', "tee'", 'pm', 'order', ':)']
# 0.5655006255006254
# ['confess', ':)', 'nice']
# 0.9346319001491415
# ['welcom', ':)']
# 0.9572761182930675
# ['nice', 'dave', ':D']
# 0.9348659003831418
# ['know', 'dumb', 'think', 'johnni', 'rock', 'u', 'seen', 'utub', "video'", 'mad', 'respect', ':D']
# 0.49507942054999315
# ['sorri', 'loss', 'hope', 'goe', 'well', ':)']
# 0.4545221019006185
# ['combin', 'three', 'add', 'bit', 'asian', 'u', 'got', 'truli', ':)']
# 0.5323285919104734
# ['happi', 'birthday', ':)']
# 0.8889517607030358
# ['got', 'call', 'end', 'pigeon', 'home', 'safe', ':)', 'definit', 'worth', 'contact']
# 0.4947066500637929
# ['morn', 'hospit', 'day', 'today', 'hope', 'final', 'get', 'sign', 'long', 'year', 'pain', 'op', 'fingerscross', ':)']
# 0.5469591712447361
# ['best', 'photobomb', ':D', 'pic', '—']
# 0.6807692307692308
# ['thank', 'se', ':)']
# 0.8362580101710536
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# 0.8076972188276119
# ['finish', 'day', '33', 'plan', 'bibl', '90', 'day', 'check', '2', 'chronicl', '23', 'complet', ':)']
# 0.6801713640632929
# ['yo', 'gimm', 'month', 'free', 'bill', 'sinc', 'servic', 'pretti', 'much', 'everi', 'day', ':)']
# 0.54897338020972
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8281468258017921
# ['hi', "i'm", 'definetli', 'exit', "i'm", 'go', 'new', 'york', ':)']
# 0.5727285927767082
# ['saturday', ':)']
# 0.6663156663156663
# ["i'v", 'type', 'wors', 'thing', 'good', ':p']
# 0.5384086159746374
# ['beat', 'da', 'beat', 'sit', 'well', 'includ', 'new', 'video', ':-)']
# 0.7127007529699041
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# 0.6930006049606776
# ['thank', ':)', '💕']
# 0.8362580101710536
# ['soon', '...', ':)']
# 0.6441499938552984
# ['sure', ':)']
# 0.7932997932997934
# ['look', 'fun', 'kik', 'thencerest', '547', 'kik', 'kiksext', 'sex', 'followback', 'l4l', 'indiemus', 'kikgirl', ':)']
# 0.5754341661190281
# ['goodnight', 'guy', ':-)', 'rememb', 'tomorrow', 'brand', 'new', 'day', 'fresh', 'start', 'anoth', 'chanc']
# 0.6391676041287943
# ['bom-dia', ':)', 'apod', 'ultraviolet', 'ring', 'm31', '2015', 'jul', '24']
# 0.560107185107185
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# 0.6930006049606776
# ['thank', 'follow', 'great', 'day', ':)']
# 0.785660303651618
# ['oooh', 'love', 'hope', 'fantast', 'time', ':)']
# 0.703633657234063
# ['yawn', 'good', 'morn', 'everyon', 'wag', 'tail', 'everyon', 'today', ':D']
# 0.7074619268175775
# ['congrat', 'launch', ':D']
# 0.8774509803921569
# ['happi', 'wonder', 'birthday', 'love', '💟', 'beauti', 'day', 'world', ':)']
# 0.7976175322832277
# ['ftw', ':)']
# 0.49964899964899967
# ['ah', 'see', 'song', 'prefer', 'take', 'maman', ':)']
# 0.5307258390778075
# ['hi', 'hayley', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# 0.9125457875457875
# ['gud', 'afterznoon', 'jumma', 'mubarak', 'tweeep', ':-)', 'plz', 'rememb', 'us', 'ur', 'prayer']
# 0.7231549364613882
# ['welcom', 'bomb', 'famili', ':)', 'x']
# 0.7222966365755391
# ['abp', 'news', 'ka', 'articl', 'read', 'kiya', ':D', 'bajrangibhaijaanhighestweek', '1']
# 0.640203104214025
# ['like', 'hurt', 'feel', 'anyth', 'right', ':)']
# 0.47097085171427283
# ['check', 'new', 'van', 'outsid', 'olymp', 'park', 'anniversari', 'game', ':)']
# 0.4639638736860959
# ['everi', 'year', 'august', 'get', 'fever', ':p', 'dunno', '😷']
# 0.5957648276701986
# ['yeah', 'classi', 'look', ':-)', "i'v", 'seen', 'peopl', 'attach', 'sort', 'life', 'save', 'equip', 'bed', 'fix', '0']
# 0.4768177834685126
# ['trend', '..', 'follow', 'bobbl', 'link', ':)']
# 0.5030406315867308
# ['next', 'year', 'sure', 'though', ':)', "there'", '2', 'girl', 'piss']
# 0.5450358517953977
# ['stand', 'cool', ':)']
# 0.7926952926952927
# ['movi', 'key', 'life', 'japanes', 'version']
# 0.504102564102564
# ['thank', 'anu', ':)']
# 0.780702454615498
# ['also', 'new', 'layout', 'new', ':)']
# 0.745949065949066
# ['im', 'tri', 'l', 'mh3', 'english', 'patch', 'psp', ':D']
# 0.4269441844635412
# ['want', 'tweet', 'someth', 'thought', "i'll", 'probabl', 'lose', 'lot', 'liam', 'girl', 'mutual', ':)']
# 0.5791446911653573
# ['1', 'day', 'go', '1', 'day', 'left', 'sponsor', 'us', 'matter', 'small', 'donat', 'differ', 'make', 'huge', ':)']
# 0.583398590704949
# ['thank', ':)']
# 0.9210536819232471
# ['follow', ':)']
# 0.782450418088716
# ['hey', 'emili', 'love', 'work', "i'd", 'like', 'contribut', 'huffpost', 'busi', "what'", 'best', 'way', 'contact', ':)']
# 0.6488807792763555
# ['asshol', '😂', "that'", 'honest', 'tribut', ':)']
# 0.6869590232748127
# ['h_eartshapedbox', 'first', 'leg', 'magictrikband', 'tour', 'go', 'well', ':D', 'music', 'band', 'rock', 'magictrik', 'tour', '…']
# 0.5463333136361447
# ['tower', 'ladi', ':)', 'tb', 'eid']
# 0.7731929331929333
# ['whatsapp', 'roommat', 'want', 'anyth', 'pari', 'french', 'man', ':)', 'lol', 'sure', "i'll", 'head', 'park', 'grab', 'one']
# 0.5377622584883958
# ['great', 'weekend', 'tami', 'thank', ':)']
# 0.7970677323862574
# ['love', ':-)']
# 0.8620689655172413
# ['want', 'look', 'good', ':)']
# 0.6369547671546105
# ['sure', ':)']
# 0.7932997932997934
# ['excit', 'weekend', ':-)']
# 0.8729674796747968
# ['b3dk', 'far', '7an', 'ank', 'mi', '15', ':)']
# 0.5665663808520952
# ['god', 'give', 'us', 'strength', 'purpos', 'help', 'other', 'struggl', ':-)']
# 0.5617744999984884
# ['lol', 'meant', 'lucki', 'eagl', 'thank', 'servic', 'oceana', ':-)']
# 0.6440198359027836
# ['woke', 'feel', 'incred', 'sick', 'idk', 'caus', 'drank', 'starbuck', '11', "o'clock", 'last', 'night', 'reaction', 'med', ':)']
# 0.4722531154848228
# ['oop', '...', "that'", 'call', 'fridayfauxpa', ':)', "i'll", 'get', 'chang', 'right', 'thank', 'g']
# 0.5847945282492789
# ['fulfil', 'fantasi', ':)', '👉']
# 0.9581578331578332
# ['call', 'night', 'go', 'sleep', ':)']
# 0.5808356366104125
# ['yeah', "they'r", 'give', 'subtl', 'hint', 'also', 'tip', '2', 'use', 'commun', 'last', 'year', ':-)', 'prim', '’', 'algorithm', 'iii']
# 0.5775139167722287
# ['funni', 'ye', 'soon', 'alway', 'go', 'soon', ':D']
# 0.6097949087108032
# ['thank', ':)', 'get', 'retweet', 'x']
# 0.747807662027611
# ['smile', 'receiv', 'text', 'dad', 'say', 'suck', ':)']
# 0.5712489205346348
# ['wat', ':)']
# 0.6246489996489997
# ["can't", 'wait', 'rosa', 'love', 'xma', ':)', 'welcom', 'back', 'ann', 'hope', 'u', 'good', 'one', 'back', 'time', ':)', 'x']
# 0.6157861793417648
# ['morn', 'tweep', 'new', 'post', 'today', 'pleas', 'like', 'share', 'see', 'thank', ':)']
# 0.64868908960416
# ['yvw', 'great', 'day', 'weekend', ':D']
# 0.7528987513113108
# ['awww', 'here', 'quick', 'workout', 'boost', ':-)']
# 0.6089605734767025
# ['lol', ':D', 'know', 'idea', ':p', 'coz', 'unforgett', 'sens', 'humor', ';)', ':)', ':D', 'love', 'bro']
# 0.7755958460702468
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8281468258017921
# ["mum'", 'home', '...', 'hahahhaah', 'thank', 'lord', ':)']
# 0.6165510909589543
# ['safe', ':D']
# 0.6875
# ['girl', ':)']
# 0.8329823329823329
# ['sombrero', 'high', 'okay', "i'm", 'lost', ':)']
# 0.4648939467904986
# ['hellooo', "i'm", 'rose', 'nice', 'meet', ':)']
# 0.7150649922201646
# ['thank', 'screenshot', 'po', 'let', 'take', 'care', 'spammer', ':)', 'proceed', 'c', '...']
# 0.5860819690023054
# ['perfect', 'thing', 'pick', ':)', 'wsalelov']
# 0.7364317995896943
# ['thank', 'amaz', 'job', ':)']
# 0.8563040197576703
# ['die', 'actual', 'pretti', 'entertain', ':p']
# 0.4655944754895279
# ['congrat', '100k', 'man', "can't", 'wait', 'till', 'hit', 'mileston', ':)']
# 0.6191353239332208
# ['morn', '...', 'judith', 'answer', 'district', 'council', 'relat', 'question', 'today', ':-)']
# 0.6004144782571041
# ['see', 'tomorrow', ':)']
# 0.7143858828069355
# ['saw', 'comment', 'midar', 'gender', 'unknown', 'like', ':)', 'yeah', 'keep', 'say']
# 0.5634386555677244
# ['wow', 'realli', 'hate', ':)']
# 0.5835687470302855
# ['watch', 'saw', 'dan', ':)']
# 0.6562443983384542
# ['thank', ':-)', 'ilysm', 'xx']
# 0.6325773411371237
# ['thank', 'trade', ':)']
# 0.7473691212821647
# ['look', 'forward', ':-)', 'ks']
# 0.8449468085106383
# ['lesley', ':)']
# 0.9996489996489997
# ['want', 'protect', 'relationship', 'other', "i'll", 'talk', 'ppl', 'need', 'know', 'awesom', ':)']
# 0.5366836827079214
# ['oh', 'dang', 'zen', 'look', 'outsid', 'space', 'neat', ':-)']
# 0.46831294722600963
# ['look', 'good', 'outfit', ':)']
# 0.6404699527564103
# ['hiya', "i'm", 'afraid', "we'v", 'alreadi', 'pick', 'rider', 'year', "we'll", 'look', 'next', 'year', ':)']
# 0.5257459333286876
# ['good', 'morn', 'u', ':)']
# 0.7293746585850912
# ['ha', 'ha', 'ok', 'honey', 'go', 'ahead', 'fyi', 'still', 'dig', 'ya', 'enjoy', 'vote', 'watch', 'side', ':)']
# 0.5484838742510912
# ['lucki', ':)']
# 0.6838595259647892
# ['learn', 'new', 'skill', 'take', 'time', 'perfect', 'master']
# 0.7391983382893493
# ['👱', '🏽', '👽', '🌳', '😂', '😂', '😂', "i'v", 'talk', 'u', 'coupl', 'time', 'u', 'seem', 'nice', 'funni', ':)']
# 0.5400737112911598
# ['agre', 'suspici', 'mind', ':)']
# 0.7571774410009704
# ['good', 'afternoon', ':)']
# 0.8247186896821933
# ['whoop', 'whoop', 'bring', 'fun', ':)']
# 0.8583211383211383
# ['new', 'report', 'talk', 'burn', 'calori', 'cold', 'work', 'harder', 'warm', 'feel', 'better', 'weather', ':p']
# 0.41338437431625247
# ['say', 'someth', "i'm", 'give', ':)', "i'm", 'sorri', 'get', ':D']
# 0.5438074645970699
# ['good', 'night', ':)']
# 0.7737927637562674
# ["there'", 'gonna', 'anoth', 'one', 'final', ':)']
# 0.4883261102940737
# ['welcom', 'jessica', 'enjoy', ':)']
# 0.8262943091465338
# ['best', 'friend', 'carina', 'one', 'san', 'francisco', 'let', 'know', 'want', 'get', 'touch', ':)']
# 0.5493753554370637
# ['thank', 'mommi', 'teret', ':)', ':)', 'potassium', 'rehydr', 'drinkitallup', 'thirstquench']
# 0.6212672625716105
# ["i'm", 'sure', 'tapir', 'calf', 'one', 'like', 'adventur', 'mealtim', ':)']
# 0.5747760943614236
# ['uhc', 'box', 'larg', 'scale', 'one', 'network', 'server', ':p']
# 0.43381211180124224
# ['ever', 'areal', "we'll", 'lunch', 'dinner', ':)']
# 0.5784183534183535
# ["here'", 'one', 'extremesport', 'fan', 'among', 'love', 'quadbik', 'get', 'touch', ':)', 'bloggersrequir', 'bloggersw']
# 0.626628814179118
# ['thank', '...', 'love', 'cake', ':)', 'bear', 'hug', 'end']
# 0.573492572385629
# ['masa', 'nowaday', 'brainer', 'type', 'invest', 'list', 'mse', 'fund', ':)']
# 0.7076143076143077
# ['magnific', ':-)']
# 1.0
# ['love', 'work', 'tokyo', ':)', 'kunoriforceo', 'ceo', '1month']
# 0.8123705464384748
# ['yeah', 'tri', 'look', 'x', ':)']
# 0.599684841277593
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# 0.7540555134569965
# [':)', 'hehe', 'get', 'think', 'mean', 'need', 'sleep', 'nooowww', 'nite', 'nite', ':)']
# 0.6799294137335237
# ['hi', '5', 'back', ':)', ':)']
# 0.7703810959624913
# ['ye', 'omg', 'lile', 'tid', 'tmi', ':)']
# 0.5530788932428277
# ['may', 'deploy', 'degre', 'sarcasm', ':)']
# 0.7030854063112127
# ['cute', 'boy', 'jule', ':-)']
# 0.6068215892053973
# ["can't", 'wait', 'week', ':D']
# 0.5956554946860566
# ['thank', 'follow', 'us', 'betti', 'miller', 'new', 'friend', 'alway', 'welcom', ':)']
# 0.734904319796379
# ['person', 'small', 'thing', 'u', 'expect', 'person', 'u', 'love', ':)']
# 0.5264806876805755
# ['ye', 'hddc', 'also', 'favourit', ':)', 'salman', 'khan', 'movi', 'etern', 'case', 'watch', 'pthht']
# 0.6142573840524931
# ['oh', 'shoot', 'well', 'watch', ':D']
# 0.5497329595052772
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# 0.5805994402816647
# ['tope', ':)']
# 0.7496489996489997
# ['good', 'night', 'sweet', 'dream', 'xxoo', '♡', '♥', '♡']
# 0.5847405559768698
# ['littl', 'finger', ':D']
# 0.6768115942028986
# ['love', ':)', '13', 'photo', 'explain', 'ukrain', 'russia']
# 0.7900448910301127
# ['friday', ':)']
# 0.9546489996489997
# ['hey', 'fam', 'vote', 'alreadi', ':)', 'gotta', 'win', 'boy', 'teenchoic']
# 0.5629403825055999
# ['hi', 'jane', 'silver-wash', 'fritillari', ':)']
# 0.6690903690903691
# ['pleasur', ':)']
# 0.9996489996489997
# ['great', 'day', 'hunni', ':)']
# 0.7549723292075408
# ['good', 'night', 'moon', ':)', 'pandora']
# 0.7642756582537604
# ['2', 'ap', 'studi', 'hall', 'haha', 'great', ':)']
# 0.5999628194202667
# ['follow', 'everyon', 'back', 'teamfollowback', ':-)']
# 0.7420242218609363
# ['ha', 'almost', 'gave', 'fuck', ':)', 'boy', 'trash', 'wast', 'time', "that'", 'sure']
# 0.4721719720047718
# ['amaz', 'pic', 'today']
# 0.622612593074532
# ['ye', 'alreadi', 'ad', 'pleas', 'check', 'final', 'design', ':)']
# 0.6335265236387528
# ['noth', 'much', 'need', 'grow', ':)']
# 0.5754753942253943
# ['easi', 'clever', 'interest', 'audienc', 'welcom', ':)']
# 0.7099650553040383
# ['great', 'video', ':D']
# 0.8303885312514266
# ['ask', 'end', '..', "i'm", 'friend', ':)']
# 0.5419379125249404
# ["thank'", 'follow', 'keven', ':)']
# 0.641225209044358
# ['ha', 'love', 'pic', 'clearli', 'much', 'learn', 'popular', 'english', 'pastim', ':)']
# 0.5745393602290154
# ['ashramcal', 'return', ':p']
# 0.5833333333333334
# ['catch', 'fall', 'fall', 'ontrack', ':)']
# 0.523470710970711
# ['alway', 'make', 'thing', 'better', ':)', '❤', '️']
# 0.5836724679300233
# ['guess', "they'll", 'show', 'german', 'also', 'subtitl', ':)']
# 0.5021847307561593
# ['pinter', ':-)']
# 0.75
# ['goood', 'morninggg', 'jummah', 'mubarak', 'everyon', 'bless', 'amaz', 'day', 'ahead', ':)']
# 0.724731996660474
# ['cute', ':-)', '🐶']
# 0.6206896551724138
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8281468258017921
# ['fabul', 'time', 'miss', ':)', 'xx']
# 0.6395297387484888
# ['noth', 'perfect', 'smile', ':)']
# 0.7848926389222443
# ['never', 'show', 'much', ':)']
# 0.5807548581521185
# [':-)', 'cheer', 'pete', 'listen', 'later', '☺', '☺']
# 0.5534013605442177
# ["that'", 'build', 'sunday', ':p']
# 0.6943319838056681
# ['direct', 'attent', '...', 'awesome-o', ':)']
# 0.7390540988772816
# ['get', 'us', 'tune', 'well', 'app', 'multipl', 'option', ':D']
# 0.647893291257597
# ['engin', ':)']
# 0.9996489996489997
# ['happi', 'friday', ':D']
# 0.9364804469273743
# ['cya', 'week', ':D']
# 0.7016806722689076
# ['happi', 'shop', ':)']
# 0.8329131133600408
# ['fantast', 'show', 'harrog', 'home', 'gift', 'back', 'offic', '2', 'day', 'jet', 'see', 'wonder', 'supplier', ':)']
# 0.5482716073870558
# ['nice', 'one', ':D']
# 0.7464601032816924
# ['ye', "let'", ':)']
# 0.8351195351195351
# ['7', ':)', ':)', ':)', ':)']
# 0.8464972229678113
# ['australia', 'morn', ':D']
# 0.8046398046398046
# ['req', 'star', ':)', 'fridayloug']
# 0.6816426816426817
# ['knew', 'whole', 'class', 'cri', 'hurt', 'word', ':)']
# 0.4082008724865868
# ['opportun', 'anyon', 'ask', 'question', 'babe', 'includ', ':)', '4thstreetmus']
# 0.640386283728675
# ['lunch', ':)']
# 0.636012636012636
# ["i'll", 'hawaii', 'decemb', "we'll", 'kick', 'back', 'miss', ':)']
# 0.4790410305933003
# ['two', '17', 'year', 'old', 'deepli', 'love', ':-)']
# 0.6758972554539058
# ['aha', "that'", 'alright', '❤', '️', 'love', ':)']
# 0.7036885152736063
# ['hope', 'nate', 'notic', 'edit', 'sinc', 'made', 'icon', ':)']
# 0.5475775872336192
# ['send', 'john@timney.eclipse.co.uk', ':)']
# 0.7358771108771109
# ['hah', '...', 'thousand', 'lie', ':D']
# 0.6463373561605389
# ["i'd", 'will', 'tri', ':)']
# 0.7335201519984128
# ['read', 'newspap', ':D']
# 0.7142857142857143
# ['afternoon', 'date', '<3', ':)']
# 0.8158474114222289
# ["here'", 'fan', 'made', 'art', 'u', ':)', 'guy', 'phone', 'lew', 'bend', ':D']
# 0.6475001763127595
# ['nah', 'beaut', 'way', ':)']
# 0.6305937305937306
# ['fallout', '4', 'get', 'see', 'glow', 'sea', 'technic', 'fallout', '3', 'play', 'see', ':D']
# 0.47382602854570816
# ["i'm", 'friend', 'cousin', 'karen', 'gunderson', 'watch', 'europa', 'report', 'thoroughli', 'impress', 'want', 'say', 'great', 'script', ':-)']
# 0.5783044599718993
# ['dri', 'start', 'wale', 'wait', 'duck', 'overtak', 'motorway', ':-)']
# 0.7258182677537517
# ['good', 'morn', 'fab', 'friday', ':)']
# 0.8485039854820876
# ['hahaha', '...', 'thu', '...', 'sneak', 'away', 'log', 'niteflirt', ':D']
# 0.5416975915011278
# ['yep', "we'r", 'trash', 'af', 'im', 'indonesia', 'hbu', ':-)']
# 0.5030203576864536
# ['obvious', 'get', 'better', 'tweet', ':-)']
# 0.6330818534394774
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# 0.7540555134569965
# ['bowl', 'alway', 'best', 'friend', ':)']
# 0.5649145449145448
# ['hope', "i'll", ':)', 'x']
# 0.7027949081713248
# ['say', 'must', 'chri', 'elli', ':)']
# 0.6031074631074631
# ['ye', 'friendli', 'contest', 'loser', 'buy', 'drink', ':)']
# 0.6626702769559912
# ['thank', 'follow', 'great', 'day', ':)']
# 0.785660303651618
# ['thank', ':-)']
# 0.9214046822742474
# ['thank', ':D']
# 0.9214046822742474
# ['day', 'practic', 'song', ':)']
# 0.6693677567188627
# ["here'", 'remind', 'need', 'one', ':-)']
# 0.6707403055229142
# ['harri', 'niall', '94', 'harri', 'born', 'ik', 'stupid', 'wanna', 'chang', ':D']
# 0.34610758750293635
# []
# nan
# ['...', 'play', 'al', 'n', "he'll", 'score', 'fuck', 'night', ':)']
# 0.5149101656563957
# ['bff', '..', ':)']
# 0.7094661761328428
# ['hi', "here'", 'vid', 'stydia', 'take', 'look', ':)']
# 0.7675714676463213
# ['im', 'send', 'alex', 'like', 'million', 'pictur', ':)']
# 0.615430529474012
# ['love', ':)']
# 0.861717965166241
# ['visit', 'blog']
# 0.8571428571428572
# ['happi', 'birthday', 'nawazuddin', 'siddiqu', '...', 'big', 'big', 'fan', ':)']
# 0.6547480092686235
# ['ye', 'pleas', 'would', 'brighten', 'night', 'shift', 'nomnomnom', ':D', 'chocol', 'dukefreebiefriday', 'xx']
# 0.6068362907375601
# ['done', 'eonni', ':)']
# 0.7296510572372642
# ['fantast', 'night', ':)']
# 0.8747659997659998
# [':)']
# 0.9992979992979993
# ['boom', 'date', ':D', 'z']
# 0.65625
# ['follow', 'alreadi', 'thank', ':)']
# 0.6810942168481484
# ['thank', ':)']
# 0.9210536819232471
# ['happi', 'end', 'insyaallah', ':)']
# 0.6660113656322755
# ['that', 'way', 'see', 'west', 'ham', 'shit', 'small', 'club', 'london', 'villa', '3rd', 'biggest', 'brum', ':)']
# 0.4363914337598548
# ['deni', 'vagina', 'rli', ':D', 'poor', 'thing', ':D']
# 0.37694051979766263
# ['smile', 'sunnah', ':)', 'غردلي', 'عن']
# 0.9677167427167428
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear']
# 0.6550670590009693
# ['share', 'readi', ':)']
# 0.8485700375101297
# ['oh', 'white', 'rabbit', 'cutest', 'thing', "i'v", 'ever', 'seen', 'wait', 'ador', ':)']
# 0.5218412011643646
# ['welcom', ':)', 'love', 'weekend', 'izzi']
# 0.7765185213290016
# ['happi', 'birthday', 'mitch', ':-)', 'wish', 'best', 'good', 'day']
# 0.6943704473005217
# ['thank', ':)']
# 0.9210536819232471
# ['done', 'ya', 'minn', ':)', 'cjradacomateada']
# 0.7644573010090252
# ['welcom', 'fun', ':)']
# 0.8689533096312757
# ['recently.websit', 'upgrad', 'might', 'see', 'new', 'pictur', 'coolingtow', 'soon.thank', 'showinginterest', ':)']
# 0.599749657491593
# ['flipkartfashionfriday', 'multicolor', 'maxi', 'dress', 'pair', 'wid', 'wedg', 'make', 'ur', 'life', 'bright', 'color', ':)']
# 0.6929184423560331
# ['alway', 'motiv', ':-)']
# 0.5
# ['nnnnot', 'see', 'upsid', ':-)']
# 0.775
# ['haha', 'kyle', "gf'", 'babi', ':)']
# 0.5922343275284452
# ['lol', 'ok', 'watch', 'ya', 'bit', ':p']
# 0.6181574067175926
# ['bluesidemenxix', "i'd", 'love', 'win', 'one', ':)']
# 0.5943821788649375
# ['happi', 'birthday', ':)']
# 0.8889517607030358
# ['hello', ':)', 'ardent', 'follow']
# 0.7311374897461124
# ['goood', 'mooorn', ':)', 'want', 'sleep', '...']
# 0.5078521194897962
# ['ghost', 'bae', ':D', 'love', 'wuppert', 'tagsforlikesapp', 'instagood', 'smile', 'follow', 'cute', 'photooftheday', '…']
# 0.6925239472423991
# ['hahaha', 'okay', 'thank', ':)']
# 0.7146935076282902
# ['lose', ':D']
# 0.6111111111111112
# ['hehe', 'cool', ':)']
# 0.9593619593619594
# ['morn', 'u', 'today', 'u', 'got', 'plan', 'lazi', "i'm", 'still', 'bed', 'toast', 'fresh', 'coffe', '2', ':)', 'great', 'fridayfunday']
# 0.570084206254336
# ['welcom', 'famili', ':)']
# 0.8410826295866828
# ['re-sign', ':)']
# 0.7496489996489997
# ['meet', 'harri', "that'", 'need', 'life', ':-)']
# 0.5383702021859916
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8263445545056768
# ['one', 'sleep', 'til', 'wed', ':-)']
# 0.48632759092152034
# ['excit', 'chalkhil', 'park', 'celebr', 'tomorrow', 'midday', 'come', 'join', 'fun', ':-)']
# 0.6239262579525737
# ['hello', ':)', 'love', 'carter', ':)']
# 0.8164766104874998
# ['good', 'read', ':)']
# 0.7797451447086484
# [':-)']
# 1.0
# ['enjoy', 'hope', 'weather', 'hold', 'guy', ':-)']
# 0.5905103274203132
# ['done', ':)']
# 0.8444765858558962
# ['remedi', 'media', 'tell', ':-)']
# 0.5684523809523809
# ['thank', ':)']
# 0.9210536819232471
# ['jumma', 'mubarak', 'stay', 'bless', ':)']
# 0.8751983532471337
# ["we'r", 'look', 'forward', 'abl', 'spend', 'time', ':)', 'enjoy', 'iflix', ':)']
# 0.6672734940713086
# ['tgif', 'weekend', '...', 'enjoy', ':)']
# 0.7937373644599374
# ['im', 'thank', 'someon', 'like', 'life', 'inspir', 'better', 'everyday', 'love', 'mind', 'follow', ':)']
# 0.6144972287420853
# ['becom', 'better', 'atrack', 'better', ':)']
# 0.6585450458689895
# ['first', 'third', 'look', 'promis', 'els', 'fail', 'make', 'decis', 'go', ':)']
# 0.5764243846362264
# ['crazi', 'girlfriend', 'like', ':-)', '(-:', 'jesu', 'christ']
# 0.6193352137603008
# ['morn', ':)', 'gd', 'day', 'store', "i'm", 'badminton', '2', "littl'un", 'fabfriday']
# 0.6733361511950124
# ['kid', 'insid', 'want', 'one', ':-)']
# 0.5184424028143408
# ['imran', 'khan', 'hero', ':)', 'realli', 'ikprideofpak']
# 0.6983050906127829
# ['janjua', 'friend', ':)']
# 0.6902421902421901
# ['sorri', 'fuck', 'eric', 'think', 'he', 'funni', ':)']
# 0.516550082109503
# ['say', 'bday', ':)']
# 0.7347828347828349
# ['hey', ':)', 'check', 'pictur', 'think', ':)', 'notic', 'follow', 'pleas', '💕', 'x']
# 0.601429146707036
# [':)', ':)', ':)', 'pimpl', ':)', ':)', ':)', 'forehead', ':)', ':)', 'size', ':)', ':)', ':)', 'volcano', ':)']
# 0.8328068328068328
# ['good', 'luck', 'coupl', 'get', 'marri', 'weekend', ':)']
# 0.7336150153579297
# ['back', ':)', 'done', 'na', 'mag', 'miryenda', ':)']
# 0.5498932799883653
# ['wait', 'bro', ':-)']
# 0.8226773226773227
# ['parti', '3d', 'printer', ':)', 'celebr', 'futur', "technology'", 'possibl', 'touchétoday', '…']
# 0.6664642450168766
# ['u', 'use', 'app', 'listen', 'music', 'ye', 'app', ':-)', '—', 'idownload']
# 0.5693420265371485
# ['get', '25ish', 'snowbal', ':p']
# 0.618840579710145
# ['cours', ':)']
# 0.8052045552045553
# ['nd', 'go', 'expir', 'next', 'year', 'dat', 'mtn', '6gb', 'u', ':D', 'realli', 'like']
# 0.41544937689842504
# ['happi', 'birthday', 'nice', 'day', ':)', 'loveu']
# 0.7654525736217156
# ['wanna', 'go', 'back', 'time', 'everyth', 'still', 'fine', ':-)']
# 0.46540136048733277
# ['celebr', 'life', ':)', 'summer', 'morefuninthephilippin', 'laho', 'island', 'caramoan', 'island']
# 0.6042117842117842
# ['nice', 'quot', ':)', 'kunoriforceo', 'ceo', '1month']
# 0.8839826167412376
# ['good', 'stuff', ':)', 'love', 'bit', 'salmon']
# 0.7618153603588181
# ['jumma', 'kareem', ':)', 'friday', 'remind', 'recit', 'surah', 'kahaf', '..']
# 0.7153776142665031
# ["i'm", 'join', 'right', ':D']
# 0.6664600611086862
# ['sure', '..', ':)']
# 0.7052333719000385
# ['hi', 'melani', ':-)', 'fact', "they'r", 'realli', 'use', 'case', 'normal', 'wifi', 'could', 'issu', 'mention', '...']
# 0.5412798888762314
# ['quit', 'phenomen', 'offer', 'bosch', 'wash', 'machin', "week'", 'definit', 'last', 'long', ':)']
# 0.621848486621214
# ['one', 'ok', "i'll", 'run', 'photo', 'moment', ':D']
# 0.5989613059246656
# ['thank', 'refollow', ':)']
# 0.780702454615498
# ['slept', 'less', '7', 'hour', 'last', 'night', 'prepar', 'possibl', 'nap', ':p']
# 0.542719887955182
# ['idk', ':p', 'follow', '😎', '💁', '🏻']
# 0.46093380614657214
# ['feel', 'like', 'relaps', ':-)']
# 0.5519986449864498
# ['girl', 'nice', 'wallet', 'boy', 'prada', 'hai', '..', 'girl', 'rich', '..', 'boy', 'stupid', 'mean', 'bhai', 'ka', 'hai', ':p', 'prada', 'punjabiswillgetit']
# 0.5009362866223909
# ['☺', 'morn', 'babe', ':)']
# 0.6377246431594258
# ['lol', 'sorri', 'ultor', 'first', 'hitter', '...', 'favor', 'much', ':)']
# 0.6322113853480339
# ['finish', 'mass', 'effect', '1', 'yesterday', 'dont', 'know', 'shoud', 'start', 'mass', 'effect', '2', '100', 'game', ':)']
# 0.45623962444441973
# ['bad', 'would', 'remind', 'exercis', '1:12', ':-)', 'miss', 'need', 'come', 'back']
# 0.44859562090318883
# ['add', 'kik', 'ughtm', '545', 'kik', 'kikmeguy', 'kissm', 'nude', 'likeforfollow', 'musicbiz', 'sexysasunday', ':)']
# 0.3963524442397682
# ['overwhelm', 'groupmat', 'thank', 'group', 'got', '1', '75', 'recit', ':)']
# 0.6250799747930026
# ['ha', 'mistak', 'thank', 'point', ':)']
# 0.6784214727692989
# ['kyunk', 'aitchison', 'hai', ':p', 'look', 'respons', 'origin', 'tweet', 'know', 'brother']
# 0.5740314243265214
# ['snapchat', 'sexyjudi', '19', 'snapchat', 'kikmeboy', 'tagsforlik', 'pussi', 'gay', 'indiemus', 'sexo', ':)']
# 0.5187401847688929
# ["that'", 'true', 'inde', 'curvi', 'rout', ':)']
# 0.7525145788303683
# ['come', 'chill', 'fire', ':)']
# 0.6051275301275301
# ['mont', 'doa', 'header', ':D']
# 0.5
# ['haha', 'x', ':D']
# 0.7450980392156863
# ['ted', 'speaker', 'say', 'stress', 'good', 'bodi', 'anoth', 'speaker', 'introduc', 'way', 'avoid', 'stress', ':)', 'ted', 'thought', 'laboratori', ':)']
# 0.5439455676859302
# ['thing', 'note', 'awesom', ':-)']
# 0.8006181318681319
# ['might', 'lose', 'friend', 'today', 'know', 'idc', ':)']
# 0.5694800216836434
# ['good', 'morn', ':D', 'lol', 'realli', 'fuckin', 'dark', 'gonna', 'rain', 'hard', 'coupl', 'minut']
# 0.49517174332595904
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# 0.5805994402816647
# ['ff', 'amaz', 'singer', 'actress', 'model', ':-)']
# 0.8637793024585477
# ['happi', 'birthday', 'see', 'tonight', ':)']
# 0.7390853421361072
# ["i'm", 'amsterdam', 'guy', 'wooo', ':D']
# 0.5721913236929922
# ['stuff', 'happen', ':)']
# 0.6034627416206364
# ['friend', ':)']
# 0.7853632853632854
# ['neobyt', ':)', 'univers', 'pictur', 'seed', 'pirat', 'movi', 'copi', 'file', 'takedown', 'notic']
# 0.6181179999361817
# ['2', 'indirag', 'want', 'judiciari', 'commit', 'govt', 'polici', 'want', 'rbi', 'commit', 'know', 'mani', 'similar', 'view', ':)']
# 0.3894046890118891
# ["thought'", 'kepler', '452b', ':D']
# 0.875
# ['progress', 'stone', 'transfer', 'chelsea', ':D']
# 0.5333333333333333
# ['gg', 'bro', ':)', 'fun', 'seri']
# 0.6443817443817443
# ['alway', 'part', 'part', 'defenit', '...', '♬', ':p']
# 0.6537724682424434
# ['cours', 'man', ':)', 'nofx', 'shit']
# 0.5615412815412816
# ['friskyfiday', 'yipee', ':)', 'x']
# 0.6468833233539116
# ['morn', 'kim', 'sorri', 'hear', 'shed', 'light', 'issu', 'look', ':)', 'helen']
# 0.5789671313926633
# ['great', 'incent', 'get', 'kid', 'eat', 'fruit', 'vege', ':-)']
# 0.5797227318480953
# ['welcom', 'sir', ':)']
# 0.8604063010842672
# ['know', 'averag', 'take', '6', 'second', 'read', 'god', 'dam', 'mother', 'fuck', 'tweet', ':)']
# 0.6593542059494905
# ['thank', 'favourit', 'tweet', 'marin', ':)']
# 0.6996371590438086
# ['get', 'close', "can't", 'wait', 'new', 'season', ':)']
# 0.5454653708704856
# ['gz', ':D', 'name']
# 0.66
# ['morn', 'day', ':-)']
# 0.789505068574836
# ['guess', 'sleep', 'list', 'thing', 'today', ':-)']
# 0.5836828717440299
# ['hai', 'rajeev', '..', 'hope', 'u', 'r', 'hvng', 'funfil', 'friday.it', 'ws', 'reali', 'amaz', 'c', 'diff', 'side', 'kabir.fel', 'luv', 'u', ':)', 'smile', 'pl']
# 0.5334350683297852
# ['prettier', ':)', 'mine', ':)']
# 0.8806013806013806
# ['happi', 'birthday', 'best', 'wish', 'dresden', 'germani', ':)', 'love', '<3', '<3', '<3', '<3', 'pleas', 'share']
# 0.6778374960857178
# ['wanna', 'loser', 'like', ':)', '♥']
# 0.5764671386622606
# ['zayn', 'pleas', 'follow', 'would', 'mean', 'world', 'birthday', ':D', 'love', 'much', 'amaz', '<3']
# 0.5853368652382668
# ['congratul', 'friend', 'graduat', 'lose', 'plot', ':D']
# 0.5186387686387687
# ['0', 'sleep', 'offici', 'way', 'pari', 'cannot', 'wait', ':)', 'pari', 'tdf', '2015', '🇫', '🇷', '🍷', '🍸', '☀', '️', '🇫', '🇷', '🚲', '🇫', '🇷', '🍷', '🍸', '☀', '️', '🚲']
# 0.6744811765798915
# ['put', 'trust', ':)']
# 0.7993691743691743
# ['hey', 'good', 'suggest', 'guy', 'make', 'minion', 'slot', 'would', 'fun', 'cute', ':)']
# 0.5923056704122729
# ['happi', "b'day", ':)']
# 0.7995797800267074
# ['hah', '...', 'thousand', 'lie', ':D']
# 0.6463373561605389
# ['wow', 'look', 'good', 'isabella', 'make', 'wanna', 'start', 'work', 'back', ':D']
# 0.5716471790776095
# ['go', 'room', 'bc', '3', ':-)']
# 0.4629355335916988
# ['okeyyy', 'vddd', ':)', ');', 'excit', "can't", 'wait', '...', 'love', 'selfee', 'pic', 'insta', ':)', '♥', '♥', 'special', 'coco', '..', '🙆', '🙌', '😛', '😄', '😄', '😁', '😂', '😂', '🐒', '😁', '😝', '❤', 'dishoom']
# 0.5648749305320275
# ['think', 'write', ':)']
# 0.6689389320968268
# ['final', 'went', 'drive', 'tonight', ':-)']
# 0.5073008073008073
# ['thank', 'follow', 'great', 'day', ':)']
# 0.785660303651618
# ['im', 'go', 'sleep', 'goodnight', ':)']
# 0.5871600337088336
# ['hello', ':)']
# 0.9294735610525084
# ['yup', 'know', 'okay', 'let', 'tri', ':)', 'done', 'hhahhaaa', '—', 'haha']
# 0.5941710282461231
# ["i'm", 'suppos', 'ask', 'buy', 'album', ':)']
# 0.5413820420285937
# ['6', 'day', 'go', ':)']
# 0.6622152959362262
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# 0.8076972188276119
# ['least', "there'", 'one', 'cool', 'thing', ':-)']
# 0.6125585011931313
# ['hey', 'guy', "that'", 'new', 'page', ':)', 'enjoy']
# 0.7295580629007442
# ['jeez', 'tara', 'move', 'teamcannib', 'vs', 'teamspacewhalingisthebest', ':p']
# 0.6119047619047618
# ['morn', 'gym', 'session', 'done', 'feel', 'good', 'workout', 'earli', '...', 'enjoy', 'rest', 'day', ':)', 'friyay', 'workout', 'fitfa', '…']
# 0.6051836880851561
# ['guess', 'never', 'realli', 'identifi', 'pharmaci', ':)', 'verylaterealis', 'iwishiknewbett']
# 0.5244300573594567
# ['yeah', 'know', 'lack', 'thing', 'hey', 'pleas', 'check', 'final', 'design', 'satisfi', 'enough', ':)']
# 0.580644363502644
# ['wow', 'nice', 'combin', ':)']
# 0.7704183695563006
# ['charg', 'speaker', 'final', 'got', 'earlier', 'today', ':)']
# 0.4260863823143907
# [':)', 'masaantoday']
# 0.9996489996489997
# ['later', 'turn', ':D']
# 0.6746031746031745
# ['text', 'wanna', 'meet', "i'll", 'get', ':)']
# 0.5663958312951133
# ['long', ':)']
# 0.7246489996489996
# ['friend', 'never', 'talk', 'ess-aych-eye-te', 'anyon', ':)']
# 0.5515394864709934
# ['ya', 'thank', ':)', '😊']
# 0.7438601742949569
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8281468258017921
# ['yeah', 'left', 'one', 'supposedli', 'hurt', 'bc', 'right', 'heart', 'appar', "it'll", 'fine', 'good', 'luck', ':)']
# 0.5005565886350163
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# 0.8076972188276119
# ['ahh', 'thank', 'u', ':D']
# 0.6700783310009185
# ['niall', 'follow', 'fan', ':)', "i'm", 'still', 'without', 'follow', '👍']
# 0.4000798903683408
# ['sister', 'best', 'best', 'pre', 'bday', 'celebr', ':)']
# 0.696731453874311
# ['among', 'time', 'fav', 'tweet', ':D']
# 0.7642222222222224
# ['happi', 'birthday', 'g', 'best', 'life', ':)']
# 0.7457579316335692
# ['need', 'stress', 'time', ':)']
# 0.5425884175884176
# ['immedi', 'plan', 'hope', 'someday', 'futur', ':)']
# 0.6716401642872231
# ['could', 'make', "foxy'", 'song', 'version', 'instrument', 'form', 'sound', 'epic', 'beat', 'alon', ':)']
# 0.5624728130442702
# ['second', 'well', 'done', ':)']
# 0.7475347356156952
# ['think', 'hard', 'bed', ':p']
# 0.525946275946276
# ['tomorrow', 'goldcoast', ':)']
# 0.681052549473602
# ['like', 'way', 'said', 'gal', 'lelomustfal', 'beautiful', 'way', ':)']
# 0.6741420005139518
# ['happi', 'save', 'day', ':)', 'hope', 'enjoy', 'meal', 'sam']
# 0.6101518792307501
# ['thank', 'min', ':)']
# 0.8084802323932759
# ['5g', 'liker', ':)', 'like', 'fast']
# 0.5512146134097353
# ['like', 'morn', 'got', 'dress', 'bought', ':)', "i'm", 'total', 'love', '♡', 'newdress', 'happi', '…']
# 0.5837579118254479
# ['ff', 'could', 'anyon', 'resist', 'beauti', 'smile', ':-)', 'quacketyquack']
# 0.7161048929141035
# ['u', 'mean', 'hide', 'fot', ':p']
# 0.5402907605430733
# ['aww', 'thankyou', ':)']
# 0.7213777213777214
# ['ok', 'good', 'night', 'wish', 'troy', 'ugli', 'met', 'today', ':)', '):', 'ok', 'today', 'fun', "i'm", 'excit', 'tmrw']
# 0.582477757226349
# ['inde', ':-)']
# 1.0
# [':)', 'good', 'afternoon', ':D', 'twitterfollowerswhatsup', 'happyfriedday', 'keepsafealway', 'loveyeah', 'emojasp_her']
# 0.6637951187829533
# ['okay', ':)']
# 0.757982332982333
# ['make', 'two', 'us', ':D']
# 0.6758868794017912
# ['hurt', 'read', "people'", 'holiday', 'work', ':D']
# 0.5426316353947933
# ['nice', 'hear', 'want', 'switch', 'us', ':)', 'pro', 'kit', 'would', 'best', 'choic', 'follow', 'link']
# 0.6010995709356447
# ['beauti', '...', 'winter', 'like', 'summer', 'russia', ':)']
# 0.571461054331272
# ['thought', '’', 'like', 'mate', ':)']
# 0.6216779338730558
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# 0.6930006049606776
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8263445545056768
# ['dm', ':p']
# 0.8148148148148149
# ['also', 'come', 'game', ':)']
# 0.6418383887133887
# ['thank', ':)']
# 0.9210536819232471
# [':)', 'hope', 'enjoy']
# 0.81461485597515
# ['ok', 'first', 'time', 'chat', 'made', 'joke', 'lol', 'believ', 'wont', 'forget', 'u', ':)', 'name']
# 0.5502678097760803
# ['mymonsoonstori', 'bodi', 'shop', 'bodi', 'mist', 'vanilla', 'work', 'wonder', 'skin', ':)']
# 0.684879129776155
# [':)', 'best', 'youtub', '...', 'keep', 'good', 'work', 'man', 'starsquad', 'sidemen']
# 0.6565556385327804
# ['yaaayyy', 'best', 'friendaaa', 'shout', 'like', 'minion', ':)']
# 0.6799884601278329
# ['thank', 'ad', 'us', 'list', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# 0.6130947629103015
# ['1tbps4', 'wow', 'prize', 'delight', 'eye', 'pick', 'win', 'burst', 'sing', 'ps4', 'mine', 'feel', 'divin', ':)']
# 0.4744922544687732
# ['bath', ':)', 'even', '’', 'wheeli', 'bin', 'nowher', 'put']
# 0.5811542061542061
# ['get', 'readi', '...', 'ubericecream', 'messengerforaday', ':)']
# 0.521718372096971
# ['yeap', ':)']
# 0.9996489996489997
# []
# nan
# ['cool', '...', 'congrat', 'kyli', 'u', 'look', 'nice', ':-)']
# 0.633170730757944
# ['thought', 'work', 'season', 'realli', 'busi', 'day', 'ok', 'deal', 'weekend', 'toilet', 'break', ':p']
# 0.5153719835183465
# ['daddi', 'af', '...', ':-)']
# 0.5385764571054354
# ['latest', 'one', ':)']
# 0.6685030598074077
# ['happi', 'make', ':)']
# 0.7775672014103553
# ['far', 'good', 'ikaw', 'musta', 'cheatmat', ':)']
# 0.6105074929892448
# ['e', 'l', 'f', 'thank', 'singer', ':)', 'kyuhyun', 'thank', 'e', 'l', 'f']
# 0.5168106116722717
# ['20', 'ghanton', 'se', 'light', 'nahi', ':)']
# 0.5832163332163333
# ['one', 'last', 'long', 'lol', 'block', 'alreadi', 'must', 'nice', 'tweet', 'hate', ':)']
# 0.505444209042272
# ['ur', 'skin', 'think', 'ur', 'still', '16', 'decid', 'break', ':-)', 'cool']
# 0.6459922170028554
# ['easy.get', '5:30', 'go', 'work', 'come', 'home', 'bout', '6', 'take', 'care', 'home', 'famili', 'therein', "that'", 'see', ':-)']
# 0.47912044767638645
# ['thank', 'majalah']
# 0.6714046822742474
# ['piti', 'parti', ':-)']
# 0.6959064327485379
# ['tgif', 'unless', 'one', 'student', ':)', 'light', 'read']
# 0.6296419009151928
# ['dominiqu', "i'm", 'biggest', 'fan', 'like', 'oh', "i'm", 'england', 'get', 'fan', 'sign', ':)']
# 0.5305351015507155
# ['good', 'caus', "i'd", 'like', 'upload', ':)']
# 0.6486967123555586
# ['goood', 'mornin', 'earthl', ':D']
# 0.875
# ['happi', 'tweet', 'like', 'new', 'build', ':)', 'mm']
# 0.7524637156517716
# ['okay', 'yay', 'ask', 'tomorrow', 'pleas', ':)']
# 0.6137503889438874
# ['alway', ':)', 'posit']
# 0.6997659997659998
# ['lamp', 'shop', ':)']
# 0.6997659997659998
# ['word', 'big', 'site', 'got', 'chang', 'a-foot', ':)', 'websit', 'develop', 'revamp']
# 0.5170933949173152
# ['vote', 'brainchild', '3', 'time', 'pleas', 'may', 'poem', ':D']
# 0.5887307989512622
# ['confid', 'confin', 'u', 'ur', 'limit', '...', ':)']
# 0.5033292509816986
# ['wish', 'colorado', ':)']
# 0.6048384635341157
# ['happi', 'friday', 'folk', 'order', 'goodyear', 'tyre', 'onlin', 'get', 'upto', '£', '40', 'cashback', 'cs', 'appli', 'yourewelcom', ':)']
# 0.6326625565483056
# ['nightli', 'routin', 'simpin', ':-)']
# 0.75
# ['add', 'snapchat', 'yall', ':)', 'give', 'name']
# 0.5669148213541806
# ["i'm", 'look', 'influenc', 'app', ':)', 'interest', "here'", 'invit']
# 0.7654146976815264
# ['sketchbook', 'art', 'love', '4wild', 'draw', 'hair', 'turn', 'pretti', 'cool', ':D', 'art', 'hair', 'color', 'colorpencil', 'cray', '…']
# 0.613257129552107
# ['tune', 'back', 'hubbi', ':)', 'u', 'play', 'queen', 'pl']
# 0.5946133656482717
# ['fell', 'asleep', 'like', '6:30', "can't", 'fall', 'asleep', 'two', 'hour', ':-)']
# 0.3756784822117974
# ['great', 'night', 'great', 'peopl', ':)']
# 0.7694396283322458
# ['imma', 'use', 'next', 'time', ':)']
# 0.49915931974755506
# ['ob', '11h', 'v', 'kino', ':)']
# 0.4998595998595999
# ['gone', 'make', 'tho', 'posit', 'day', ':)', 'adult', "can't", 'keep', 'act', 'like', 'mom', '..']
# 0.4737692240750705
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear']
# 0.6550670590009693
# ['great', 'went', 'kardamena', 'last', 'summer', 'amaz', 'beach', 'wonder', 'sea', 'year', 'time', 'go', 'samo', 'greec', ':)', ':)']
# 0.5525678781604678
# ['chicken', 'caesar', 'salad', 'tad', 'bland', 'live', ':)']
# 0.47382261667975956
# ['love', 'afraid', 'respond', 'hate', ':)', 'ili', 'x', 'x', 'x']
# 0.5727564977057877
# ['first', 'leg', 'tour', 'go', 'well', ':D', 'music', 'band', 'rock', 'magictrik', 'tour']
# 0.5417979547288307
# ['okk', 'den', 'call', 'abp', 'n', 'spread', 'allov', 'india', 'n', 'abroad', 'well', ':p']
# 0.5479111209701272
# ['thank', 'much', ':)']
# 0.7427835833632935
# ['pleas', 'let', 'us', 'know', 'store', 'abl', 'visit', 'may', 'inform', 'expect', ':)']
# 0.5791062844645855
# ['tweet', 'much', 'appreci', 'thank', 'dedic', 'member', ':)']
# 0.7840501071556972
# ['freedom', 'hangout', 'whoever', 'want', ':)']
# 0.45419030852101716
# ["i'm", 'like', ':)']
# 0.6169668844185244
# ['hi', ':-)', 'look', 'tourist', 'info', 'get', 'applic', 'zonzofox', 'click', 'link']
# 0.7567970065703646
# ['leo', 'season', ':-)', '♌', '️']
# 0.6789855072463769
# ['life', 'kutiyapanti', ':D', 'love', 'life', ':D']
# 0.7219717064544651
# ['thank', 'support', ':)', 'kunoriforceo', 'ceo', '1month']
# 0.8920519075798579
# ['profession', 'hit', 'video', 'wick', 'boomshot', 'fuh', 'di', 'world', 'even', 'thank', ':)']
# 0.6416595341347934
# ['yeeey', 'welcom', 'club', 'one', 'half', 'year', 'whatsapp', '..', 'donot', 'regret', '..', ':)']
# 0.5718581506870625
# ['problem', ':)', 'pleasur', '❤', '️']
# 0.7600045273958317
# ['send', 'one', 'pleas', ':)', 'wont', 'expos', 'roast', '<3']
# 0.6280166376554059
# ['lemm', 'cover', 'u', 'lipstick', 'n', 'cran', 'vodka', ':-)']
# 0.5856223383662409
# ['road', 'trip', ':D']
# 0.7572463768115942
# ['alway', 'walk', 'past', 'place', 'may', 'go', 'tri', ':D']
# 0.5861169048085002
# ['yeah', "i'v", 'lost', 'call', 'day', ':)']
# 0.4856697006459969
# ['jummah', 'mubarak', 'rememb', 'prayr', ':)']
# 0.7898595998595999
# ['member', 'හෙල', 'හවුල', 'chanc', ':D']
# 0.5752941176470588
# ['miss', 'babi', ':)', 'onemochaonelov']
# 0.47012976602820356
# ['yo', 'southpaw', 'great', 'movi', 'someon', 'better', 'get', 'award', ':D']
# 0.657788622597997
# ['music', 'human', 'geniu', 'stroma', ':)']
# 0.6252564252564252
# ['🔴', 'live', 'younow', 'jonah', 'jareddd', ':)']
# 0.5646978146978147
# ['messag', 'full', 'name', 'b', 'address', 'postcod', 'talkmobil', 'phone', 'number', 'thank', ':)']
# 0.5635301398513443
# ['last', 'class', 'morn', 'two', 'week', 'break', ':-)']
# 0.5617790706026
# ['happi', 'happi', 'birthday', 'emili', ':D']
# 0.9133997247186463
# ['elf', 'fight', 'huha', ':D', ':)', 'teenchoic', 'choiceinternationalartist', 'superjunior']
# 0.6769955832455832
# ['may', 'find', 'confus', ':)', 'simpl', 'wolf']
# 0.5908902602450989
# ['nice', 'pic', ':)']
# 0.8012985668158082
# ['promot', ':)']
# 0.7496489996489997
# ['yeah', 'bird', 'transform', 'sword', ':D']
# 0.6123076923076922
# ['even', 'real', 'word', ':D']
# 0.6035714285714285
# ['could', 'misread', 'wors', 'thing', ':p']
# 0.49628397917871603
# ['forward', 'richard', '...', 'follow', ':)']
# 0.5621746662531681
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel']
# 0.6184131285757302
# ['yup', 'happen', 'everywher', 'peopl', 'cant', 'debat', 'come', 'name', 'call', ':-)']
# 0.5037670239813097
# ['need', 'get', 'work', 'today', 'ibiza', ':)', ':)', ':)', 'birthdaymoneyforjesusjuic']
# 0.6499540004392841
# ['anytim', ':)']
# 0.9163156663156664
# ['mistak', 'happen', 'man', 'long', 'get', 'play', 'game', "we'll", 'happi', ':)']
# 0.5338919954660051
# ['hey', 'wanna', 'check', 'ytb', 'channel', 'post', 'gameplay', 'tutori']
# 0.5199200336700337
# ['one', 'construct', 'critic', 'welcom', ':)', 'ganesha', 'textur', 'photographi', 'art', 'hinduism', 'hindugod', 'elephantgod']
# 0.4920742000697786
# ['ye', 'alway', 'selfish', 'fuck', ':)']
# 0.48077321360903447
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel']
# 0.6184131285757302
# ['want', 'creat', 'first', 'bboy', 'cardgam', 'pixelart', 'gamedesign', ':D', 'think', 'indiedev', 'pixel_daili', 'gamedev']
# 0.5917515518893471
# ['sound', 'still', 'like', 'good', 'idea', ':)']
# 0.6271759576606223
# ...
# 0.568765107035561
# ['order', 'dress', '..', ':)', ':)']
# 0.7145136645136645
# ['like', 'eye', ':D']
# 0.6761713993951534
# ['dear', 'person', 'pleas', 'studi', 'embarrass', 'urself', 'entropi', 'work', '100', 'w', 'evolut', ':)']
# 0.4766991935722586
# ['ye', 'stay', 'touch', ':)', 'instagram']
# 0.6602993633481439
# ['look', 'forward', 'alway', 'love', 'giggl', 'loop', 'two', 'great', 'act', ':)']
# 0.6788266309149724
# ['cheer', 'mention', '...', 'even', 'wrong', 'section', ':)']
# 0.6136100706266296
# ['ty', 'dear', 'eva', "i'm", 'total', 'agre', ':-)', 'keep', 'smile', 'u']
# 0.6067716167879802
# ['spain', 'morn', ':)', 'good', 'morn', 'ian']
# 0.7318139642957161
# ['anoth', 'note', 'found', 'camden', 'town', '...', ':D', 'work']
# 0.5540092640961217
# ['even', 'talk', 'great', ':)']
# 0.6781199180528039
# ['ohhh', 'wait', '28', ':)', 'luv', 'uhh']
# 0.7283933783933785
# ['thank', 'favorit', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# 0.5810353512939753
# ['scoup', '17', 'like', 'jren', 'nuest', ':D']
# 0.5844625112917795
# ['oh', 'love', 'lovelayyy', 'thank', 'ok', 'kidney', '..', 'want', 'anyway', ':p']
# 0.5348727476065881
# ['neuer', 'post', 'onlin', ':)', 'fix', 'spray']
# 0.4790986861575097
# ['check', 'us', ':)']
# 0.8122908902478795
# ['class', 'today', 'train', 'friend', ':)']
# 0.5175710522566506
# ['okay', 'let', 'get', 'bat', ':)']
# 0.6278108515065037
# ['one', 'fall', 'love', 'choic', '’', 'chanc', '...', ':)', '♡']
# 0.524210984398786
# ['would', 'email', 'donnae.strydom@westerncape.gov.za', ':-)', 'ta']
# 0.6504032258064516
# ["that'", 'great', 'hear', "we'll", 'sure', 'pass', 'thank', 'staff', ':)', 'nic']
# 0.6945739405104815
# ['seen', 'uni', '..', 'talent', ':)']
# 0.49615589615589617
# ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 0.29520089285714285
# ['aww', 'love', 'kind', 'men', ':)']
# 0.7481611314759258
# ['mca', 'money', 'tell', 'stori', ':)']
# 0.6398595998596
# ['save', 'live', ':-)']
# 0.6574074074074074
# ['hey', 'juaquin', 'v3nzor99', ':)', 'want', 'get', 'iph', '0ne', '6', 'free', 'kindli', 'check', 'bi0', 'thx']
# 0.7458295004817722
# ['break', 'shell', ':-)']
# 0.6666666666666666
# ['truth', ':D']
# 0.75
# ['fantast', 'thank', ':)']
# 0.9473691212821648
# ['heyi', ':)', 'u', 'rt', 'link']
# 0.5413863657766097
# ['hashtag', 'say', '...', ':)']
# 0.6682620680410465
# ['still', 'green', 'tea', 'blend', 'flavor', ':)']
# 0.5579279887790526
# ["i'm", 'excit', "what'", 'come', ':)', 'realli', 'deserv']
# 0.6087871402479209
# ['today', 'improv', 'tomorrow', '...', ':-)', ':)']
# 0.7472305028454057
# ['sometim', ':-)']
# 0.7115384615384616
# ["i'm", 'sorri', 'ran', 'friend', 'rough', 'day', "i'll", 'tri', 'stream', 'saturday', ':)']
# 0.4884614818553119
# ['get', 'well', 'soon', ':)', 'xx']
# 0.6446505697592654
# ['bed', 'best', 'coupl', 'ever', ':)']
# 0.6687384987384987
# ['favorit', 'appl', 'sauc', ':)']
# 0.8171321921321921
# ['nice', 'holiday', 'honey', ':-)', 'kiss']
# 0.654967159277504
# ['follow', 'back', 'pleass', ':)']
# 0.6237833485792417
# ['thakyou', 'sir', ':)']
# 0.721988221988222
# ['thank', 'beatriz', ':)']
# 0.780702454615498
# ['rt', 'bailona', 'group', 'chat', 'mention', 'approv', 'fanbas', ':)']
# 0.7089219901719902
# ['parti', 'cancel', ':p', 'bajrangibhaijaanhighestweek', '1']
# 0.6361092604930046
# ['thank', 'follow', ':-)', 'hope', 'great', 'week']
# 0.7444507743204173
# ['puff', 'pastri', 'egg', 'tart', 'hot', 'fresh', 'oven', ':)', 'wan', 'chai', 'mtr']
# 0.5853593792465266
# ['thank', 'follow', 'us', ':)', 'like', 'cool', 'new', 'product', 'check', 'campaign']
# 0.7237341325203628
# ['make', 'alyssa', 'rub', 'tummi', ':)']
# 0.3866520526897886
# ['almost', 'done', 'master', 'sword', ':D', 'princess', 'zelda']
# 0.7461412151067324
# ['ive', 'email', 'regard', 'cours', 'queri', ':)']
# 0.6329848517348518
# ['happi', 'birthday', '🎂', 'jiva', 'ever', ':)', '🍹', '🍸', '🍻']
# 0.5442970515474767
# ['awesom', 'news', 'mate', 'well', 'happi', ':)']
# 0.755421055523036
# ['jumma', 'mubbarak', ':)', '❤', '❤']
# 0.7331929331929332
# ['gorgeou', 'deborah', 'good', 'tast', ':)', 'use', 'coupon', 'code', 'colourdeb', 'red', 'purpl', 'blue']
# 0.6383225295634054
# ['im', 'sure', 'wasnt', 'anyth', "we'r", 'alreadi', 'use', ':)', 'glad', 'ur', 'home']
# 0.5538069882367642
# ['wooo', 'happi', 'friday', 'friend', ':)', 'ff']
# 0.7982098034332671
# ['plan', 'send', 'email', "chippy'", 'vessel', 'monday', 'ps', 'happi', 'anniversari', 'haha', ':)']
# 0.6190253232514906
# ['comput', 'sex', 'count', ':)', 'funni', 'vintag']
# 0.5990545398440136
# ['use', "i'll", 'pick', 'next', 'time', "i'm", ':)', 'yeah', "i'll", 'cook', 'nice', 'big', 'kitchen', '😍', '😊']
# 0.6011326073130789
# ['love', 'great', 'collag', ':)']
# 0.9056911973482212
# ['✫', '✧', '˚', '✧', '·', '✵', '⊹', 'thank', 'alway', 'put', 'smile', 'face', 'mind', 'follow', ':)', 'nice', 'day', 'x', '1710']
# 0.5777443687787894
# ['look', 'fun', 'snapchat', 'gooffeanotter', 'snapchat', 'kiksex', 'snapm', 'lesbian', 'instagram', 'mpoint', 'mugshot', ':)']
# 0.40686315316074556
# ["can't", 'sleep', 'much', 'want', 'love', 'bug', 'made', '33', 'token', 'never', 'mind', ':)']
# 0.559844759156652
# ['gamer', 'follow', 'train', 'follow', 'retweet', 'follow', 'retweet', 'gain', 'activ', 'follow', ':)', '110']
# 0.6741783932803959
# ['look', 'forward', 'hear', 'thought', ':)', 'maritimen']
# 0.6312761103186635
# ['stat', 'day', 'arriv', '2', 'new', 'follow', 'unfollow', ':)', 'via']
# 0.8053202017093453
# ["there'", 'stun', 'show', 'garden', 'rh', 'tatton', 'park', 'show', 'wonder', 'design', 'construct', 'plant', ':)']
# 0.5580780163776115
# ['behav', 'els', 'u', 'jump_julia', 'malema', ':D']
# 0.6900890437475803
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# 0.8076972188276119
# ['great', 'friday', 'fren', ':-)']
# 0.8273322147651007
# ['nuf', 'teas', 'alreadi', 'show', 'us', 'alien', 'everyday', 'seem', 'get', 'closer', 'see', 'alien', 'cousin', ':-)']
# 0.3718133666240258
# ['new', 'monitor', 'good', ':D']
# 0.7294648781875059
# ['good', 'morn', 'kimmi', ':)']
# 0.7359077596303873
# ["channel'", 'show', 'planetbollywoodnew', 'full', 'epi', 'avail', 'onlin', ':)']
# 0.5304305469746646
# ['evolut', ':D']
# 0.75
# ['fback', ':)']
# 0.9996489996489997
# ['love', 'airport', ':-)', ':-)']
# 0.7365900383141762
# ['love', ':)', 'want', 'corn', 'chip', ':)']
# 0.749064578822928
# ['thank', ':)', 'tricki', 'bt', 'v', 'import', 'subject']
# 0.5774439091209277
# ['hah', '...', ':D', 'say', 'sorri', '...']
# 0.5782871279924325
# ['be-shak', ':p']
# 0.75
# [':)']
# 0.9992979992979993
# ['happi', 'birthday', 'miss', 'chenoweth', 'hope', 'great', 'one', '...', 'oodl', 'cake', ':)']
# 0.5939939754770627
# ['happi', 'birthday', 'gorgeou', 'hope', "i'll", 'see', 'fair', ':)']
# 0.7154793693390117
# ['im', 'go', 'bed', 'love', 'hailey', 'milk', 'craźi', 'sęxxxÿ', 'cøôl', 'runway', 'look', ':)']
# 0.519995500925089
# ['feel', 'someon', 'share', 'review', 'work', 'hard', ':D']
# 0.5781772583861328
# ['gooodnight', 'love', 'boy', 'iv', 'ri', 'zoe', 'kati', 'jayci', 'jen', ':)']
# 0.6121986654970163
# ['well', 'bud', 'guess', "i'm", 'go', 'bed', 'goodnight', 'guy', 'see', 'morn', 'whatev', 'woke', ':)']
# 0.5877197500991492
# ['thank', 'follow', 'great', 'day', ':)']
# 0.785660303651618
# ['thank', ':)']
# 0.9210536819232471
# ['bad', 'thing', 'think', 'weird', 'face', 'rad', ':-)', 'thank', 'though']
# 0.5377738014566659
# ['make', 'aliv', 'make', 'suffer', 'make', 'feel', '..', 'addict', 'song', 'alway', 'sing', 'karaok', ':-)', '..']
# 0.5050427774525467
# ['realli', 'cuti', ':D']
# 0.7412886259040105
# ['ltsw', 'gooo', ':-)']
# 0.6666666666666666
# ['thank', 'favorit', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# 0.5810353512939753
# ['threw', 'phone', 'wall', ':)']
# 0.5950625950625951
# ['giant', 'balloon', 'want', 'one', ':)']
# 0.47448016359348094
# ['face', 'time', ':)']
# 0.5682040029866117
# ["what'", 'hashtag', 'weekend', 'guy', ':)']
# 0.7055695978197944
# ['one', 'look', 'like', 'need', 'much', 'care', 'studi', "i'll", 'favourit', 'later', ':-)']
# 0.5572230249826178
# ['welcom', 'hun', ':)', 'thank', 'follow']
# 0.7445928876028125
# ['12pm', ':)']
# 0.9996489996489997
# ['thank', 'much', 'mom', 'get', 'ticket', ':)']
# 0.6069655940477495
# ['thank', 'manila_bro', 'follow', "let'", 'connect', 'soon', ':)']
# 0.8087937649388687
# ['lol', 'sometim', 'tweet', 'account', 'lol', 'day', 'home', 'dont', 'lot', 'say', ':D']
# 0.5616434552546248
# ['✫', '✧', '˚', '✧', '·', '✵', '⊹', 'thank', 'alway', 'put', 'smile', 'face', 'mind', 'follow', ':)', 'nice', 'day', 'x', '1709']
# 0.5777443687787894
# ['hope', 'one', 'day', "he'll", 'fall', 'love', 'strong', 'woman', 'let', 'see', 'thing', 'refus', 'see', ':)']
# 0.5844013028102155
# ['actual', 'lol', ':)']
# 0.6669441099820848
# ["that'", 'great', 'idea', 'love', 'fellow', 'veggi', ':-)']
# 0.8044559639500092
# ['c', '75', 'made', 'collagen', 'an', '2win', 'hopetowin', ':)']
# 0.5595873911551877
# ['awww', 'thank', 'hey', 'million', ':)', 'enjoy', 'weekend', 'hey']
# 0.7954664471330541
# ['guess', 'need', 'build', 'content', 'around', 'imag', 'inventori', 'littl', 'bit', ':)']
# 0.6127645556432373
# ['gamer', 'follow', 'train', 'follow', 'retweet', 'follow', 'retweet', 'gain', 'activ', 'follow', ':)', '1']
# 0.6958028658542355
# ['snap', ':)']
# 0.7996489996489997
# ['bring', 'togeth', 'friend', 'famili', 'loveforfood', 'foodforthought', 'thoughtfortheday', ':)']
# 0.5974277778625605
# ['carp', 'diem', 'mr', 'nath', ':)']
# 0.5831929331929333
# ['yep', "i'd", 'without', 'ning', 'recommend', 'book', 'thought', 'wow', ':)', 'think', 'gener', 'posit', 'lead']
# 0.5661369887007068
# ['ty', 'appreci', 'recent', 'retweet', 'great', 'friday', ':)']
# 0.8781031566362343
# ['11:11', 'meet', 'michael', 'hug', 'tight', 'talk', 'tell', "he'", 'import', 'love', 'much', 'make', 'smile', ':D']
# 0.526300182351221
# ['long', 'feel', 'comfort', 'im', 'gonna', 'wear', 'want', 'mother', 'haha', '...', 'sound', 'nice', '...', ':-)']
# 0.48411015669673235
# ['congratul', 'daughter', ':D']
# 0.7727272727272728
# ['goodnight', 'love', 'everyon', 'hate', 'stupid', ':)']
# 0.652565515995643
# ['thank', 'fill', 'although', 'opinion', 'still', 'stand', 'agre', 'disagre', 'harm', 'done', ':)']
# 0.6644436151028145
# ['see', 'saturday', ':p', "i'll", 'see', 'stormi', ':D']
# 0.6718654434250765
# ['time', '2', 'parti', ':D']
# 0.6048877825193615
# ['upgrad', 'an', 'sync', 'plu', 'done', 'singl', 'remot', 'devic', 'get', 'folk', ':)']
# 0.5576866896173152
# ['haha', 'know', 'mess', ':D']
# 0.5421994884910486
# ['want', 'say', 'huge', 'thank', 'ff', 'thank', 'support', ':)']
# 0.7089781072981542
# ['found', 'song', 'mention', 'nylon', 'gvb', 'cd', 'take', 'mountain.titl', 'unto', 'other', 'theworldwouldchang', ':)']
# 0.5152117659170808
# ['relat', 'would', 'make', 'new', 'categori', 'blog', 'everyth', 'one', 'place', ':)']
# 0.6349574781095859
# ['yah', 'know', "i'm", 'good', 'fake', 'mah', 'emot', ':)']
# 0.4523125704332547
# ['go', 'nice', 'mother', 'daughter', 'day', 'today', ':)', 'even', 'though', 'rain', 'morn', 'great', 'day', 'folk', 'xx']
# 0.6054506351297441
# ['idk', 'cant', 'wait', 'tonight', 'panel', 'peopl', ':)']
# 0.38532117103545677
# [':)', 'reason', 'dream', '...']
# 0.6786253159042943
# ["i'am", 'elf', 'hbu', ':)']
# 0.6248244998244998
# ['follow', 'back', 'pleass', ':)']
# 0.6237833485792417
# ['ps', 'took', '80-1', 'hope', 'count', ':-)']
# 0.4950980392156863
# ['✫', '✧', '˚', '✧', '·', '✵', '⊹', 'thank', 'alway', 'put', 'smile', 'face', 'mind', 'follow', ':)', 'nice', 'day', 'x', '1708']
# 0.5777443687787894
# ['yeah', 'neenkin', 'congrat', 'success', 'masterpiec', ':)', '🎉']
# 0.671249279652641
# ['goodmorn', 'smile', 'debit', 'order', ':)', 'soon']
# 0.7145502770502771
# ['thank', 'work', 'beagl', 'amaz', 'incred', ':)']
# 0.7631416940406189
# ['rt', 'bailona', 'group', 'chat', 'mention', 'approv', 'fanbas', ':)']
# 0.7089219901719902
# ['rememb', 'someon', ':)', '♫', 'see', 'feat', 'charli', 'puth', 'wiz', 'khalifa', '—']
# 0.4568880534121176
# ['cours', ':)']
# 0.8052045552045553
# ['hi', 'dylan', 'tyler', ':)', '♡', '♡', '♡']
# 0.6993502636359779
# ['favorit', 'tea', ':)']
# 0.7107217107217108
# ["i'v", 'done', 'today', 'watch', 'law', 'order', 'svu', 'love', 'sick', ':-)']
# 0.4873670240388567
# ['pleasur', ':D', 'enjoy', 'day']
# 0.8779718646179402
# ['fine', 'day', ':)']
# 0.7196739987437661
# ['morn', 'wear', 'get', 'darker', 'end', 'world', 'day', 'today', 'instead', 'septemb', ':-)']
# 0.5882367673069804
# ['lmao', 'love', 'berni', ':D']
# 0.5977011494252873
# ['lol', '...', 'morn', ':)', '...', 'wet', 'hey', 'friday', ':)']
# 0.6746728154890101
# ['aint', 'never', 'upload', 'lol', 'also', 'found', 'anoth', 'vid', 'u', 'danc', 'henri', 'trap', 'keep', 'go', 'fit', 'journey', 'tommi', ':)']
# 0.511546533908459
# ['ye', 'think', 'b', 'stupid', 'discuss', 'abt', 'wild', 'card', 'entri', 'jst', 'wait', "vivian'", 'perform', ':)']
# 0.5477591906163334
# ['new', 'blog', 'import', 'life', 'lesson', 'learnt', 'watch', 'movi', ':)', 'someth', 'everyon', 'need', 'rememb', 'xx']
# 0.6569754878425231
# ["i'm", 'best', 'perfect', 'promis', 'love', 'whole', 'heart', ':)']
# 0.6044867664423018
# ['u', 'transpar', '...', 'glass', '..', ':-)']
# 0.5081567700012921
# ['thank', 'share', 'bitcoin', 'news', 'stream', 'great', 'monday', ':)', 'insight']
# 0.6569328350794366
# ['ye', ':D']
# 0.803030303030303
# ['thank', 'retweet', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# 0.5859663177634034
# ['rang', 'sick', 'yesterday', 'told', "i'd", 'back', 'today', "i'm", 'better', 'morn', 'anyway', 'day', 'sunday', ':)']
# 0.4849726192728157
# ['ping', "i'm", 'watch', 'tl', 'like', 'hawk', ':D']
# 0.47659331653647524
# ['make', 'use', 'masquerad', 'mask', 'lol', 'zorroreturm', ':-)']
# 0.6499276726851875
# ['hope', 'help', ':-)']
# 0.670237230694747
# ['congrat', 'ryan', 'jami', 'delight', ':)', 'xx']
# 0.8531918234124117
# ['✫', '✧', '˚', '✧', '·', '✵', '⊹', 'thank', 'alway', 'put', 'smile', 'face', 'mind', 'follow', ':)', 'nice', 'day', 'x', '1707']
# 0.5777443687787894
# ['thank', 'mention', 'happi', 'friday', ':)']
# 0.8803097409257233
# ['ye', 'pk', 'hay', ':p']
# 0.5265151515151515
# ['hi', 'jacquelin', "we'r", 'sorri', 'hear', 'pleas', 'dm', 'us', 'contact', 'detail', 'give', 'call', ':)']
# 0.5648316283231606
# ['passion', 'beer', 'ultim', 'made', 'way', 'becom', 'full-fledg', 'busi', ':)']
# 0.6573825243316769
# ['thank', 'guy', ':)', 'fun', ':)', 'anoth', '1', ';)']
# 0.7867730304306014
# ['hi', "i'm", 'see', 'workplac', 'one', 'venu', 'list', "i'm", 'sure', 'fix', 'thank', ':)']
# 0.5641026123035119
# ['oh', 'wow', 'thank', ':)', 'skin', 'go', 'perfect', 'time', 'head', 'lago', 'travel']
# 0.6179058809814402
# ['wow', 'luxord', 'look', 'realli', 'amaz', 'new', 'kingdom', 'heart', '3', 'promo', 'art', ':)']
# 0.5945339974434797
# ['new', 'potato', 'garden', 'hundr', 'dig', ':)']
# 0.48906048906048905
# ['love', ':D']
# 0.8620689655172413
# ['thank', 'love', 'weekend', 'everyon', ':-)']
# 0.8050270897786165
# ['well', 'total', 'blew', 'mind', 'morn']
# 0.6886029060453612
# ['cours', "i'v", 'cite', 'academ', 'paper', 'feel', "i'v", 'arriv', ':-)']
# 0.44539495618037983
# ['life', 'smile', ':)']
# 0.7974766224766224
# ['thank', 'info', ':)']
# 0.9170660909791345
# ['sure', 'watch', 'pokiri', '1nenokkadin', 'tym', 'fav', ':-)', 'bajrangibhaijaanhighestweek', '1']
# 0.6895939799983797
# ['yang', 'retweet', ':)', ':D']
# 0.9581578331578332
# ["who'", 'still', 'awak', ':)']
# 0.575042721319317
# ['heritag', 'sword', 'made', 'wood', ':D']
# 0.6288135593220339
# ['right', 'thx', 'andrew', 'great', 'day', ':)']
# 0.8206631496891558
# ['true', ':)']
# 0.7496489996489997
# ['beleaf', 'u', ':-)']
# 0.6579558652729385
# ['cool', 'video', 'love', '...', ':)', 'thank', 'u']
# 0.7081014284671368
# ['season', '11', 'set', '♡', 'nice', 'friday', 'spnfamili', ':)', 'spn', '11', 'alwayskeepfight', 'jaredpadalecki', 'jensenackl']
# 0.5690176179831352
# ['cool', ':D']
# 0.9393939393939394
# ['exactli', ':D']
# 0.75
# ['peasant', 'seat', 'watch', 'peasant', 'team', '...', 'mind', ':p', 'ahahha']
# 0.4409863986541946
# ['chri', "that'", 'great', 'hear', ':)', 'due', 'time', 'remind', 'inde', 'plan', 'avail', 'distant', 'futur']
# 0.5138893507203316
# ['thank', 'shout-out', ':)', 'great', 'aboard']
# 0.8482872445813794
# ['hey', ':)', 'long', 'time', 'talk', '...']
# 0.5950390698917222
# ['matt', 'would', 'say', 'welcom', 'adulthood', '...', ':)']
# 0.6765931388311304
# ['could', 'say', 'egg', 'face', ':-)']
# 0.4135189422832443

# %%
neg_values = []
for i in test_neg:
    val = check(i)
    neg_values.append(val)
# Out:
# ['help', '...', 'stop', 'cri', ':(']
# 0.2688610771158464
# ['otl', 'nevermind', ':(', 'least', 'got', 'jeon']
# 0.31775775772058784
# ['soon', 'tweet', 'plant', 'claw', 'thigh', 'traction', 'zoom', 'away', ':(']
# 0.4497169347715199
# ['damnit', ':(']
# 0.25013646288209607
# ['use', 'pri', 'pv', '...', 'wish', 'could', 'reliv', 'day', 'becom', 'nyc', 'pv', 'buy', 'way', 'commun', 'nyc', 'usa', 'klm', ':(']
# 0.5874243583897542
# ['realli', 'hot', ':-(']
# 0.36006257226416377
# ['monday', ':(']
# 0.25013646288209607
# ['go', 'stop', 'breakfast', 'earli', 'might', 'want', 'remov', '11am', 'websit', 'even', "mcd'", 'pull', 'trick', ':(']
# 0.46944233888795195
# ['mean', 'way', ':(', '3rd', 'load', 'hung']
# 0.29923008336368523
# [':(', 'wtf', 'suppos', 'without']
# 0.26611597679913823
# ['headach', 'strike', ':(']
# 0.1667576419213974
# ['english', 'weather', 'need', 'fix', ':(']
# 0.28473122607947937
# ['live', 'fam', 'bam', 'cough', ':(']
# 0.5478323629306162
# ['absolut', 'gut', 'jame', 'bay', 'ticket', 'sold', 'manchest', ':(']
# 0.2991569227380679
# ['seventh', 'spot', 'na', 'lang', ':(', 'otwolgrandtrail']
# 0.28850702608890383
# ['splendour', ':(']
# 0.25013646288209607
# ['omg', 'swedish', 'hair', 'metal', 'legend', 'häirførc', 'studio', 'leav', 'nooo', ':(', 'givecodpieceach']
# 0.25269456980493377
# ['sore', 'alic', ':(']
# 0.5152424904062459
# ["i'm", 'readi', 'work', 'yet', ':(']
# 0.3621237505784076
# ['someon', 'unfav', ':(']
# 0.14224783799982874
# ['stile', ':(']
# 0.25013646288209607
# ['funni', 'mo', ':(']
# 0.4299155366582395
# ['someon', 'explain', 'sandrabland', ':(']
# 0.3566858784998716
# ['dont', 'sad', ':(', 'ili']
# 0.31697299334581
# ['go', 'spend', 'night', 'pragu', 'leav', 'tomorrow', ':(']
# 0.3532236537134884
# ['one', 'friend', 'follow', 'littl', 'heart', 'attack', 'im', 'sorri', 'your', 'block', ':(', 'sadi']
# 0.3694916328402649
# ["i'm", 'annoy', ':(']
# 0.18170017065702956
# ['consid', 'lucki', 'favourit', 'charact', 'even', 'make', 'season', 'final', '100', ':(']
# 0.45106394358240254
# ['boo', 'alreadi', 'turn', 'ye', '915', ':(']
# 0.32050003308191083
# ['itun', "i'm", 'wait', 'notanapolog', ':(']
# 0.37656588994000534
# ['layout', 'match', 'closest', 'could', 'find', 'header', ':(', 'someon', 'help']
# 0.3355748126188485
# ['hayee', ':(', 'hayee', ':(', 'patwari', 'mam', "ik'", 'vision', 'would', 'say', 'noth', 'rather', 'lil', 'laugh']
# 0.4690908268943027
# ['agh', 'sorri', ':-(']
# 0.03333333333333333
# ['vidcon', ':(', ':(', ':(']
# 0.0502046943231441
# ['ga', ':(']
# 0.5001364628820961
# ['awhhh', 'ok', 'ok', ':(', 'see', 'nalang', 'class', 'open', 'hehe']
# 0.47616201232770866
# ['last', 'night', 'one', 'worst', 'night', ':(', 'pretti', 'sure', 'albanian', 'women', 'curs']
# 0.4293333256741564
# ['air', 'max', 'tava', 'pl', 'pl', 'pl', 'pl', ':(']
# 0.3014230046094129
# ['taken', ':(', 'anoth', 'chara', 'mayb', 'teteh']
# 0.3470572721391499
# ['dev', 'verri', 'sad', 'caus', 'twitter', ':(']
# 0.27120950879138656
# ['imagin', 'would', 'shatter', 'dream', ':-(', "we'll", 'let', 'colleagu', 'know', 'sb']
# 0.5233982532194313
# ['much', 'miss', ':(']
# 0.15097418733585946
# ['nawe', ':(']
# 0.25013646288209607
# ['want', 'white', 'french', 'bulldog', ':(']
# 0.4377186271475891
# ['wanna', 'feel', 'love', ':(']
# 0.2894884003292573
# ['aww', 'poor', 'wish', 'help', 'even', 'though', "can't", 'realli', 'help', 'much', ':(']
# 0.2907122064499566
# ["i'm", 'sorri', 'see', 'tweet', ':(', '2', 'point', 'x']
# 0.420507065851182
# ['miss', 'macho', 'man', ':(']
# 0.24166979394104804
# ['hav', 'puriti', 'back', ':(']
# 0.23262637097593175
# ['kwento', ':(', 'fbc']
# 0.1667576419213974
# ['3', 'day', 'without', 'talk', 'bae', ':(']
# 0.37202940114253286
# ['whaaat', 'nooo', ':(']
# 9.097525473071324e-05
# ['pleas', 'tweet', 'someth', "i'm", 'sad', ':(', 'cheer', 'pleas', '..']
# 0.3819245614865111
# ['miss', 'brown', 'hair', ':(']
# 0.09275675046278717
# ['nakakapikon', 'yung', 'nagbabasa', 'ka', 'ng', 'blog', 'comment', 'info', 'full', 'peopl', 'ask', 'damn', 'question', 'answer', 'post', ':(']
# 0.5474426530983573
# ['lead', 'caus', 'cancer', 'children', 'five', ':(']
# 0.46234707492895266
# ['alon', ':-(', ":'(", ':-\\']
# 0.125
# ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', ':(', 'great']
# 0.6323818007198712
# ["i'm", 'sorri', 'peopl', 'shit', 'respect', 'person', 'space', ':(']
# 0.27499669585551795
# ['nooo', ':(', 'sogok', 'ice', 'cream']
# 0.17070393580218907
# ['thank', 'send', 'premium', 'write', 'instrument', 'howev', 'dastardli', 'swine', 'stole', 'envelop', ':(']
# 0.5118511810970067
# ['im', 'get', 'sick', 'tire', 'pipol', 'say', 'im', 'short', '...', 'short', '...', 'tini', ':(']
# 0.2978768818660271
# ['fair', 'enough', ':(', 'would', 'anyon', 'seem', 'tad', 'fuck', '😔', '..', 'wiper', 'wiper']
# 0.3691376623786942
# ['supposedli', 'one', 'worst', 'kernel', 'devic', ':(']
# 0.3609707942048459
# ["i'm", 'bore', ':(']
# 0.21027159922845814
# ['true', 'doubt', ':(', 'zayniscomingbackonjuli', '26']
# 0.25005458515283846
# ['today', '’', 'job', 'anoth', 'fack', 'intel', 'extra', 'mega', 'care', 'get', 'bent', 'socket', 'pin', ':-(', 'pcgame', 'pcupgrad']
# 0.5448582912825791
# ['hate', 'messeng', ':(']
# 0.05564653081028626
# ['everyon', 'asleep', 'alreadi', ':(']
# 0.33072299334580996
# ["they'v", 'brainwash', ':(']
# 0.1667576419213974
# ['1', 'pl', 'download', 'smosh', 'movi', 'free', 'onlin', 'hahahaha', ':(']
# 0.4447774691370928
# ['kik', 'plawnew', '837', 'kik', 'kikmenow', 'amateur', 'sf', 'snapm', 'summer', 'hotti', ':(']
# 0.2545477063785385
# ['omg', 'way', 'guy', 'aswel', ':-(', 'btw', 'cat', 'litter', 'isnt', 'good', 'pregnanc', 'make', 'sure', 'u', 'dont', 'go', 'near']
# 0.43278359953410794
# ['ah', 'mensch', ':(']
# 0.3149057900695455
# ['sepanx', 'one', ':(']
# 0.3116851781532814
# ['cannot', 'view', 'pictur', 'unhappi', 'seat', 'bu', ':(']
# 0.29948403056924905
# ["there'", 'huge', 'bag', 'present', 'luke', "can't", 'open', "he'", 'back', 'work', ':-(']
# 0.4142258908729375
# ['pci', 'mine', ':-(']
# 0.3412698412698412
# ['last', 'time', 'went', 'caerphilli', 'find', 'anywher', 'sell', 'local', 'chees', ':-(']
# 0.26224070224070223
# ['eye', 'realli', 'bad', 'today', 'even', 'glass', ':(']
# 0.36371616577362875
# ["i'm", 'omw', '😍', 'lol', 'wish', ':(']
# 0.4613188066640495
# ['joke', 'lang', 'eh', ':(', 'hahdhdhshh']
# 0.23005458515283844
# ['never', 'see', 'dad', 'midnight', 'bc', 'work', 'hard', 'fuck', ':(', 'growinguppoor']
# 0.3502872294580219
# ['number', 'one', 'america', '😭', '🇺', '🇸', 'wish', 'could', 'buy', 'money', ':(']
# 0.36364123886532534
# ['wish', 'buy', "bangtan'", 'merch', ':(']
# 0.253098063413708
# ['pain', 'ubericecream', 'driver', 'busi', ':(']
# 0.1973879184861718
# ['oh', 'gosh', 'say', 'aw', 'hun', ':(', 'cuddl']
# 0.2539138453481949
# ['want', ':(']
# 0.13596323453563938
# ['taimoor', 'meray', 'dost', ':(']
# 0.37506823144104806
# ['tya', 'mind', 'refollow', ':(']
# 0.44124470202928334
# ['stomach', 'kill', ':(']
# 0.06259097525473072
# ['apolog', 'avail', 'australia', ':(']
# 0.43062378699660364
# ['ksoo', 'u', 'dumb', 'butt', ':(']
# 0.29482810431660156
# ['omg', 'get', 'hate', 'sex', 'offend', ':(', 'poor', ':(', "i'm", 'stupid', 'pissbabi']
# 0.23815537241207335
# ['want', 'finish', 'death', 'parad', 'weekend', ':(']
# 0.36930481801594484
# ["i'm", 'frustrat', 'plank', 'time', 'super', 'inconsist', 'idea', "i'm", 'wrong', ':(']
# 0.38910139088463386
# ['rip', 'tom', 'moor', '...', 'love', 'read', 'comic', 'book', '...', 'anoth', 'great', 'artist', 'truli', 'miss', ':(']
# 0.410501590431253
# ['miss', 'much', ':(']
# 0.15097418733585946
# ['awww', 'miss', 'swear', 'twitter', 'day', 'truli', 'bore', 'rather', 'watch', 'movi', 'footbal', ':(']
# 0.3337025200057104
# ['sch', 'get', 'better', '...', ':-(']
# 0.2969430191238258
# ['throat', 'sore', ':(']
# 0.18190915707291253
# ['one', 'awak', ':(']
# 0.3116851781532814
# ['im', 'hungri', ':(']
# 0.13129341056675506
# ['get', 'bin', 'osx', 'chrome', 'voiceov', '>:(']
# 0.4958937198067633
# ['😂', '😂', 'night', ':(', 'devo', 'xxx']
# 0.4373867574686352
# ['im', 'sad', ':(']
# 0.10272198199532649
# ['hope', 'wrong', 'hulkhogan', 'think', 'know', 'deep', 'hurt', 'wake', 'kind', 'unpleas', ':(']
# 0.4026757670912417
# ['even', 'know', 'say', ':(']
# 0.3332807918275215
# ['daaamn', ':(']
# 0.25013646288209607
# ['grabe', 'ang', 'harsh', 'huhuhu', 'u', 'like', ':(']
# 0.18094712500685298
# ['aw', 'babe', ':(']
# 0.12237358395038289
# ['boy', 'r', 'play', ':(', 'cant', 'watch', ':(', 'rip']
# 0.30841132375354036
# ['dada', 'uh', 'iphon', 'na', ':(', ':(', 'pic', '—']
# 0.31470983983265644
# ['sorri', "i'm", 'fulli', 'book', ':-(', 'xx']
# 0.4331657088122605
# ['unfollow', 'unni', ':(']
# 0.45637512826019516
# ['lucki', 'spike', ':-(']
# 0.2894736842105263
# ['omg', 'miss', '2', ':(']
# 0.20846199597915172
# ["panic'", 'new', 'album', 'come', '22nd', ':(']
# 0.41670313553501326
# ['bigbang', 'need', 'rest', ':(', 'travel', 'one', 'place', 'anoth', 'must', 'realli', 'tire', ':(']
# 0.3353971722009184
# [':(', 'rude']
# 0.13650009924573242
# ['mention', 'south', 'africa', 'mani', 'time', 'song', 'time', 'come', 'south', 'africa', ':(']
# 0.6395030838382101
# ['hate', "can't", 'rememb', 'dream', 'love', 'share', ':(']
# 0.4072852249835418
# ['go', 'america', 'man', 'r', 'p', 'victim', 'louisiana', ':(']
# 0.2925763360970467
# ['school', 'come', 'twitter', ':(']
# 0.32820443215789397
# ['take', '190', 'horribl', 'time', ':(']
# 0.30071793506991973
# ['ella', ':(', 'cheer', 'pl']
# 0.262568231441048
# ["that'", 'excus', 'launch', 'attack', 'lizardz', 'feel', 'like', 'shit', 'deepli', 'asham', '>:(']
# 0.42767406220551274
# ['noth', 'wors', ':(']
# 0.17717430858806404
# ['sorri', ':(', 'need', 'get', 'emerg', 'engin', 'home', 'next', '4', 'hour', 'laura']
# 0.4270318626601084
# ['never', 'go', 'sleep', 'earli', ':(', 'lol']
# 0.37134197316284884
# ['home', 'dormtel', 'near', 'st', 'scho', 'girl', 'siya', 'tho', ':(', 'want', 'help', 'find', 'onee']
# 0.3673054609018188
# ['talk', 'exclus', ':(', 'u', 'know', 'carri', 'u', 'want', 'play', '😘']
# 0.42087623769263305
# ['7pm', 'friday', 'dead', ':(']
# 0.4359015647743814
# ['sorri', 'nat', 'school', 'holiday', '..', ':(', "i'm", 'work', '1pm']
# 0.23363127960595792
# ['im', 'work', ':(']
# 0.24123493103459134
# ['everi', 'time', 'feta', 'chees', 'head', 'start', 'blaaaz', 'sometim', 'vision', 'mess', 'nausea', 'come', ':(']
# 0.42408323737091763
# ['oh', "that'", 'good', ':(', "we'r", 'awar', 'issu', 'abl', 'top-up']
# 0.4840989129515264
# ['sharknado', 'one', 'hour', 'never', 'get', 'back', ':(']
# 0.39218684938379056
# ['yeah', 'leav', 'read', ':-(']
# 0.3415750915750916
# ['cannot', 'even', 'sleep', 'right', ':(']
# 0.3146758050284171
# ['erni', ':(']
# 0.25013646288209607
# ['tl', ':(', 'hungri', 'af']
# 0.15840156477438136
# ['rain', ':-(']
# 0.16666666666666666
# ['ezoo', 'year', 'sorri', ':-(']
# 0.26785714285714285
# ['look', 'fun', 'snapchat', 'lilybutl', '18', 'snapchat', 'kikmenow', 'amateur', 'kikmeboy', 'seduc', 'hannib', 'kiksext', ':(']
# 0.4050199362555036
# ['ed', 'sheeran', 'preform', 'countri', 'tonight', 'ur', 'go', ':(']
# 0.2808121165203271
# ['cannot', 'seem', 'get', 'one', 'powai', ':(']
# 0.3731648803119754
# ['neighbor', 'let', 'sleep', ':-(']
# 0.36947898799313894
# ['back', 'delhi', ':(']
# 0.4768351613012423
# ['feet', 'cold', 'point', 'take', 'sock', 'okay', 'stop', ':(']
# 0.30898045545044583
# ["can't", 'belieb', 'rain', ':(']
# 0.31419765415985623
# ['sinc', 'model', 'stop', 'stock', 'boot', "can't", 'get', "can't", 'even', 'order', 'onlin', 'tell', 'unsaf', ':(']
# 0.3508352629808025
# ['summer', 'holiday', 'great', "i'm", 'bore', 'alreadi', ':(']
# 0.3859729033446348
# ['oh', 'plan', 'stream', 'halo', 'xbox', 'one', 'today', ':(']
# 0.40890594602348423
# ['drop', 'dead', 'fred', 'use', 'favorit', 'movi', 'wish', ':-(']
# 0.4407147502256198
# ['rememb', '2', 'gaon', 'bad', '6', 'infnt', 'elig', 'apink', ':(', 'acub', "why'd", 'u']
# 0.4428088798506556
# ['sad', 'everi', 'time', 'apink', 'event', '..', 'understand', 'korean', ':(', '😭', '😭']
# 0.3329054384313825
# [':(', 'fun']
# 0.3462903090359422
# ['bullshit', '...', ':(']
# 0.31541514028420026
# [':(', 'know', 'happen', 'internet', 'light', 'connect', 'drop', 'thank', 'kei']
# 0.41139109260509804
# ['wish', 'could', 'hear', 'food', ':(']
# 0.2915542037645852
# ['hanaaa', 'birthday', 'ya', 'allah', 'sorri', 'wish', 'van', 'jn', 'tak', 'tau', ':(', 'happi', 'birthday', 'gorgeou']
# 0.5155593006125215
# ['omg', 'realli', "i'm", 'sorri', 'babe', ':(']
# 0.22551593942251738
# ['happen', 'soul', 'si', ':(']
# 0.36762775525057184
# ['faith', ':(']
# 0.37513646288209607
# ['last', 'present', 'receiv', '—', 'haha', 'basta', ':(']
# 0.48295215466099106
# ['went', 'bed', 'headach', '...', 'woke', 'headach', ':(']
# 0.19263716222390223
# ['snapchat', 'guy', 'jasmingarrick', 'snapchat', 'kiksext', 'chat', 'sext', 'addm', 'mpoint', 'hotmusicdeloco', ':(']
# 0.46017187998425163
# ['relat', 'full', 'lie', ':(']
# 0.3899491838220004
# ['aw', 'fuck', "there'", 'dress', 'bag', 'floor', 'dammit', "that'", 'realli', 'loud', ':(']
# 0.23333865577556476
# ['dhi', '👉', 'block', 'twitter', ':(', 'thank', 'good', 'time', '😢', 'play', '8ball', 'fakmarey']
# 0.4757352391137358
# ['unfortun', 'smell', 'like', 'doo', 'doo', ':(']
# 0.35534133225247827
# ['wanna', 'go', 'six', 'flag', ':(']
# 0.4262534508865879
# ['sorri', ':(']
# 0.05013646288209607
# ['shop', 'fun', ':(']
# 0.43086020602396147
# ['miss', 'cat', ':(']
# 0.1202656076076719
# ['miss', ':(']
# 0.03333958788209607
# ['would', 'like', 'abl', 'work', 'full', 'time', 'stuff', 'move', "i'm", 'consid', 'take', 'fulltim', 'job', ':(']
# 0.462731345876448
# ['yeah', "i'v", 'seen', 'someth', 'tinder', 'fb', 'root', ':(', 'woman', 'frustrat', 'awkward']
# 0.34852796110870554
# ['food', 'kitchen', 'money', 'wallet', 'thank', 'barcelona', 'dad', 'home', 'month', 'beet', 'juic', 'either', ':(']
# 0.41100211967501493
# ['dci', 'today', 'wish', 'go', ':-(']
# 0.3416282722426162
# ['work', 'freez', ':(']
# 0.1544769401670114
# ['srsli', 'u', ':(']
# 0.2136023960832247
# ['hate', 'see', 'granddad', 'like', ':(']
# 0.35474293203630725
# ['sorri', 'pre', ':(']
# 0.2000909752547307
# ['want', 'minion', 'bucket', 'pleas', ':(', 'yesterday', ':(']
# 0.26108138872909004
# ['fair', 'love', 'war', 'kapan', 'updat', ':(', 'oh', 'ya', 'udah', 'dihapu', 'hilang', 'dari', 'muka', 'bumi', 'want', 'read', 'someon', 'give', 'link', '😢']
# 0.43188869120536666
# ['girl', 'quick', ':(']
# 0.42231319747695295
# ['mani', 'nasti', 'narrow', 'mind', 'peopl', ':(']
# 0.5379471284701827
# ['want', 'room', ':-(']
# 0.19311528366646477
# ['friend', 'respect', 'life', ':-(', "i'm", 'sorri']
# 0.31723927413582587
# ['sadli', ':(']
# 0.04559100833664152
# ['suck', "i'm", 'gona', 'miss', 'chello', 'parti', ':(']
# 0.30261052560918883
# ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', ':(']
# 0.6027210164598121
# ["can't", 'watch', 'phone', 'sorri', ':(', 'thank', 'still', '<3']
# 0.37256185084194865
# ['taxi', 'driver', 'thought', 'sophi', 'work', 'nintendo', 'took', 'us', 'gate', ':(', 'secur', 'guard', 'gave', 'us', 'dirtiest', 'look', 'haha']
# 0.38646609267421367
# ['omg', ':-(', 'love', 'much', 'monica', 'see', 'soon', 'aaahhh']
# 0.4263344448194646
# [':(', 'crepe', '40', '—']
# 0.41256823144104804
# ['kick', 'bae', ':(']
# 0.12130309646685193
# ['haha', 'sound', 'like', '’', 'fun', 'game', ':(']
# 0.4772280272905222
# ['follow', ':(']
# 0.28293788132181236
# ['school', 'monday', 'wanna', 'meet', 'new', 'peopl', ':(']
# 0.3870867214886996
# ['...', 'havent', 'finish', 'yet', ':(']
# 0.3344523362030405
# ['u', 'forsaken', 'ran', 'gf', ':(']
# 0.34482810431660155
# ['kanin', 'pleas', ':(', 'xd']
# 0.2703210694183442
# ['get', 'hypixel', ':(', 'want', 'record', 'grrr', 'thestruggleisr', 'geek', 'gamer', 'gamer', 'youtub']
# 0.5895803660006451
# ['want', 'afterbirth', ':(']
# 0.25730882302375957
# ['bummer', ':(', "apink'", 'digit', 'physic', 'sale', 'super', 'great', 'bc', 'time', 'album', 'releas', 'win']
# 0.3477269103222514
# ['overperhatian', ':(', ':(']
# 0.1668486171761281
# ['sad', ':(']
# 0.02394598669161988
# ["that'", 'aw', ':(', 'son', 'miss', 'physic', 'exam', 'chicken', 'pox', 'gave', 'predict', 'grade', 'poor', 'girl']
# 0.36795127541411493
# ['srsli', 'tho', 'bae', 'look', ':(']
# 0.28089616743371987
# ['ahm', '...', "i'v", 'never', 'london', '...', 'holiday', 'outsid', 'ireland', 'nearli', '8', 'year', ':(', 'never', 'got', 'chanc', 'cash', 'go']
# 0.3691722632285958
# ['pleas', 'follow', ':(']
# 0.27118459373982534
# ['omg', ':-(']
# 0.10655737704918032
# ['5am', "i'm", 'wit', 'ha', 'damn', 'headach', ':(']
# 0.30453816837682224
# ['dream', 'met', 'karli', 'kloss', 'sweet', 'want', 'take', 'like', 'bunch', 'goofi', 'photo', ':(']
# 0.44077445155687456
# ['realiz', '3', 'watch', 'concert', 'video', 'pcd', 'extrem', 'hard', 'rn', ':(']
# 0.4175947254882638
# ['sorri', 'antagonis', 'call', 'writer', 'sever', 'polit', 'nudg', '...', ':(']
# 0.4830295365573185
# ['delv', 'enough', 'seen', 'heard', 'fuck', 'horrend', ':(']
# 0.38542000747375793
# ['follow', ':(']
# 0.28293788132181236
# ['duo', 'drop', 'doubl', 'digit', ':(', 'twice']
# 0.22226770984958757
# ['got', ':(', 'come']
# 0.2848982314905584
# ['theyr', 'cute', 'wish', 'knew', 'say', ':(']
# 0.28977839894948215
# ['care', ':(']
# 0.24013646288209606
# ['wish', "could'v", 'met', ':(']
# 0.172622579267135
# ['grandad', 'realli', 'well', ':(', 'worri', 'much']
# 0.43728152876530163
# ['u', "gray'", 'followk', 'omg', 'hard', 'day', 'u', 'know', ':(', ':(']
# 0.35351666169401497
# ['idk', 'bc', 'money', 'leav', ':-(']
# 0.12281573498964804
# ['lot', 'peopl', 'suggest', 'still', ':(']
# 0.5006506456273183
# ['follback', 'pl', ':(']
# 0.38254711560560795
# ['get', 'pace', 'maker', 'oh', ':(']
# 0.467258196461938
# ['ah', 'minc', ':(']
# 0.14823912340287884
# ['molli', 'deserv', 'much', 'higher', 'place', ':(']
# 0.4443477007467828
# ["i'm", 'hungri', ':(']
# 0.15947794843480734
# ['wanna', 'good', 'time', 'one', 'hit', 'date', 'much', 'ask', ':(']
# 0.4608364268691847
# ['feel', 'sucki', 'w', 'run', 'nose', 'cough', 'sore', 'throat', 'fever', ':-(']
# 0.2663340724316334
# ['hate', 'hot', 'weather', ':(', 'graduat', 'ceremoni', 'later', 'boy', 'gonna', 'wear', 'suit', 'everyon', 'go', 'die']
# 0.427647095675074
# ["let'", 'go', 'parti', '...', 'pant', 'ew', ':(', 'gross']
# 0.4061628102637995
# ['someon', 'niall', 'layout', 'give', ':(']
# 0.3404211665680132
# ['hey', 'christin', 'moodi', ':(']
# 0.43756823144104806
# ['miss', ':(']
# 0.03333958788209607
# ['throwback', ':(']
# 0.5001364628820961
# ['that', 'good', 'enough', 'reason', ':(', 'pleas', 'dont', 'leav', 'your', 'one', 'fav', 'barb']
# 0.45857111674248596
# ['cooper', "i'm", 'convinc', 'neither', '2', 'pleas', "i'm", 'concern', 'creasi', 'win', 'deputi', ':(']
# 0.29176533169430835
# ['tast', 'bad', 'though', ':(']
# 0.3682054863430088
# ['joke', 'man', ':(']
# 0.21675764192139738
# ['never', 'remov', 'minion', 'car', '23', 'day', 'run', 'batteri', "banana'", ':(']
# 0.3815835775625386
# ['want', 'sponsor', 'acc', 'new', 'even', '1k', ':(']
# 0.29895795569292855
# ['told', 'u', 'guy', 'bday', 'today', ':(', 'gift', 'want', 'paypal']
# 0.41429344507515686
# ['goodby', 'stage', 'alreadi', ':-(']
# 0.18841036414565826
# ['shit', 'idk', 'time', ':(']
# 0.18550366687648348
# ['today', 'tire', ':-(']
# 0.2044334975369458
# ['pretti', ':(']
# 0.2932399111579581
# [':(', 'matt']
# 0.41680312954876275
# ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', ':(', 'saludo']
# 0.5924489148138309
# ['hey', 'someon', 'text', ':(']
# 0.4141858784998716
# ['anoth', 'dissapoint', 'review', ':(']
# 0.4685025748753915
# ['😫', '<--', 'face', 'everi', 'guy', 'pull', 'get', 'head', 'feel', "bae'", 'teeth', 'dick', ':(']
# 0.36130696993671624
# ['ahhh', 'well', ':(']
# 0.25806198974748434
# ['wanna', 'see', 'paper', 'town', 'w', ':(']
# 0.2911469787288565
# ['get', 'long', 'last', 'black', 'pump', ':(']
# 0.3852249217198429
# ['omfg', 'beauti', 'place', 'ever', 'miss', 'much', ':(']
# 0.33083225540200434
# ['hate', 'pimpl', ':(']
# 0.2223131974769529
# ['almost', '12', "i'm", 'tire', ':(']
# 0.31060740398151937
# ['honey', 'brown', 'sugar', 'good', 'ur', 'lip', ':/', 'amount', 'stuff', 'use', 'face', "could'v", 'use', 'food', 'instead', ':(']
# 0.4088640761580316
# ['ikr', 'hai', 'would', 'someon', 'sell', 'preciou', 'thing', ':(']
# 0.3106748546463673
# ["i'm", 'tire', ':(', 'got', 'good', 'sleep']
# 0.31319536737926834
# ['yea', 'man', '...', 'suppos', 'footbal', 'tdi', 'man', 'plan', 'fail', ':(']
# 0.449419550997916
# ['pleas', 'god', 'wanna', 'go', 'work', ':(']
# 0.31010361437735856
# ['kinda', 'miss', 'pamela', 'good', 'anna', ':(']
# 0.3058646731939278
# ['pleas', 'woe', "can't", 'run', 'six', 'though', 'live', 'mexico', ':(']
# 0.36301856087929874
# ['idk', "i'm", 'get', 'mini', 'bu', 'idk', 'time', "i'm", 'go', 'get', ':(']
# 0.3076152978771913
# ['hi', 'harri', 'sorri', ':(', "we'r", 'work', 'mast', 'area', 'caus', 'intermitt', 'servic', 'work', 'complet']
# 0.5059313569812924
# ['look', 'fun', 'snapchat', 'janniecam', 'snapchat', 'kikm', 'webcam', 'snapchatm', 'kikhorni', 'musicbiz', 'hotmusicdeloco', ':(']
# 0.4422979323864636
# ['braxton', 'gone', 'pro', ':(', 'feel', 'bad', 'urban', 'unpreced', 'brainwash', 'see', 'tebow', 'alex', 'smith']
# 0.40056729160773
# ['wat', 'okaaay', 'huhu', ':(', 'sayanggg', 'find', 'yah', 'phone']
# 0.3269235253305219
# ['1', 'taxi', 'servic', '2', 'second', 'schedul', 'blog', 'post', '3', 'housework', 'bust', ':(']
# 0.5531028107378535
# ['mum', 'say', 'done', 'leav', 'step', 'dad', ':-(']
# 0.33344280240831964
# ['want', 'go', 'disneyland', 'badli', ':-(']
# 0.2340649279305203
# ['bc', 'thoma', 'tommyy', ':(']
# 0.28811170970191763
# ['billi', '...', ':(']
# 0.482081806950867
# ['fanci', 'kevin', 'clifton', 'strictli', 'come', 'danc', 'much', "he'", 'marri', ':(', 'whyyi']
# 0.3664858089285886
# ['nsc', 'mat', '0', 'tomorrow', ':(']
# 0.5088265149773998
# ['awhh', 'see', 'guy', "would'v", 'ram', 'car', ':(']
# 0.418414565431751
# ["that'", 'ok', ':(', 'reason', 'voucher', "can't", 'use', 'onlin']
# 0.4673431486052094
# ['kik', 'smadvow', '544', 'kik', 'kikgirl', 'lgbt', 'photo', 'model', 'free', 'hotti', ':(']
# 0.3771932090240412
# ["everyone'", 'work', "can't", 'even', 'get', ':(']
# 0.24088513836947448
# ['would', 'love', 'see', 'acdc', '..', 'miss', 'ticket', ':(']
# 0.4388436943006433
# [':(', 'aker', 'ive', 'send', 'ka', 'gmail', 'u', 'get', ':(']
# 0.3509010110579014
# ['last', 'stage', 'today', ':(', "i'm", 'go', 'miss', 'see', 'almost', 'everyday']
# 0.3180621208070298
# ['never', 'give', 'best', 'thing', 'take', 'time', 'weh', ':(']
# 0.4008938039972071
# ['guy', 'add', 'kik', 'sprevelink', '633', 'kik', 'hornykik', 'chat', 'porno', 'orgasm', 'free', 'webcamsex', ':(']
# 0.3649511565871709
# ['lana', ':(']
# 0.25013646288209607
# ['miss', '11:11', ':(', 'btw', 'wish', 'follow', '♥', 'loveyoutilltheendcart', '☺']
# 0.34349319976526294
# ['aw', 'sound', 'great', 'better', 'lunch', ':(']
# 0.3922941491329273
# ['want', 'play', 'sfv', 'capcom', 'plz', ':(']
# 0.3209058735001839
# ['tip', 'onlin', '6/7', 'winner', 'yesterday', '1', 'goal', 'nice', '20/1', ':(', 'hope', 'similar', 'strike', 'rate', 'today']
# 0.4692572332442042
# ['u', 'prob', 'fun', 'david']
# 0.6804327109205157
# ['sooo', 'burnt', '...', ':-(']
# 0.31982645710543545
# ['need', 'new', 'phone', ':(']
# 0.3802308616036782
# ['miss', 'tito', 'daddi', ':(']
# 0.10000312727438136
# ['rosi', 'hayoung', 'shut', ':(']
# 0.25006823144104806
# ['want', 'ram', 'nlb', ':-(']
# 0.44291338582677164
# ['hahahah', 'holi', 'shit', 'comfort', ':(']
# 0.1595140446122979
# ['could', 'flat', 'ab', 'time', '...', '@_', 'gym', 'tayo', 'g', ':(']
# 0.4594637233718098
# ['yeah', ':(']
# 0.23090569365132685
# ['first', 'two', 'day', 'kati', 'summer', 'back', 'forth', 'doctor', 'suspect', 'mening', 'viral', 'tonsil', ':(', 'poorli', 'girl', '😷']
# 0.482392242430214
# ['wanna', 'go', 'movi', 'today', 'one', ':(']
# 0.34338378944863496
# ['want', 'watch', 'paper', 'town', ':-(']
# 0.2090979638781107
# ["i'v", 'repli', 'yet', ':(', 'ang', 'given', 'work', 'next', '3', 'week', '😝', 'x']
# 0.4216983221140243
# ['say', ':-(']
# 0.2388888888888889
# ['babyy', ':(']
# 0.25013646288209607
# ['dont', 'either', ':(', 'ugli', 'cushion', 'littl', 'longer', 'thank', 'help']
# 0.4510923339891092
# ['happi', 'birthday', 'pleas', 'come', 'back', 'singapor', ':-(', '😿', '💓', '💓', '💕', '😚', '😚', '😚', '❤', '️', '❤', '️', '❤', '️', '❤', '️', '❤', '️']
# 0.4702821753063575
# ['weigh', 'risk', 'premium', 'go', ':(', 'lot', 'money', '1', 'reason', "i'm", 'keen', 'get', 'dog']
# 0.4305783254784312
# ['know', 'feel', 'man', ':(']
# 0.2808078920985242
# ['yeah', 'look', ':(']
# 0.3471995404484023
# ["can't", 'see', 'say', 'ice', 'cream', 'uber', 'app', ':(', 'set', 'locat']
# 0.31044818143306224
# ['wish', 'could', 'see', 'ben', ':(']
# 0.34888753709791853
# ['think', 'ever', 'win', 'petrofac', 'cup', ':-(', ';-)']
# 0.48141620284477427
# ['15', 'day', 'ago', 'danni', 'took', 'wig', 'put', 'onto', "mark'", 'head', 'want', 'go', 'back', ':(', '♥']
# 0.4176133649423988
# ['pathet', 'emot', 'burden.say', 'like', 'care', 'hug', 'respect', 'toler', 'call', 'name', ':-(']
# 0.3561000937699544
# ['allerg', 'cat', '...', 'itchi', 'throat', ':(']
# 0.2067271779852374
# ['like', 'dog', ':(']
# 0.28012710894940096
# ['man', 'right', 'wish', 'someon', 'would', 'bring', 'food', 'offic', "i'm", 'starv', ':(']
# 0.36051369200947003
# ['gosh', 'cheaper', 'malaysia', ':(', 'worth', '130', 'ship']
# 0.4697359590918543
# ['weather', 'set', 'sleep', 'respons', ':-(']
# 0.3597877358490566
# ['think', 'someon', 'hack', 'acc', ':(']
# 0.2293963218475163
# ['guy', 'nooo', ':-(', 'wow', 'wow', 'wow', 'wow']
# 0.5181771633384537
# ['boy', 'snapchattimg', 'happi', 'bc', 'friend', 'ruin', 'said', 'wanna', 'fun', '😏', '😏', ':(']
# 0.4406172909330051
# ['look', '12', 'still', ':(']
# 0.3495067657200079
# ['tbh', 'forget', 'donat', 'manag', 'sin', 'due', 'hp', 'corrupt', 'restor', 'data', 'lost', 'lor', ':(']
# 0.2815335993315701
# ['worst', 'pain', ':(']
# 0.18368071884447432
# ['never', 'dedic', 'anyth', ':(', 'smh', 'lol']
# 0.4825450824598074
# ['iren', 'unni', 'bite', 'finger', 'worriedli', 'stare', 'staff', ':(', 'okay', 'unni']
# 0.41669395924308594
# ['feel', 'sick', ':(']
# 0.07726515608744813
# [':(']
# 0.0002729257641921397
# ['guy', 'add', 'kik', 'toneadi', '46532', 'kik', 'kikmeboy', 'wife', 'porno', 'snapdirti', 'premiostumundo', 'sheskindahot', ':(']
# 0.4708424874785019
# ['omfg', 'hug', 'corps', ':(']
# 0.21100573144104803
# ['taeni', 'fyeah', 'link', 'broken', ':(']
# 0.37278185788011114
# ['hello', 'info', 'possibl', 'interest', 'jonatha', 'he', 'close', 'beti', ':(']
# 0.546424720163516
# ['cant', 'watch', 'tonight', 'andromeda', ':(']
# 0.30582713137482287
# ['la', 'time', 'right', 'ye', 'yunni', 'im', 'seriou', ':(']
# 0.3805556949350979
# ['develop', 'releas', 'good', 'game', 'school', ':(']
# 0.4257237441744705
# ['thank', 'feel', 'aw', 'sick', 'long', 'time', ':(']
# 0.29022132532218337
# ['lot', 'write', 'boy', 'section', 'whdjwksja', 'idk', 'ziam', 'write', 'still', 'fuck', 'go', '100k', 'school', ':(']
# 0.42544933845603783
# ['noo', "i'v", 'ben', 'watch', 'like', 'hawk', 'week', 'gut', ':(']
# 0.30583771650264885
# ['spoil', ':(']
# 0.5001364628820961
# ['none', 'hide', 'behind', 'shower', 'curtain', ':(']
# 0.3750454876273654
# [':(', 'want', 'good', 'least', 'watchabl', 'account', 'neither']
# 0.4029798018419905
# ['want', 'watch', ':(']
# 0.2104923436230105
# ['last', 'day', 'indiana', ':(']
# 0.2637171793923216
# ['fav', 'chees', 'give', 'migrin', ':(']
# 0.5217937155876211
# ['still', 'sad', 'fix', 'car', 'window', 'bc', "can't", 'drive', 'anywher', 'without', 'scare', "it'll", 'shatter', ':(']
# 0.3278339464458133
# ['morn', 'work', 'unfortun', ':(', 'gdce', 'gamescom']
# 0.3892805946256303
# ['hay', 'idk', 'babi', ':(', '😭', '😭', '😭']
# 0.08072682008271527
# ['oh', ':(', "do't", 'think', 'parcel', 'come', 'yodel', 'hit', 'follow', 'dm', 'track', 'num', 'chelsea']
# 0.5182395008408118
# ['wish', 'could', 'friend', 'everybodi', ':(', 'lmfaooo']
# 0.23597770948636068
# ['oooouch', 'poor', 'pinki', 'toe', '👣', 'good', 'thing', 'work', 'podiatrist', 'wait', 'morn', 'go', 'hurri', 'morn', ':(']
# 0.4614444630868059
# ['morn', 'miss', ':(']
# 0.27131064100564645
# ['miss', 'old', 'hous', 'could', 'hear', 'parent', 'door', 'open', 'act', 'like', "i'm", 'asleep', ':(']
# 0.36935768273112873
# ['gusto', 'ko', 'ng', "rodic'", ':(', 'someon', 'share', 'order', "one'", 'big']
# 0.4778046972445801
# ['adoohh', ':(']
# 0.25013646288209607
# ['b-butt', 'black', 'cat', 'bad', 'luck', 'ene']
# 0.35407066052227343
# ['miss', 'ticket', 'show', 'morn', ':(', 'get', 'tigermilk', 'fix']
# 0.41605381801896446
# ['ye', 'hope', 'next', 'year', ':(']
# 0.4351602637879289
# ['want', 'meet', 'jacob', 'bad', ':(']
# 0.270561764402491
# ['pleas', 'tell', ':(']
# 0.2572534893831891
# ['use', 'recommend', 'east', 'dulwich', 'gone', 'super', 'crazi', 'last', 'five', 'year', ':(']
# 0.446022604489725
# ['awww', 'miss', ':(']
# 0.1512586499859135
# ['last', 'episod', 'realli', 'intens', ':(', 'kagami', 'n', 'kuroko', 'forev', '<3']
# 0.4392595529232219
# ["can't", 'sleep', ':-(']
# 0.16779101226239415
# ["can't", 'say', 'nah', 'food', ':(']
# 0.19691367888344052
# ['want', 'see', ':(', 'sana', 'makita', 'na', 'kita', 'ang']
# 0.2985512481943494
# ['spooki', 'jim', 'smol', 'bean', ':(']
# 0.4000545851528384
# ['one', 'guy', 'true', 'blood', 'st', 'fagan', 'yesterday', ':(', ':(', ':(']
# 0.2659422725938601
# ['buy', 'book', 'memem', 'live', 'finland', ':(']
# 0.27319363577551353
# ['whaaat', 'fair', ':(']
# 0.11120208636584182
# ['nooo', 'stay', 'uk', 'im', ':(']
# 0.2296703552831425
# ['aw', 'poor', 'thing', ':(']
# 0.17533914108695767
# ['also', 'want', ':(']
# 0.2980495637645003
# ['look', 'amaz', 'think', 'saw', 'meadowhal', 'day', 'actual', 'unfortun', 'weekend', "i'll", 'work', ':(']
# 0.4846110402592671
# ['sorri', ':(', 'spend', 'time', 'instagram']
# 0.26251490261315585
# ['rip', 'lola', ':(', "i'll", 'miss', 'sorri', 'di', 'kita', 'nadalaw', 'last', 'day', 'thank', 'everyth', '..', 'sa', 'memori', 'sa', 'warm', 'hug', 'sa', 'lahat', 'labyu', 'la']
# 0.38207479295309205
# ['oki', ':-(']
# 0.0
# ['dont', 'want', 'anyth', 'happen', 'bae', ':(']
# 0.26951957575939706
# ['even', 'start', 'trend', 'wanna', 'know', 'jot', 'truth', ':(', 'zayniscomingbackonjuli', '26']
# 0.3023152492823283
# ['snapchat', 'guy', 'ivypowel', '19', 'snapchat', 'kikhorni', 'chat', 'girl', 'like', '4like', 'travel', 'phonesex', ':(']
# 0.43971933809716107
# ['schade', ':(']
# 0.00013646288209606986
# ['missin', 'homeslic', 'bday', ':(', '333']
# 0.2455091306073839
# ['poor', 'throat', ':(']
# 0.037128012291767744
# ['fav', 'emoticon', 'right', ':(', 'emoticon']
# 0.49625711679840806
# ['see', "i'd", 'get', 'eyebrow', 'done', 'prettylook', 'wanna', 'tri', 'differ', 'style', ':(']
# 0.48109503462222425
# ['rip', 'whitney', 'houston', ':(']
# 0.44325004962286624
# ['aur', 'ap', 'bhi', 'shamil', 'ho', ':(']
# 0.416712154294032
# ['much', 'past', '2', 'day', 'bc', 'need', 'save', '3g', 'feel', 'like', "i'v", 'miss', 'tonn', ':(']
# 0.3527303830604346
# ['hey', 'sorri', 'hear', ':(', 'check', 'servic', 'statu', 'page', '→']
# 0.5831402604170678
# ['hold', 'back', 'like', 'way', ':(']
# 0.3647987676735383
# ['amount', "i'm", 'eat', 'day', 'ridicul', 'know', "i'm", 'suddenli', 'alway', 'hungri', ':(']
# 0.3740373789605464
# ['omg', 'alli', 'hug', 'mani', 'wrap', 'arm', 'around', 'neck', 'pull', 'closer', ':-(']
# 0.42244901779870053
# ['love', 'toothsensit', ':-(']
# 0.2413793103448276
# ['ye', ':(']
# 0.3031667659123991
# ['heartbroken', ':(']
# 0.25013646288209607
# ['chover', ':(']
# 0.25013646288209607
# ['want', 'cebu', 'lechon', ':(']
# 0.3179816172678197
# ['head', 'kill', ':(']
# 0.19592430858806406
# ['want', 'kitten', 'badli', 'oh', 'god', ':(']
# 0.35851678754911925
# ['sleep', 'wake', 'time', ':(']
# 0.28301222664919423
# ['add', 'snapchat', 'jannygreen', '22', 'snapchat', 'kiksex', 'xxx', 'seduc', 'tagsforlik', 'nakamaforev', 'hotel', ':(']
# 0.3489752532925079
# ['probabl', 'fault', 'lost', 'phone', ':(']
# 0.1839373690356223
# ['told', 'suicid', 'kill', 'ran', 'away', 'forev', ':(']
# 0.3564950333509285
# ['mad', 'wrong', ':(', 'make', 'forgiv', ':(']
# 0.32620589806776673
# ['pleas', 'follow', 'conno', "i'm", 'late', 'time', 'zone', 'could', 'freak', 'never', 'see', ':(']
# 0.3574803373226482
# ['biggest', 'dream', 'u', 'follow', 'brooo', ':(']
# 0.43995722641040674
# ["i'm", 'lone', 'girl', 'england', ':(']
# 0.32235343572755115
# ['time', 'last', 'week', 'rout', 'lovebox', ':(', 'share', 'day', 'new', 'prod']
# 0.5661869093477225
# ['im', 'osad', ':-(']
# 0.25342465753424653
# ['hate', 'break', ':(']
# 0.2223131974769529
# [':(']
# 0.0002729257641921397
# ['still', 'happen', 'lot', 'unfortun', 'still', 'report', 'peopl', 'fall', 'scam', ':(']
# 0.3650585210574957
# ['eric', 'made', 'still', 'tell', 'love', ':-(', 'fake', 'ass']
# 0.40819221376037723
# ['miss', 'itb', 'omigod', ':(']
# 0.26666979394104806
# ['need', 'job', 'learn', 'drive', 'fricken', 'health', 'put', 'back', ':(']
# 0.43613133095335793
# ['hi', 'unfortun', "we'r", 'unabl', 'locat', 'origin', 'complaint', ':(', 'pl', 'dm', 'us', 'product', 'detail', "we'll", 'get', 'back']
# 0.42007412668334365
# ['miss', 'boyfriend', ':-(']
# 0.022135416666666668
# [':-(']
# 0.0
# ['ehem', '😏', '😏', 'haha', 'ala', 'yeke', ':(', 'okay', 'fun', 'kk', 'jumpa', 'next', 'time', '✈', '️', '🇺', '🇸', 'mayb', '😋']
# 0.4365974363978248
# ['come', 'home', 'empti', 'hous', 'ape', ':(']
# 0.4231391695445767
# ["i'v", 'shit', 'bestfriend', ':(']
# 0.3678315605807817
# ["i'm", 'gonna', 'inact', 'next', 'month', ':(']
# 0.25586586175402753
# ['miss', ':(']
# 0.03333958788209607
# [':(', 'well', 'tri', 'someth', 'keep', 'mind', 'bad', 'thing', "we'r", 'alway']
# 0.46803806495464534
# ["i'v", 'never', 'seen', 'felt', 'snow', ':(']
# 0.23668584178349603
# ["i'm", 'work', ':(', 'show', 'get', 'home', '1.2', 'lost', 'map', 'accid', 'lost', 'build']
# 0.36451825134556676
# ['dont', 'know', 'huhu', 'test', 'kasi', 'namin', 'didnt', 'finish', 'ap', 'test', ':-(']
# 0.28592116323574124
# ['want', 'hot', 'dog', ':(']
# 0.3237287437046013
# ['reject', 'section', 'uk', 'govt', 'e-petit', 'site', 'die', ':(']
# 0.38934570992342254
# ["i'm", 'sad', ':(']
# 0.13090651986337878
# ['cant', 'find', ':(']
# 0.18290199139908017
# ['oh', ':(', 'build', 'suit']
# 0.45689883253394425
# ['wanna', 'cut', 'k', "i'm", 'friend', 'threw', 'sleepov', 'parti', ':(', "i'm", 'pretend', 'ok', 'like', 'usual']
# 0.4065627122592703
# ['leav', 'alon', ':(']
# 0.08739256255631801
# ['pray', 'khami', '...', ':(', '...']
# 0.1784435831882019
# ['damn', 'forgot', 'hot', 'chocol', ':(']
# 0.29055704820702566
# ["i'm", 'crave', 'oreo', 'milk', ':(']
# 0.1606867690608844
# ['love', 'island', 'finish', 'feel', 'like', 'summer', 'gone', ':(']
# 0.42238401292639266
# ['miss', ':(']
# 0.03333958788209607
# ['push', 'client', 'way', 'host', 'mayb', 'better', 'wait', 'till', 'next', 'week', ':(']
# 0.4733133649958203
# ['im', 'irk', ':(']
# 0.25351563278897726
# ['someon', 'say', 'thank', 'u', 'goodby', 'chri', 'tomorrow', 'pl', ':(']
# 0.36213061648068945
# ['need', 'nate', 'ruess', 'album', ':(']
# 0.34633836893662223
# ['could', 'realli', 'use', 'hug', 'mayb', 'icecream', ':(']
# 0.3871897479127628
# ['lot', 'good', 'comic', 'event', 'seem', 'kid', ':(', 'part', 'school', 'program']
# 0.5245273360143492
# ['look', 'like', 'dog', 'food', '...', ':(', 'ugh']
# 0.3201630079970235
# ['miss', 'bad', ':(']
# 0.09085384290178954
# ['aigoo', 'babi', ':(']
# 0.27169591352633565
# ['want', 'watch', 'paper', 'town', ':-(']
# 0.2090979638781107
# ['wanna', 'recov', ':(']
# 0.07753205269580815
# [':-(', 'poor', 'boy']
# 0.2254428341384863
# ['u', 'guy', 'togeth', ':(']
# 0.37256738846026805
# ['saw', 'one', 'doujin', 'think', 'killua', 'get', 'fuck', 'ging', 'bit', 'sad', 'caus', 'didnt', 'show', 'dick', 'hope', 'ginggon', ':(']
# 0.3772485294777407
# ['comput', 'broken', 'wait', 'fix', 'miss', 'much', 'twitter', 'guys.al', 'love', '..', ':(']
# 0.4166621726604971
# ['feel', 'like', 'ytd', ':(']
# 0.3020668764274979
# ['joe', "i'm", 'sick', 'come', 'round', 'make', 'soup', ':(']
# 0.30533739246979946
# ['cri', ':(', 'pdapaghimok']
# 0.21860949377324923
# ['stori', 'life', ':(', 'haha', 'look', "who'", 'talk']
# 0.46801951890768656
# ['work', ':(', 'smh']
# 0.2655880512781225
# ['anyon', 'awak', ':-(']
# 0.27777777777777773
# ['ya', 'sorri', ':-(']
# 0.24444444444444444
# ['friend', ':(']
# 0.28585074859638177
# ['use', 'flexibl', ':(']
# 0.3360698112335667
# ['taxi', 'driver', 'go', 'realli', 'fast', "i'm", 'scare', ':(']
# 0.27571659051548414
# ['bet', 'wonder', 'happen', ':(']
# 0.35096108858390523
# ['sheet', 'hurt', 'nanaman', ':(']
# 0.2770952584680751
# ['need', 'small', 'ladi', 'walk', 'back', 'sore', '...', ':(']
# 0.4054536526429222
# ['want', 'meet', ':(']
# 0.27119771191264846
# ['alex', 'fell', 'asleep', ':(']
# 0.2479848981077147
# ['justin', 'come', 'scotland', ':(']
# 0.4084015647743814
# ['ok', "i'll", 'write', 'u', 'everi', 'week', ':(']
# 0.5059089003893308
# ['curv', 'tummi', 'big', '..', 'get', 'flat', 'ab', ':(']
# 0.327296517167708
# ['look', 'like', ':(']
# 0.3622784091858076
# ['feel', 'sick', 'stomach', 'hurt', "i'v", 'done', 'cri', 'night', "can't", 'sleep', ':(']
# 0.23585329250286166
# ['wait', 'gone', 'liter', ':(']
# 0.27061157698439364
# ["that'", 'quot', 'tweet', ':(']
# 0.4106822665287674
# ['cream', 'pinay', 'pie', 'soup', ':(']
# 0.4697515548498082
# ['one', ':(']
# 0.21752776722992215
# ['jadi', 'langsung', 'flasback', '..', ':(', 'dont', 'cri', 'babyy', ';(']
# 0.3227698900466975
# ['okay', 'miss', ':(']
# 0.1944486141436196
# ['listen', 'album', 'live', 'franc', ':(']
# 0.44033236293061623
# ['time', 'like', 'style', ':|', 'like', ':(']
# 0.5486001398405542
# ['feel', 'sick', ':(']
# 0.07726515608744813
# ['account', 'meant', 'hit', 'us', 'lunch', 'time', ':(']
# 0.43862331853220915
# ['miss', 'lo', ':(']
# 0.18889305858806404
# ['pl', 'stop', 'say', 'rude', 'nicknam', 'involv', 'short', 'im', 'sick', 'yall', ':(']
# 0.3596036994055206
# ['miss', ':(']
# 0.03333958788209607
# ['pl', 'write', 'english', ':(', 'dont', 'understand']
# 0.27297929272835314
# ['snow', 'cold', 'gross', 'ew', 'big', 'mess', 'everyon', 'scrape', 'pile', 'anyway', ':(']
# 0.38481426440437955
# ['hey', 'went', 'home', 'na', ':(']
# 0.30581804091629416
# ["i'm", 'still', 'hope', ':(', 'zayniscomingbackonjuli', '26']
# 0.1935722380193784
# ['nigga', 'dalla', 'look', 'like', ':(', 'sale', 'sare', 'bandar', 'varg']
# 0.315203914173047
# ['hammer', 'right', '...', 'look', 'set', 'day', '...', ':(']
# 0.44678503333539643
# [':(', 'vidcon', ':(']
# 0.0668486171761281
# ['abbi', ':(']
# 0.25013646288209607
# ['feel', 'like', 'cri', 'reason', 'right', ':(']
# 0.3523444147873607
# ['poor', 'must', 'tire', ':(']
# 0.19222329859611517
# ['ur', 'crazi', 'af', 'hurt', 'much', 'bc', 'u', 'know', 'shit', 'aint', 'real', 'edit', ':(']
# 0.3560302179154258
# ['forev', 'miss', 'love', 'lolo', ':(']
# 0.34149675469306834
# ['xbsbabnb', 'poor', ':(']
# 0.20379467895843442
# ['although', 'mum', 'ask', 'watch', 'w', '…', 'stilll', ':(', 'read', 'yet', "she'd", 'ask', 'question', 'middl', 'movi']
# 0.3806961948218481
# ['work', '5', 'everyday', 'exhaust', ':(']
# 0.3414041128181556
# ['end', 'state', 'last', 'night', ':(', ':(', ':(', ':(']
# 0.21559139485488518
# ['tbh', 'prefer', 'apma', '14', 'idk', 'man', 'there', 'someth', 'right', 'year', 'apma', ':(']
# 0.34919250527908335
# ['u', 'give', '350', 'ill', 'give', 'u', '350', '350', 'rt', 'anyth', 'pl', ':(']
# 0.3242174588152719
# ['lmao', 'back', 'get', 'realli', 'realli', 'seriou', '...', ':(']
# 0.323160792371383
# ['wonder', 'happen', 'earlier', 'realiz', 'leadership', ':-(', 'wakeupgop']
# 0.4758658008658009
# ['ah', 'dude', ':(']
# 0.27323912340287887
# ['wanna', 'take', 'adam', 'candi', 'eat', ':(']
# 0.3047509167109039
# ['pleas', 'watch', "infinite'", 'mv', ':(']
# 0.2215003012275593
# ["can't", 'believ', 'ill', 'go', 'work', 'today', 'wish', ':(']
# 0.32332332557693655
# [':(', 'hate', 'school', 'u', 'dont', 'understand', 'miss', 'lot', 'blame', 'school']
# 0.317712630662283
# ['like', "can't", 'actual', 'put', 'pressur', 'ankl', 'hop', 'around', 'hous', 'lost', 'balanc', 'fell', ':(']
# 0.24695219121207565
# ['bull', 'shark', ':(', 'late', 'trafficcc']
# 0.2667212518195051
# ['miss', 'oscar', ':(']
# 0.35555972525473073
# ['need', 'translat', ':(']
# 0.25084172600548144
# ['last', 'time', 'one', 'work', ':(', 'fb', 'gone', 'check', 'long', 'time', 'lol']
# 0.42561220834831576
# ['asian', 'ummm', 'mayb', 'ur', 'film', 'child', 'pornographi', 'slutsham', 'fake', 'suicid', 'ect', ':-(']
# 0.5091435185185185
# ['poland', 'faraway', 'germani', 'girl', ':(', 'still', 'believ', 'one', 'day', 'meet']
# 0.39159515626715574
# ['good', 'quit', 'full', 'time', 'job', 'last', 'week', "can't", 'find', 'anoth', 'one', ':(']
# 0.46737154573963474
# [':(', 'well', 'cooki', 'better', 'worth']
# 0.49114961382288247
# ['lmao', 'catch', 'point', 'watch', 'weekli', "i'll", 'ok', 'make', '700', "there'", '800', 'ep', ':(']
# 0.48170541280074397
# ['cake', 'look', 'amaz', "can't", 'believ', "i'm", 'miss', ':(']
# 0.3492023518464343
# ['keep', 'forget', 'area', ':-(', 'want', 'visit', 'next', 'time', 'xx']
# 0.5403823327468624
# ['make', 'want', 'watch', 'whole', 'film', 'cgi', 'kick', 'oop', 'pun', 'start', 'grumbl', 'turn', ':(']
# 0.41325782595509913
# ['see', 'delph', 'anoth', 'kit', 'upset', ':(']
# 0.22933841692029466
# ['miss', ':(', 'haha', "x'", '😂', '😂', 'still', 'rememb', 'u', 'hate', 'xxx']
# 0.36961192984949415
# ['zayniscomingbackonjuli', '26', 'funni', ':(']
# 0.19743665249367962
# ["we'r", 'allow', 'cheat', 'meal', ':(']
# 0.19116569626394955
# ['fun', 'osaka', 'super', 'junior', ':(', 'would', 'love', 'watch', 'comeback', 'stage', 'though']
# 0.48621347864967834
# ['aytona', 'hala', 'guy', 'get', 'readi', 'na', 'mathird', 'wheel', ':(', 'jkjk']
# 0.39322109269869066
# ['worst', 'day', 'ever', ':(', 'pain', '...']
# 0.3416825486519624
# ['backtrack', '3', 'hour', ':(', '...', 'time', 'start', 'actual', 'util', 'list']
# 0.45921509169788094
# ['surviv', 'anoth', 'week', 'without', 'phone', ':(']
# 0.3635767726596646
# ['wish', ':(']
# 0.15774515853426999
# ['pat', 'jay']
# 0.75
# ['sad', 'stori', 'broh', ':(']
# 0.256020612393429
# ['uh', 'asleep', ':(']
# 0.09731319747695294
# ['need', 'boyfriend', 'rn', 'answer', 'calll', ':(']
# 0.25908099372169496
# ['icaru', '500', 'awn', 'unfortun', 'fit', '600', 'size', ':(']
# 0.32815911572052403
# ['2', 'bach', ':(']
# 0.35144232660608204
# ['6', 'day', 'left', ':(']
# 0.3909162534663957
# ['pleas', 'babi', 'follow', ':(']
# 0.28209214900857277
# ["there'", 'noth', ':-(']
# 0.2406798245614035
# ["can't", 'feel', 'tomorrow', ':(']
# 0.22963411115600516
# ['give', 'work', 'old', 'staff', 'come', 'polic', 'later', 'court', 'look', 'anoth', 'job', ':(', 'bye', 'bye']
# 0.4889895071897782
# ['landlord', 'like', "mp'", 'though', "that'", 'go', 'easi', ':-(']
# 0.4089044547225503
# ['look', 'old', 'photo', 'get', 'sad', ':(']
# 0.3659390198098275
# ['oh', ':(', 'hope', 'everyth', 'okay']
# 0.3696367130859789
# ['want', 'want', 'want', 'follow', 'want', 'want', 'want', "that'", 'crazi', ':(', 'pleas', 'love', '(:', '♡', '♡']
# 0.363655401147284
# ['bullshit', ':(']
# 0.25013646288209607
# ['nugget', 'fri', ':-(']
# 0.08333333333333333
# ['love', 'warrior', ':-(']
# 0.2413793103448276
# ['tire', 'eat', ':(']
# 0.08915623098665311
# ['dame', 'assign', ':(']
# 0.23342430858806404
# ["i'm", 'watch', 'gossip', 'girl', 'make', 'sad', ':(']
# 0.4075570074579285
# ['tomorrow', ':(']
# 0.2720662874434996
# ['still', 'realli', 'miss', 'purpl', 'hair', 'tie', ':(']
# 0.2891386991067968
# ["can't", 'deal', 'match', 'unless', 'ishii', 'fuck', 'everyth', ':(']
# 0.306912259915749
# ['clara', 'yile', 'left', ':(']
# 0.32819323144104806
# ['whatev', 'stil', 'l', 'young', '>:-(']
# 0.48571428571428565
# ['last', 'chanc', ':(']
# 0.20335894911093988
# [':(']
# 0.0002729257641921397
# ['look', 'like', 'cri', 'look', 'like', 'cri', 'bit', ':(']
# 0.381992151486292
# ['come', 'onlin', 'follow', 'peopl', ':/', 'z', 'wrong', 'u', 'ignor', 'sidharth', ':(', ':(']
# 0.28027790644984724
# ['lol', "i'm", 'lazi', 'learn', 'ps', ':(']
# 0.32544924144665827
# ['sleep', "i'm"]
# 0.3375081327260898
# ['bad', 'day', ':-(']
# 0.2757149371376457
# ['tagal', ':(']
# 0.00013646288209606986
# ['oh', 'ndabenhl', ':-(', 'pleas', 'let', 'us', 'know', 'feel', 'way', 'sa']
# 0.41109675624568054
# ["i'v", 'got', 'one', 'poorli', 'doggi', ':(']
# 0.26728491881752586
# ['repli', 'pleas', 'antag', ':(']
# 0.2605171478497168
# ['window', '7', ':(']
# 0.29064355992496244
# ['well', "i'm", 'p', '41', '8', 'page', 'note', 'thu', 'far', ':-(', "i'v", 'read', 'twice']
# 0.4803859736423197
# ['want', 'kyli', 'jenner', 'cloth', ':(']
# 0.18771862714758908
# ['ye', 'unfortun', 'done', 'whole', 'troubleshoot', 'box', "i'm", 'still', 'issu', ':(']
# 0.36139419236775044
# ['miss', "convo'", 'bad', 'damn', ':(']
# 0.1785123057410737
# ['dem', 'free', 'tix', 'big', 'bang', 'concert', ':(']
# 0.5030783111842064
# ['your', 'gonna', 'guess', 'what', 'insid', 'box', ':(']
# 0.2923008941567894
# ['idk', ':-(', 'mayb', 'think', 'boob', 'fun', 'play']
# 0.34475382595683346
# ['jahat', ':(']
# 0.00013646288209606986
# ["we'r", 'sorri', ':(', 'longer', 'abl', 'access', 'site', 'automat', 'redirect', 'local', 'site']
# 0.3787907315033763
# ['mad', 'gigi', 'dream', 'hang', 'didnt', 'want', 'talk', ':(']
# 0.353146652789754
# ['carter', 'deserv', 'hate', ':(', 'deserv', 'singl', 'corn', 'chip', 'deserv', 'two', 'corn', 'chip']
# 0.5724433787343176
# ['nnnooo', 'cz', "he'", 'daddi', 'gorilla', 'anymor', '...', ':(']
# 0.34680079254910384
# ['still', '6', 'hour', 'work', 'left', 'omg', ':(']
# 0.337298078820965
# ['link', 'miss', 'hbm', ':(']
# 0.28939706666832077
# ['freak', 'humid', 'think', 'never', 'get', 'use', 'even', "i'm", '100', 'japanes', ':(']
# 0.44681469408177393
# ['school', 'work', ':(']
# 0.25125113371539853
# [':(', 'longer', 'admir', 'consist', 'jason', "shackell'", 'hair', 'podcast']
# 0.4880775939813936
# ['envi', 'peopl', 'get', 'meet', 'pictur', 'laura', 'taylor', 'lana', 'etc', "they'r", 'lucki', 'meet', 'babi', ':(']
# 0.41199258178494585
# ['want', 'sa', 'bday', 'ko', ':(', ':(', ':(', '<3']
# 0.3135982736516002
# [':-(', 'pleas', 'notic', 'gonna', 'spam', 'u', 'till', 'u', 'follow', 'babi']
# 0.35697702558471234
# ['kik', 'twer', '782', 'kik', 'kikhorni', 'lesbian', 'hornykik', 'girl', 'countrymus', 'hornykik', ':(']
# 0.27653511291139965
# ['need', 'hug', ':(']
# 0.25431394822770365
# ['word', 'explain', 'much', 'miss', 'hope', 'know', ':(']
# 0.4421785611052113
# ['oh', 'gfriend', 'perform', 'rn', ':(']
# 0.16368900066767827
# ['ok', ':-(', 'w', 'hahaahahahaha']
# 0.3842592592592593
# ['sm1', 'bad', 'mean', 'got', 'mutil', 'robot', 'shot', 'wall', 'know', 'could', 'destroy', '...', '>:(']
# 0.4433336308674872
# ['dare', ':(']
# 0.37513646288209607
# ['good', 'morn', 'twitter', 'friend', 'hope', 'amaz', 'day', 'freakin', 'tire', 'need', 'sleep', ':(']
# 0.49070952016193986
# ['😢', 'haestarr', '’', ':(']
# 0.2399330963059129
# ['wish', 'help', ':(']
# 0.2574268135084434
# ['good', 'alway', '😀', 'fli', 'back', 'today', 'though', ':(']
# 0.47164008758997494
# ['need', 'car', 'function', 'car', ':(']
# 0.20883836893662222
# ['wish', 'twitter', 'would', 'support', 'audio', 'record', 'would', 'send', 'yall', 'snippet', 'amaz', ':(']
# 0.5053024185619622
# ['et', 'brotherhood', 'steel', ':(']
# 0.37506823144104806
# [':-(', 'pleas', 'notic', 'mefd']
# 0.27025283797729616
# ['miss', 'diana', ':(']
# 0.18889305858806404
# ['master', 'figur', 'turn', 'led', 'gold', "we'r", 'doom', ':(']
# 0.5538535601649685
# ['want', 'pull', 'nighter', "i'm", 'sleepi', 'alreadi', ':(']
# 0.20477438884926316
# ['ever', 'wanna', 'sleeep', ':(', 'let', 'mee']
# 0.2186902687721465
# ['oh', 'allow', 'vote', 'teen', 'choic', 'award', ':(', 'said', "i'm", 'area']
# 0.47671198860396435
# ['want', 'icon', 'selfi', 'jack', ':(']
# 0.41188529381425576
# [':-(', 'pleas', 'notic', 'meowkd']
# 0.27025283797729616
# ['twitter', 'turn', 'much', 'complic', "can't", 'find', 'trend', ':(']
# 0.4070352332663343
# ['right', "i'm", 'tire', ':(', 'good', 'night', 'alli', 'love', '❤', '️']
# 0.4552973215150392
# ['😂', 'wish', 'channel', 'watch', ':(', 'usual', 'watch', 'onlin', 'laptop', 'anymor', ':/']
# 0.33434857056907474
# ['rude', ':(']
# 0.13650009924573242
# ['would', 'want', 'peopl', 'understand', 'busi', 'daili', 'schedul', '😞', "c'mon", 'guy', 'bare', 'even', 'get', '5', 'hour', 'sleep', ':-(']
# 0.3629722240523994
# [':(', 'kill']
# 0.09388646288209607
# ['think', 'she', 'busi', ':(']
# 0.3363777552505719
# ["swimmer'", 'ear', 'kasi', ':(']
# 0.29814515451797113
# ['want', 'bday', 'answer', 'pleas', '—', 'idk', 'leh', ':(', 'b']
# 0.3490357399293668
# ['yeahhh', '...', ':(', 'tht', 'corner', 'b', 'rememb', 'alway', 'coz', 'gg', '...', ':(', 'n', 'bb', 'didnot', 'show', 'th', 'clip', 'episod', ':(']
# 0.34452524576052707
# ['releas', 'onlin', 'album', 'know', ':(']
# 0.35146123476920677
# [':-(', 'pleas', 'notic', 'h']
# 0.22858617131062953
# ['😂', '😂', '😂', 'thank', 'san', '😀', 'wanna', 'chang', 'avi', 'usanel', ':(']
# 0.45701713348839573
# ['sad', 'day', 'nathan', ':(']
# 0.41728860796375017
# ['noo', 'sad', 'time', ':(', 'rubi', 'replac', 'shuffl', 'act']
# 0.15529205222846051
# ['got', 'excit', 'micha', 'rt', 'fave', 'tweet', 'creep', ':-(']
# 0.5665348639455783
# ['anyon', 'wanna', 'friend', "i'm", 'lone', 'girl', 'england', 'bore', 'hell', 'throughout', 'summer', 'holiday', '..', ':(']
# 0.3678168829504956
# ['home', 'alon', ':(']
# 0.0926835678473233
# ['whose', 'idea', 'ave', 'tripl', 'busi', 'lectur', 'friday', 'afternoon', '2-5', ':(']
# 0.5846652854079605
# [':(']
# 0.0002729257641921397
# ["that'", 'damn', 'lie', ':(']
# 0.2304441712906721
# ...
# ['lolliv', ':(']
# 0.25013646288209607
# ['im', 'watch', 'disney', 'channel', ':(']
# 0.29068615869960357
# ['nobodi', 'pick', 'one', 'right', ':(']
# 0.32433917966307957
# ['someon', 'gift', ':(', 'calibraskaep', 'need', 'bad']
# 0.24817413097659693
# ['lol', 'got', 'split', 'hard', 'lol', 'singl', 'singl', 'split', 'collat', 'spilt', 'singl', 'singl', 'spilt', 'singl', 'split', 'singl', 'singl', 'collat', ':(']
# 0.5263501999294014
# ['hope', 'feel', 'better', 'jay', ':(']
# 0.46375885765538116
# ['ye', 'mani', 'time', ':(', 'quitkarwaoyaaro']
# 0.41784790294615626
# ['stu', 'deacti̇v', ':(']
# 0.1667576419213974
# ['disappoint', ':(', 'never', 'ever', 'lucki', 'handl', 'jabongatpumaurbanstamped']
# 0.3488337658753136
# ['hello', 'need', '2.5', 'g2a', 'code', 'pl', ':(']
# 0.4017391858319232
# ['thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'sherep', 'nemen', 'ng', 'behey', 'ke', ':(']
# 0.15626705786026202
# ['deactiv', 'acc', ':(', 'otwolgrandtrail']
# 0.19173489810771469
# ['still', 'sad', 'kick', 'epic', 'motherfuck', ':(']
# 0.3017172201501617
# ['realli', 'want', 'anoth', 'tattoo', ':(']
# 0.4294614996596923
# ['someon', 'get', 'mad', 'reec', 'vm', 'tomorrow', 'pleas', 'never', 'one', ':(']
# 0.3825810916208225
# ['deth', 'deth', 'dont', 'leav', ':(']
# 0.2964355375337908
# ['true', ':-(']
# 0.25
# ["let'", 'go', '더쇼', 'cast', 'vote', 'got', '7', 'today', ':(']
# 0.35685562897948286
# ['someon', 'hug', 'pl', ':(']
# 0.24262337849987156
# ['omg', ':(', 'gonna', 'happen', 'yeah', 'wish', '..']
# 0.2882933693736307
# [':(', 'lest', 'gp', 'get']
# 0.368908811151193
# ['aww', ':(', 'catch', 'departur']
# 0.34261630836412493
# ['appar', 'isnt', ':(']
# 0.2686094937732492
# ['miss', 'day', ':(', 'toothsensit']
# 0.17198540855898822
# ['unavail', ':(']
# 0.00013646288209606986
# ['mean', "can't", 'wipe', ':-(']
# 0.2501926411096128
# ['found', 'flight', 'home', '13', 'hour', 'long', ':(']
# 0.39026574676449916
# ['ugh', 'yuck', ':(', 'make', 'sure', 'rest', 'next', 'two', 'day']
# 0.401161297920234
# ['omg', 'sad', 'birthday', 'sorri', 'didnt', 'send', 'someth', 'ystrday', 'ill', 'later', 'cuz', 'dont', 'phone', ':(']
# 0.35571899402675344
# ['seolhyun', 'isnt', 'first', 'ep', 'she', 'film', 'drama', ':(']
# 0.5251333220697303
# ['sorri', ':(']
# 0.05013646288209607
# ['alway', 'get', 'like', '5', '4', 'piec', 'spici', 'nugget', ':(']
# 0.34743343964956597
# ['im', 'sooo', 'hungri', 'though', ':(']
# 0.19877604634005303
# ['thigh', 'cramp', ':-(']
# 0.16666666666666666
# ['fellow', 'morn', 'owl', 'sure', 'notic', 'sun', 'alreadi', 'rise', 'bit', 'later', '...', 'sign', 'winter', 'come', ':(']
# 0.49671251403926725
# ['nowher', 'near', 'tire', ':(']
# 0.23816346953628612
# ['hot', ':(']
# 0.34496404908899264
# ['dude', ':(', "i'm", 'scare', 'lol']
# 0.2798248040217042
# ['rain', 'whole', 'day', 'mumbai', '’', 'feel', 'like', 'work', ':(']
# 0.4354237761160801
# ['best', 'get', 'littl', 'ladi', "pj'", 'need', 'go', 'wallpap', 'mom', ':(', 'realli', 'cba', 'today']
# 0.4723633066780763
# ['ye', 'pl', 'far', 'need', ':(']
# 0.3383838234820768
# ['even', 'know', 'could', 'get', 'hotter', 'fml', ':(']
# 0.3085221538277058
# ['aw', 'bless', 'made', 'smile', "i'm", 'miss', ':(']
# 0.4066070231079802
# ['hi', 'life', ':(']
# 0.4667576419213974
# ['mood', 'whole', 'day', ':-(']
# 0.4261489479512735
# ['almost', 'done', 'park', 'rec', ':(', 'lol']
# 0.5134760613700299
# ['u', 'come', 'back', ':(']
# 0.3427599365973023
# ['hi', "we'r", 'sorri', 'hear', ':(', 'log']
# 0.45533038791226566
# ['gotdamn', ':-(']
# 0.25
# ['want', 'phone', 'baaack', ':(']
# 0.28821971250591494
# ['honest', 'miss', 'dubai', 'dubai', 'miss', 'want', 'come', 'back', ':(']
# 0.25573757709749784
# ['final', 'get', 'star', 'driver', 'srw', 'mobag', ':(']
# 0.41163991434984687
# ['sad', 'reason', 'suck', 'u', 'dunno', 'stop', 'sad', 'u', 'gotta', 'chill', 'ur', 'room', 'listen', 'music', 'b', 'alon', ':(']
# 0.389055667402356
# ['stream', 'pass', 'melon', 'pleas', 'stream', 'much', '인피니트', 'digit', 'bad', ':(']
# 0.20218948653427882
# ['snapchat', 'jannygreen', '18', 'snapchat', 'kiksex', 'hot', 'teen', 'lgbt', 'goodmus', 'sexcam', ':(']
# 0.3035247089397704
# ['aw', ':(', 'stroke']
# 0.3542576419213974
# ['first', 'saw', 'gnr', 'open', 'alic', 'cooper', 'famou', 'parti', 'backstag', 'alic', 'r', 'slash', ':(']
# 0.48691653131242474
# ['tag', '♡', "i'm", 'sorri', 'lot', 'music', 'prolli', 'know', 'half', ':(', 'also']
# 0.5267524803753844
# ['24', 'hour', 'enough', ':(']
# 0.3002152902645775
# ['awww', 'poor', 'bunni', ':(']
# 0.3746202027672129
# ['stress', 'let', 'go', ':(']
# 0.3385909006323219
# ['wish', 'blooper', ':(']
# 0.10516343902284665
# ['love', 'u', 'fuck', 'know', ':(']
# 0.403705009147768
# ['yeah', ':(']
# 0.23090569365132685
# ['noth', 'though', ':(']
# 0.22439653081028624
# ['aww', "i'v", 'alreadi', 'left', 'would', 'come', 'said', 'hey', 'seen', 'sooner', ':(', 'good', 'night', 'x']
# 0.4311537524956009
# ['weird', ':(']
# 0.15398261672824992
# ['sr', 'financi', 'analyst', 'expedia', 'inc', 'bellevu', 'wa']
# 0.2619047619047619
# ['serious', ':(']
# 0.00013646288209606986
# ['tri', 'make', 'prison', 'style', 'alcohol', 'fail', 'badli', 'end', 'massiv', 'dose', 'shit', '...', ':(']
# 0.3661035399316018
# ['fair', 'still', 'look', 'cute', ':(']
# 0.3075747612350101
# ['hi', 'love', 'u', ':(', ':(']
# 0.40894104490710576
# ['overli', 'attach', ':(']
# 9.097525473071324e-05
# ["m'", 'voic', ':(', 'lord', 'help']
# 0.295958064389651
# ['want', 'bandana', 'bottl', 'set', 'huhuh', ':(']
# 0.29532107817854647
# ["can't", 'sleep', 'bc', 'heartburn', ':-(']
# 0.23110938996613214
# ['meet', 'steven', 'kid', 'listen', ':(']
# 0.2980430908999649
# ["i'm", 'fuck', 'jealou', 'everyon', 'holiday', ':(']
# 0.3443711703794506
# ['terribl', 'thing', 'doin', 'yoga', 'work', 'stop', 'start', '...', 'awalmu', 'njareeem', ':(']
# 0.36285521209793925
# ['nooo', 'last', 'day', 'today', ':(']
# 0.3098243182265009
# ['care', 'maggi', 'psycho', 'bitch', 'want', 'kill', 'take', 'two', 'day', 'vacat', 'twitter', ':(', 'wahhh']
# 0.4682102269119784
# ['realli', 'look', 'forward', 'work', 'tonight', 'though', ':(']
# 0.4184269563086258
# ['miss', 'abudhabi', ':(']
# 0.18889305858806404
# ['go', 'home', 'blue', ':-(', 'back', 'monday', 'hiby', 'social', 'action', 'plan', 'shareyoursumm']
# 0.47190865070482035
# ['pro', 'soccer', 'play', 'would', 'cool', ':(']
# 0.48840317314124787
# ['wish', 'b8', 'strong', ':(']
# 0.353872579267135
# ['hey', 'girl', 'must.b', 'dairi', 'produxt', 'want', "can't", 'lactos', 'intoler', ':(']
# 0.38617774932798443
# ['midland', 'ye', 'thank', 'depress', 'weather', 'forecast', 'word', 'rain', 'mention', 'sever', 'time', ':-(']
# 0.473227590143351
# ['cri', ':(']
# 0.07791424065987385
# ['old', 'one', 'day', '...', ':(']
# 0.40045809760400275
# ['liter', 'spent', 'day', 'yesterday', 'sleep', 'bed', "i'm", 'still', 'absolut', 'fuck', 'knacker', 'today', ':(']
# 0.3755106048746291
# ['new', 'sandra', 'bland', 'footag', 'realli', 'ice', 'cake', '..', 'heartbreak', 'drag', 'lifeless', 'bodi', 'polic', 'car', ':(']
# 0.2742013059035108
# ['knowww', ':(']
# 0.00013646288209606986
# ["we'r", 'sorri', 'feel', 'way', 'shell', ':(', 'regularli', 'review', 'price', 'offer', 'best']
# 0.39899376253620583
# ['sorri', 'hear', 'jess', ':(', 'quickest', 'way', 'call', '44', '7782', '333', '333', 'add', 'account', 'within', '72', 'hour']
# 0.33884685901149175
# ['pengen', 'box', ':(', '—']
# 0.33399680286961947
# ['girlll', 'u', 'hear', 'abt', 'possibl', 'tsunami', 'us', 'west', 'indi', 'im', 'island', 'im', 'afraid', 'lol', ':(']
# 0.5071880691937299
# ['snap', ':(']
# 0.30013646288209606
# ['would', 'love', 'see', 'w', 'nick', 'pick', 'one', 'waist', 'tv', 'time', 'never', 'work', 'anyway', ':(']
# 0.4881814926089911
# ['hulk', 'hogan', 'news', 'racial', 'tirad', ':(', 'thought', 'couldnt', 'stoop', 'lower', 'role', 'thunder', 'paradis']
# 0.5179050709971593
# ['sorri', 'forget', 'import', 'day', 'huhu', 'fight', 'im', 'sorri', ':(']
# 0.3540945970717128
# ['break', 'habit', 'lifetim', '...', "i'm", 'play', 'call', 'duti', 'game', '..', ':(']
# 0.3942911560230105
# ['apolog', 'annoy', 'much', 'snapchat', ':(']
# 0.3158997536295859
# ['adult', 'take', 'thing', 'seriou', 'realli', 'miss', 'kid', ':(']
# 0.27080444867856496
# ['facad', 'democraci', 'drop', 'quickli', ':(']
# 0.4700545851528385
# ['confus', 'brat', ':(']
# 0.24083171599547146
# ['someon', 'come', "i'll", 'make', 'popcorn', 'watch', 'movi', 'pl', 'cuddl', ':(']
# 0.31995049201141934
# ['final', 'home', 'drive', 'sinc', '5am', ':(']
# 0.2692855068673846
# ['tb', 'mr', "o'", 'class', ':(']
# 0.40561014070839396
# ['bade', 'fursat', 'se', 'usey', 'banaya', 'hai', 'usey', 'uppar', 'waal', 'ney', 'afso', 'hums', 'dur', 'hai', 'wo', ':(']
# 0.5062670578602619
# ['oh', 'realli', ':(', 'saw', 'gif', 'post', 'seen', 'realli', 'happi', 'mayb', 'peopl', "who'd", 'happi', 'naruhina']
# 0.44851317130198204
# ["can't", ':(']
# 0.0867286416530458
# ['that', 'english', 'namee', ':(', 'haiqal', 'isnt', 'english', 'name', 'rememb']
# 0.36422414296293865
# ['want', 'dont', 'paypal', ':(']
# 0.2479816172678197
# ["that'", '360hr', 'summer', 'end', '...', 'huhuhu', 'miss', 'picc', 'lot', ':(']
# 0.35900737975980357
# ['heart', 'hurt', ':(']
# 0.10755558271933818
# ['instor', 'card', 'expir', 'june', 'havent', 'sent', 'new', 'one', ':(']
# 0.3284260839154517
# ['mcountdown', 'pre-vot', 'begin', '5th', 'place', ':(']
# 0.3799738030395517
# ['felt', 'bad', 'iren', 'forgot', 'go', 'say', ':(']
# 0.23629038917960468
# ['wow', "that'", 'great', "what'", 'usernam', ':(']
# 0.618614592467517
# ['minho', 'still', 'injur', ':(', 'get', 'well', 'oppa', 'miss', '<3']
# 0.37385330602376693
# ["can't", 'even', 'deliv', 'ice', 'cream', 'tri', 'twice', 'ice', 'cream', 'van', 'busi', ':(']
# 0.24440411171035292
# ['want', 'durian', 'strudel', ':(']
# 0.3179816172678197
# ['vidcon', ':(']
# 0.10013646288209607
# ['guy', 'add', 'snapchat', 'amargolonnard', 'snapchat', 'kikmeboy', 'sexi', 'french', 'dirtykik', 'newmus', 'sexcam', ':(']
# 0.2947637837584578
# ['u', 'chang', 'u', 'say', 'chang', 'tsk', ':(']
# 0.40800263618844795
# ['damn', '..', 'wish', 'could', 'sleep', ':(']
# 0.27062114897256745
# ['like', 'join', 'marin', ':-(']
# 0.4616937669376694
# ["i'm", 'sad', 'yall', 'thought', 'real', ':(']
# 0.3059294504078799
# ["i'm", 'go', ':(', 'kailan', 'ba', 'may', 'tix', 'ka']
# 0.4699875800718335
# ['alreadi', 'kill', 'tho', ':(']
# 0.1996393098724206
# ['hotel', 'dog', 'pretti', 'sad', 'brother', 'sister', 'got', 'separ', ':(']
# 0.4085128751930761
# ['miss', 'cute', 'someon', 'la', ':(']
# 0.2643770792366789
# ['payday', 'feel', 'like', 'payhour', 'gone', 'bill', 'immedi', ':(']
# 0.35658899376930453
# ['lmao', ':(', 'natur', 'hair', "i'v", 'seen', 'ugli', 'swear']
# 0.34997566781766964
# ['nope', ':(', 'best', 'place', 'get', 'first', 'pre-ord', 'amazon']
# 0.5345639510480452
# ['sunday', 'littl', 'abl', 'get', 'much', 'year', 'busi', ':(', 'look', 'great', 'tho']
# 0.4432773107699749
# ['fwm', ':(']
# 0.5001364628820961
# ["what'", 'wrong', ':(']
# 0.25626381476090354
# ['miss', 'guppi', ':-(']
# 0.18880208333333334
# ['go', 'away', '...', 'must', 'go', 'dentist', ':(', 'poorkid']
# 0.3269228106673128
# ['thank', 'lack', 'time', 'problem', ':(']
# 0.605331433907948
# ['get', 'misunderstood', ':(']
# 0.32521174820159066
# ['ur', 'cat', 'super', 'nice', 'cuddli', 'suddenli', 'scratch', 'tri', 'bite', ':(', 'like', 'trust', 'anymor']
# 0.47070777754877163
# ['hit', 'thumb', ':(']
# 0.5953290704928259
# ['almost', 'got', 'see', 'cute', 'ankl', 'sock', ':(']
# 0.26906147523651186
# ['honestli', 'point', 'care', 'compens', 'want', 'abl', 'play', 'bf', ':(']
# 0.46847831180205496
# ['song', ':(']
# 0.19525841410160827
# ['awww', 'babi', ':(', '💕']
# 0.3422127953598055
# ['sleep', 'last', 'night', 'n', 'help', 'wake', '8', 'morn', 'n', 'phone', 'even', 'charg', ':(']
# 0.4245514108665563
# ['pleas', 'tell', 'everyon', 'didnt', 'go', 'vidcon', ':(']
# 0.3049596112543996
# ['need', 'like', 'tell', 'na', 'na', 'okay', 'lang', ':(']
# 0.30349769555605505
# ['follow', 'back', ':(']
# 0.33203610692771984
# ['heart', 'current', 'tortur', ':(', 'lol', 'wat']
# 0.26960135370221877
# ['femal', 'student', 'kill', 'cast', 'love', 'kirkiri', ':(']
# 0.3981301223998107
# ["i'v", 'run', 'bread', 'feel', 'well', 'enough', 'make', ':(']
# 0.39391638097041515
# ['dream', ':(']
# 0.25013646288209607
# [':(', 'broken', 'heart', "that'", 'phase', 'worri']
# 0.4626337765314437
# ['stop', 'sour', ':(', 'suit', '😂', '💞']
# 0.3709978685797463
# ['wonho', 'remind', 'someon', '>:(', 'cant', 'put', 'finger']
# 0.3701458361122226
# ['wont', 'work', 'today', 'feel', 'ill', ':(', 'tummi', 'bug', 'xx']
# 0.33023018393969283
# ['last', 'day', 'beach', ':-(', ':-(', ':-(', '...']
# 0.27559138792356164
# ['rain', ':(']
# 0.16680312954876272
# ['visual', 'studio', '2015', 'got', 'switch', 'alreadi', 'broke', 'lot', 'code', ':(']
# 0.3788878367941063
# ['serious', 'unfair', 'ask', 'question', 'readi', 'answer', 'win', ':(', "='(", 'busi', 'ask', 'question']
# 0.41273395733134777
# ['mission', 'bear', 'fail', ':(']
# 0.340977322350139
# [':-(', 'ugli', 'af', ':-(']
# 0.17708333333333331
# ['pap', 'spirit', 'anim', '—', 'dont', ':(']
# 0.3783788209606987
# ['total', 'ship', 'danzel', "i'm", 'craft', "can't", 'go', 'vidcon', 'would', 'sell', 'soul', 'devil', 'get', 'hug', 'dan', 'phil', ':(']
# 0.47514260238653927
# ['hate', ':(']
# 0.0834697962154294
# ["he'", 'gona', 'miss', 'sheff', 'utd', 'york', 'probabl', 'wait', 'visa', 'leav', 'gim', '1', 'friendli', 'bet', 'start', 'season', 'bench', ':(']
# 0.46424912799027257
# ['lead', 'us', 'gone', ':(']
# 0.3585359733765319
# ['😂', '😩', '😩', 'mess', ':(']
# 0.08805458515283843
# ['ironi', 'harm', '..', ':(']
# 0.25734336371618033
# ['miss', 'much', ':(', 'xxx']
# 0.26799254526379934
# ['motiv', ':(']
# 0.00013646288209606986
# ['point', 'yolo', 'sort', 'die', 'lactos', '...', 'ugh', 'like', '3', 'month', 'pregnant', 'bloat', ':(']
# 0.36664811356867566
# ['realli', 'sorri', 'cant', 'find', 'imag', 'mention', ':(']
# 0.3448912169394198
# ['im', 'get', 'olli', 'tweet', 'notif', ':(']
# 0.4770959806456964
# ['go', 'home', 'tomorrow', ':-(']
# 0.305077130811525
# ['bad', "i'm", 'poor', ':(']
# 0.16552349400584407
# ['team', 'kill', ':(']
# 0.27880719147094696
# ['way', ':(']
# 0.2616749244205576
# ["i'm", 'inact', ':(']
# 0.1150335039903629
# [':(', 'world', 'alterni', 'kill', 'realli', 'sad', 'leav', 'place', 'everyon', 'die']
# 0.36681074646101247
# ['everyon', 'gonna', 'talk', 'abt', 'rat', 'boy', 'today', 'bc', ':(']
# 0.35259877390523314
# ['earth', 'assum', 'rain', 'london', 'like', 'influenc', 'overal', 'warm', 'dri', 'past', 'week', 'continent', 'europ', ':(']
# 0.5192309191046035
# ['rememb', 'fab', 'four', '24', 'hour', 'call', 'damn', 'miss', 'much', ':(']
# 0.3817831859059732
# ['😀', '🔫', 'r', 'u', 'sure', 'u', 'want', 'b', 'r', 'u', 'h', 'bare', 'surviv', 'w', 'tank', 'top', ':(']
# 0.5192738965091005
# ['thirsti', ':(']
# 0.25013646288209607
# ['konami', 'polici', 'pe', 'pc', 'version', 'happen', 'version', ':(']
# 0.4144686395300478
# ['sound', 'effect', ':(']
# 0.31860949377324926
# ['blame', 'ranti', ':(']
# 0.3334243085880641
# ['ummm', 'ok', 'new', 'develop', ':(']
# 0.33161783671608996
# ['guy', 'never', ':(', '—', 'aw', 'sorri', "we'r", 'realli', 'bust', 'atm', '..', 'shall', 'back', 'soon']
# 0.45567810713971213
# ['bad', ':(', 'like', 'video', 'mani', 'pervers']
# 0.390538103268577
# ['first', 'time', 'go', 'school', 'without', 'bracelet', ':(', 'feel', 'odd']
# 0.36622989308603254
# ["can't", 'fall', 'back', 'asleep', ':(']
# 0.2346268571780142
# ['im', 'twin', 'follow', 'back', 'bylfnnz', ':(']
# 0.29273038223098324
# ['unfair', '..', 'u', 'ban', 'film', 'pakistan', ':(']
# 0.4004630072405052
# ['want', 'one', ':(']
# 0.23556969258897698
# ['feel', 'sick', ':(']
# 0.07726515608744813
# ['hmmm', '10', 'min', 'get', 'train', "i'm", 'current', '15', 'min', 'away', ':(', 'failsatlif']
# 0.4660694664416734
# ["i'm", 'hungri', ':(']
# 0.15947794843480734
# ['want', 'birthday', 'alreadi', ':(']
# 0.33917726944173276
# ['complet', 'agre', 'press', ':(']
# 0.5974947020292833
# ['im', 'super', 'duper', 'tire', ':(']
# 0.4288600799534984
# ['bore', 'time', ':(', 'know', '...']
# 0.3396286562892227
# ['ill', 'soon', 'promis', ':(', 'waaah']
# 0.3823644321685678
# ['wanna', 'chang', 'avi', 'usanel', ':(']
# 0.30620915409810506
# ['puppi', 'broke', 'foot', ':(']
# 0.16078251715533373
# ["where'", 'jaebum', 'babi', 'pictur', ':(']
# 0.2796842147824681
# ['mr', 'ahmad', 'maslan', 'cook', ':(']
# 0.35005458515283844
# ['hull', 'support', 'expect', 'misser', 'week', ':-(']
# 0.423969587835134

# %%
error_in_pos = 0
for i in pos_values:
    if i>0.5:
        error_in_pos+=1

error_in_pos = 100 - error_in_pos/len(pos_values)*100
error_in_pos
# Out:
# 9.0

# %%
error_in_neg = 0
for i in neg_values:
    if i<=0.5:
        error_in_neg+=1

error_in_neg = 100 - error_in_neg/len(neg_values)*100
error_in_neg
# Out:
# 6.799999999999997
